# %%
from autoscraper import AutoScraper
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city

# %%
url="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city"
wanted_list=["3 BHK Apartment","Chattarpur, Delhi","1250","Ready to move","0 - 1","65 L"]

# %%
scraper=AutoScraper()

# %%
scraper=AutoScraper()
result=scraper.build(url,wanted_list)
print(result)
# Out:
# ['3 BHK Apartment', '2 BHK Apartment', '4 BHK Independent House', '2 BHK Independent Floor', '3 BHK Independent Floor', '1 RK Studio Apartment', '4 BHK Independent Floor', '5 BHK Apartment', 'Chattarpur, Delhi', 'Vasant Kunj, Delhi', 'Mehrauli, Delhi', 'Anand Parbat, Delhi', 'vikaspuri, Delhi', 'Uttam Nagar, Delhi', 'Sector 14 Dwarka, Delhi', 'Dwarka Mor, Delhi', 'Hastsal, Delhi', 'Subhash Nagar, Delhi', 'Mahavir Enclave, Delhi', 'Sector 18 Rohini, Delhi', 'Janakpuri, Delhi', 'Sector 22 Rohini, Delhi', 'Rangpuri, Delhi', '1250', '1200', '1500', '800', '900', '3000', '840', '500', '522', '720', '642', '1100', '1935', '732', '1350', '1650', '713', '2500', 'Ready to move', 'Under Construction', '65 L', '70 L', '75 L', '50 L', '90 L', '50.5 L', '42 L', '28 L', '31 L', '25 L', '1.2 Cr', '38 L', '1.6 Cr', '85 L', '2 Cr', '2.65 Cr', '2.5 Cr']

# %%
scraper.get_result_similar(url,grouped=True)
# Out:
# {'rule_9a44': ['3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '4 BHK Independent House',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '1 RK Studio Apartment',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Apartment',
#   '2 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '2 BHK Apartment',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '5 BHK Apartment'],
#  'rule_6ymm': ['3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '4 BHK Independent House',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '1 RK Studio Apartment',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Apartment',
#   '2 BHK Independent Floor',
#   '4 BHK Independent Floor',
# ...

# %%
scraper.set_rule_aliases({'rule_9a44':'Title','rule_s2ox':'Location','rule_5gjw':'Area','rule_khl6':'Status','rule_lkyc':'Price'})
scraper.keep_rules(['rule_9a44','rule_s2ox','rule_5gjw','rule_khl6','rule_lkyc'])
scraper.save('makaan-search')

# %%
results=scraper.get_result_similar('https://www.makaan.com/listings?sortBy=popularity&listingType=buy&pageType=CITY_URLS&cityName=Delhi&cityId=6&templateId=MAKAAN_CITY_LISTING_BUY',group_by_alias=True)

# %%
results['Price']
# Out:
# ['8.5 Cr',
#  '9.5 L',
#  '2.35 Cr',
#  '2.4 Cr',
#  '2.35 Cr',
#  '2.9 Cr',
#  '2.25 Cr',
#  '2.7 Cr',
#  '1.95 Cr',
#  '1.65 Cr',
#  '1.35 Cr',
#  '1.25 Cr',
#  '1.2 Cr',
#  '1.15 Cr',
#  '45.95 Cr',
#  '1.6 Cr',
#  '1.08 Cr',
#  '1.07 Cr',
#  '1.25 Cr',
#  '20.1 Cr']

# %%
makaan=pd.DataFrame(results)
makaan.head(20)
# Out:
#                       Title                         Location  Area  \
# 0   4 BHK Independent Floor                Neeti Bagh, Delhi  2925
# 1           1 BHK Apartment               Khera Khurd, Delhi   450
# 2   3 BHK Independent Floor             Paschim Vihar, Delhi  1620
# 3   3 BHK Independent Floor             Paschim Vihar, Delhi  1620
# 4   4 BHK Independent Floor             Paschim Vihar, Delhi  2250
# 5   4 BHK Independent Floor             Paschim Vihar, Delhi  2250
# 6   3 BHK Independent Floor             Paschim Vihar, Delhi  1800
# 7   4 BHK Independent Floor             Paschim Vihar, Delhi  2250
# 8           3 BHK Apartment          Sector 19 Dwarka, Delhi  1800
# 9           3 BHK Apartment          Sector 19 Dwarka, Delhi  1800
# 10          2 BHK Apartment             Paschim Vihar, Delhi   900
# 11          2 BHK Apartment             Paschim Vihar, Delhi   900
# 12          2 BHK Apartment             Paschim Vihar, Delhi   900
# ...

# %%
makaan.shape
# Out:
# (20, 5)

# %%
url2="https://www.makaan.com/listings?sortBy=popularity&listingType=buy&pageType=CITY_URLS&cityName=Delhi&cityId=6&templateId=MAKAAN_CITY_LISTING_BUY&page=3&_=1666733990508"
wanted_list2=["3 BHK Independent Floor","Kaushambi, Delhi","2010","Ready to move", "5 - 6", "1.99 Cr"]

# %%
result2=scraper.build(url2,wanted_list2)
print(result2)
# Out:
# ['4 BHK Independent Floor', '3 BHK Independent Floor', '1 BHK Independent Floor', '3 BHK Apartment', '3 BHK Apartment in DDA D3 and D4 Vasant Kunj', '2 BHK Apartment', '2 BHK Apartment in Reputed Builder Ekta Apartment', '4 BHK Apartment', '4 BHK Apartment in Reputed Builder Sapna Ghar Apartment', '3 BHK Apartment in Reputed Builder Heritage Tower', '3 BHK Apartment in Reputed Builder Kaveri Apartment', '3 BHK Apartment in Reputed Builder Shivani Apartment', '4 BHK Apartment in CGHS Best Paradise', '1 BHK Apartment in Reputed Builder Shree Awas Apartment', '2 BHK Apartment in DDA Suryodaya', 'Kaushambi, Delhi', 'Sector 14 Rohini, Delhi', 'Shalimar Bagh, Delhi', 'Janakpuri, Delhi', 'Sector 11 Rohini, Delhi', 'Sector 10 Dwarka, Delhi', 'DDA D3 and D4 Vasant Kunj,Vasant Kunj, Delhi', 'Sector 22 Dwarka, Delhi', 'Sector-18 Dwarka, Delhi', 'Vasant Kunj, Delhi', 'Sector 3 Dwarka, Delhi', 'Sector 11 Dwarka, Delhi', 'Sector 8 Dwarka, Delhi', 'Sector 6 Dwarka, Delhi', 'Sector 12 Dwarka, Delhi'
# ...

# %%
scraper.get_result_similar(url2,grouped=True)
# Out:
# {'rule_9lgy': ['4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '1 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Apartment',
#   '3 BHK Apartment in DDA D3 and D4 Vasant Kunj',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment in Reputed Builder Ekta Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment in Reputed Builder Sapna Ghar Apartment',
#   '3 BHK Apartment in Reputed Builder Heritage Tower',
#   '3 BHK Independent Floor',
#   '3 BHK Apartment in Reputed Builder Kaveri Apartment',
#   '3 BHK Apartment in Reputed Builder Shivani Apartment',
#   '4 BHK Apartment in CGHS Best Paradise',
#   '1 BHK Apartment in Reputed Builder Shree Awas Apartment',
#   '2 BHK Apartment in DDA Suryodaya'],
#  'rule_329f': ['4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '1 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
# ...

# %%
scraper.set_rule_aliases({'rule_9lgy':'Title','rule_uc6v':'Area','rule_tfxu':'Status','rule_hzph':'Price'})
scraper.keep_rules(['rule_9lgy','rule_uc6v', 'rule_tfxu','rule_hzph'])
scraper.save('makaan-search')

# %%
results2=scraper.get_result_similar('https://www.makaan.com/listings?sortBy=popularity&listingType=buy&pageType=CITY_URLS&cityName=Delhi&cityId=6&templateId=MAKAAN_CITY_LISTING_BUY&page=3&_=1666733990508',group_by_alias=True)

# %%
results2
# Out:
# {'Title': ['4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '1 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Apartment',
#   '3 BHK Apartment in DDA D3 and D4 Vasant Kunj',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment in Reputed Builder Ekta Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment in Reputed Builder Sapna Ghar Apartment',
#   '3 BHK Apartment in Reputed Builder Heritage Tower',
#   '3 BHK Independent Floor',
#   '3 BHK Apartment in Reputed Builder Kaveri Apartment',
#   '3 BHK Apartment in Reputed Builder Shivani Apartment',
#   '4 BHK Apartment in CGHS Best Paradise',
#   '1 BHK Apartment in Reputed Builder Shree Awas Apartment',
#   '2 BHK Apartment in DDA Suryodaya'],
#  'Area': ['2010',
#   '950',
#   '500',
#   '2025',
#   '1180',
#   '1500',
#   '1450',
#   '1100',
#   '1100',
#   '1800',
#   '1100',
#   '2200',
#   '2100',
#   '1700',
#   '2100',
# ...

# %%
makaan2=pd.DataFrame(results2)
makaan2.head(20)
# Out:
#                                                 Title  Area         Status  \
# 0                             4 BHK Independent Floor  2010  Ready to move
# 1                             3 BHK Independent Floor   950  Ready to move
# 2                             1 BHK Independent Floor   500  Ready to move
# 3                             4 BHK Independent Floor  2025  Ready to move
# 4                             3 BHK Independent Floor  1180  Ready to move
# 5                                     3 BHK Apartment  1500  Ready to move
# 6        3 BHK Apartment in DDA D3 and D4 Vasant Kunj  1450  Ready to move
# 7                                     2 BHK Apartment  1100  Ready to move
# 8                                     2 BHK Apartment  1100  Ready to move
# 9                                     3 BHK Apartment  1800  Ready to move
# 10  2 BHK Apartment in Reputed Builder Ekta Apartment  1100  Ready to move
# ...

# %%
m=makaan.append(makaan2)
m.head()
# Out:
#                      Title              Location  Area         Status    Price
# 0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925  Ready to move   8.5 Cr
# 1          1 BHK Apartment    Khera Khurd, Delhi   450  Ready to move    9.5 L
# 2  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move  2.35 Cr
# 3  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move   2.4 Cr
# 4  4 BHK Independent Floor  Paschim Vihar, Delhi  2250  Ready to move  2.35 Cr

# %%
m.shape
# Out:
# (40, 5)

# %%
url="https://www.makaan.com/listings?sortBy=rating-desc&listingType=buy&pageType=LISTINGS_PROPERTY_URLS&cityName=Delhi&cityId=6&templateId=MAKAAN_CITY_LISTING_BUY"
wanted_list=["3 BHK Apartment","Chhawla, Delhi","1540","Under Construction","Possession by Apr 2023","53 L"]

# %%
result3=scraper.build(url3,wanted_list3)
print(result3)
# Out:
# ['3 BHK Apartment', '2 BHK Apartment', '1 BHK Apartment', '4 BHK Apartment', '4 BHK Independent Floor', 'Chhawla, Delhi', 'Zone L Dwarka, Delhi', 'Neeti Bagh, Delhi', '1540', '1235', '935', '575', '2275', '1575', '1275', '1975', '1875', '2575', '875', '1075', '925', '765', '525', '4200', '4100', '4000', '7000', 'Under Construction', 'Ready to move', 'Possession by Apr 2023', 'Possession by May 2023', 'Possession by Mar 2023', 'Possession by Jun 2023', 'Possession by Nov 2021', '2 - 3 years old', '3 Bathrooms', '2 Bathrooms', '1 Bathrooms', 'New', '4 Bathrooms', '53 L', '42 L', '32 L', '20 L', '93.04 L', '64.41 L', '52.14 L', '80.77 L', '76.68 L', '1.05 Cr', '35.78 L', '43.96 L', '34.68 L', '28.68 L', '19.68 L', '18 Cr', '21 Cr']

# %%
scraper.get_result_similar(url3,grouped=True)
# Out:
# {'rule_307e': ['3 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '1 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '1 BHK Apartment',
#   '1 BHK Apartment',
#   '4 BHK Independent Floor',
#   '1 BHK Apartment',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor'],
#  'rule_es88': ['3 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '1 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '1 BHK Apartment',
#   '1 BHK Apartment',
#   '4 BHK Independent Floor',
#   '1 BHK Apartment',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
# ...

# %%
scraper.set_rule_aliases({'rule_307e':'Title','rule_jkyi':'Location','rule_o91r':'Area','rule_k5zp':'Status','rule_trej':'Year', 'rule_ewe5':'Bathroom','rule_nzng':'Price'})
scraper.keep_rules(['rule_ocm3', 'rule_jkyi', 'rule_o91r', 'rule_k5zp','rule_trej','rule_ewe5','rule_nzng'])
scraper.save('makaan-search')

# %%
results3=scraper.get_result_similar(url3,group_by_alias=True)
results3
# Out:
# {'Location': ['Chhawla, Delhi',
#   'Chhawla, Delhi',
#   'Chhawla, Delhi',
#   'Chhawla, Delhi',
#   'Zone L Dwarka, Delhi',
#   'Zone L Dwarka, Delhi',
#   'Zone L Dwarka, Delhi',
#   'Zone L Dwarka, Delhi',
#   'Zone L Dwarka, Delhi',
#   'Zone L Dwarka, Delhi',
#   'Zone L Dwarka, Delhi',
#   'Zone L Dwarka, Delhi',
#   'Chhawla, Delhi',
#   'Chhawla, Delhi',
#   'Chhawla, Delhi',
#   'Neeti Bagh, Delhi',
#   'Neeti Bagh, Delhi',
#   'Neeti Bagh, Delhi',
#   'Neeti Bagh, Delhi',
#   'Neeti Bagh, Delhi'],
#  'Area': ['1540',
#   '1235',
#   '935',
#   '575',
#   '2275',
#   '1575',
#   '1275',
#   '1975',
#   '1875',
#   '2575',
#   '875',
#   '1075',
#   '925',
#   '765',
#   '525',
#   '4200',
#   '4100',
#   '4000',
#   '4100',
#   '7000'],
#  'Status': ['Under Construction',
#   'Under Construction',
#   'Under Construction',
#   'Under Construction',
#   'Under Construction',
#   'Under Construction',
#   'Under Construction',
#   'Under Construction',
# ...

# %%
makaan3=pd.DataFrame(results3)
makaan3.head(20)
# Out:
#                 Location  Area              Status                    Year  \
# 0         Chhawla, Delhi  1540  Under Construction  Possession by Apr 2023
# 1         Chhawla, Delhi  1235  Under Construction  Possession by May 2023
# 2         Chhawla, Delhi   935  Under Construction  Possession by Mar 2023
# 3         Chhawla, Delhi   575  Under Construction  Possession by Jun 2023
# 4   Zone L Dwarka, Delhi  2275  Under Construction  Possession by Mar 2023
# 5   Zone L Dwarka, Delhi  1575  Under Construction  Possession by Mar 2023
# 6   Zone L Dwarka, Delhi  1275  Under Construction  Possession by Mar 2023
# 7   Zone L Dwarka, Delhi  1975  Under Construction  Possession by Mar 2023
# 8   Zone L Dwarka, Delhi  1875  Under Construction  Possession by Mar 2023
# 9   Zone L Dwarka, Delhi  2575  Under Construction  Possession by Mar 2023
# 10  Zone L Dwarka, Delhi   875  Under Construction  Possession by Mar 2023
# ...

# %%
m3=m.append(makaan3)
m3.head()
# Out:
#                      Title              Location  Area         Status  \
# 0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925  Ready to move
# 1          1 BHK Apartment    Khera Khurd, Delhi   450  Ready to move
# 2  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 3  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 4  4 BHK Independent Floor  Paschim Vihar, Delhi  2250  Ready to move
#
#      Price Year Bathroom
# 0   8.5 Cr  NaN      NaN
# 1    9.5 L  NaN      NaN
# 2  2.35 Cr  NaN      NaN
# 3   2.4 Cr  NaN      NaN
# 4  2.35 Cr  NaN      NaN

# %%
m3.shape
# Out:
# (60, 7)

# %%
m3.to_csv("WebScraped_Makaan.csv")

# %%
url4="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=5"
wanted_list4=["2 BHK Independent Floor","Uttam Nagar, Delhi","580","Ready to move","2 Bathrooms","20 L"]

# %%
result4=scraper.build(url4,wanted_list4)
print(result4)
# Out:
# ['2 BHK Independent Floor', '3 BHK Independent Floor', '3 BHK Independent House', '1 BHK Apartment', '1 BHK Independent House', '4 BHK Independent Floor', 'Residential Plot', '3 BHK Apartment', 'Uttam Nagar, Delhi', 'Krishna Nagar, Delhi', 'Razapur Khurd, Delhi', 'Ashok Vihar, Delhi', 'Sabzi Mandi Old, Delhi', 'Pitampura, Delhi', 'Tilak Nagar, Delhi', 'Mahavir Enclave, Delhi', 'rohini sector 5, Delhi', 'Najafgarh, Delhi', 'Sector 14 Rohini, Delhi', 'Rajpur, Delhi', 'Sewak Park, Delhi', 'Sector 19 Dwarka, Delhi', 'Punjabi Bagh, Delhi', 'Janakpuri, Delhi', 'Patparganj, Delhi', 'Shahdara, Delhi', 'Sector 21 Rohini, Delhi', '580', '990', '459', '1780', '2000', '1337', '810', '450', '278', '1000', '3000', '1300', '720', '828', '750', '1500', '675', '700', 'Ready to move', 'Under Construction', 'Resale', '2 Bathrooms', '1 Bathrooms', '3 Bathrooms', '6 - 7 years old', '3 - 4 years old', '5 - 6 years old', '3 years old', '20 L', '63 L', '15 L', '2.6 Cr', '1 Cr', '46 L', '20.99 L', '50 L', '4
# ...

# %%
scraper.get_result_similar(url4,grouped=True)
# Out:
# {'rule_04kn': ['2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent House',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '1 BHK Apartment',
#   '1 BHK Independent House',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   'Residential Plot',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Apartment',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor'],
#  'rule_vxzl': ['2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent House',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '1 BHK Apartment',
#   '1 BHK Independent House',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '4 BHK Independent Floor',
# ...

# %%
scraper.set_rule_aliases({'rule_04kn':'Title','rule_uzst':'Area','rule_3rep':'Status','rule_i6gs':'Price'})
scraper.keep_rules(['rule_04kn', 'rule_uzst', 'rule_3rep','rule_i6gs'])
scraper.save('makaan-search')

# %%
results4=scraper.get_result_similar(url4,group_by_alias=True)
results4
# Out:
# {'Title': ['2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent House',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '1 BHK Apartment',
#   '1 BHK Independent House',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   'Residential Plot',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Apartment',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor'],
#  'Area': ['580',
#   '990',
#   '459',
#   '1780',
#   '2000',
#   '1337',
#   '810',
#   '450',
#   '278',
#   '1000',
#   '3000',
#   '2000',
#   '1000',
#   '1300',
#   '720',
#   '828',
#   '750',
#   '1500',
#   '675',
#   '700'],
#  'Status': ['Ready to move',
#   'Ready to move',
#   'Under Construction',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
# ...

# %%
makaan4=pd.DataFrame(results4)
makaan4.head(20)
# Out:
#                       Title  Area              Status    Price
# 0   2 BHK Independent Floor   580       Ready to move     20 L
# 1   3 BHK Independent Floor   990       Ready to move     63 L
# 2   2 BHK Independent Floor   459  Under Construction     15 L
# 3   3 BHK Independent Floor  1780       Ready to move   2.6 Cr
# 4   3 BHK Independent House  2000       Ready to move     1 Cr
# 5   3 BHK Independent Floor  1337       Ready to move   2.6 Cr
# 6   2 BHK Independent Floor   810       Ready to move     46 L
# 7           1 BHK Apartment   450       Ready to move  20.99 L
# 8   1 BHK Independent House   278       Ready to move     50 L
# 9   3 BHK Independent Floor  1000  Under Construction     42 L
# 10  4 BHK Independent Floor  3000       Ready to move   3.6 Cr
# 11  4 BHK Independent Floor  2000       Ready to move  2.75 Cr
# 12         Residential Plot  1000              Resale     45 L
# 13  3 BHK Independent Floor  1300  Under Construction     75 L
# ...

# %%
m4=m3.append(makaan4)
m4.head()
# Out:
#                      Title              Location  Area         Status  \
# 0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925  Ready to move
# 1          1 BHK Apartment    Khera Khurd, Delhi   450  Ready to move
# 2  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 3  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 4  4 BHK Independent Floor  Paschim Vihar, Delhi  2250  Ready to move
#
#      Price Year Bathroom
# 0   8.5 Cr  NaN      NaN
# 1    9.5 L  NaN      NaN
# 2  2.35 Cr  NaN      NaN
# 3   2.4 Cr  NaN      NaN
# 4  2.35 Cr  NaN      NaN

# %%
m4.shape
# Out:
# (80, 7)

# %%
url5="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=6"
wanted_list5=["2 BHK Independent Floor","Mahavir Enclave, Delhi","800","Ready to move","2 Bathrooms","36.5 L"]

# %%
result5=scraper.build(url5,wanted_list5)
print(result5)
# Out:
# ['2 BHK Independent Floor', '3 BHK Apartment', 'Residential Plot', '3 BHK Independent Floor', '1 BHK Independent Floor', '4 BHK Independent Floor', '1 BHK Apartment', '2 BHK Apartment in C S Homes D 1 12 Chattarpur', '2 BHK Apartment in Reputed Builder Savera Appartments', 'Mahavir Enclave, Delhi', 'Jamia Nagar, Delhi', 'Karol Bagh, Delhi', 'Najafgarh, Delhi', 'vikaspuri, Delhi', 'Sector-7 Rohini, Delhi', 'Punjabi Bagh, Delhi', 'Sector 1 Dwarka, Delhi', 'Sector 14 Dwarka, Delhi', 'Sector 21 Rohini, Delhi', 'Chattarpur, Delhi', 'Sector 13 Rohini, Delhi', '800', '1100', '900', '450', '1250', '345', '2800', '1500', '2495', '500', '700', '630', '986', 'Ready to move', 'Under Construction', 'Resale', 'NorthEast facing', 'East facing', '3 Bathrooms', '1 Bathrooms', '4 Bathrooms', '2 Bathrooms', '2 open sides', '3 open sides', '6 years old', '3 years old', '2 - 3 years old', '36.5 L', '38 L', '70 L', '2.5 L', '8.99 L', '20 L', '1.55 Cr', '1.65 Cr', '33 L', '5 Cr', '2.45 Cr', '4.25 Cr', '75 
# ...

# %%
scraper.get_result_similar(url5,grouped=True)
# Out:
# {'rule_rs72': ['2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Apartment',
#   'Residential Plot',
#   'Residential Plot',
#   'Residential Plot',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '1 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '1 BHK Apartment',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Apartment in C S Homes D 1 12 Chattarpur',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Apartment in Reputed Builder Savera Appartments'],
#  'rule_av8n': ['2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Apartment',
#   'Residential Plot',
#   'Residential Plot',
#   'Residential Plot',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '1 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
# ...

# %%
scraper.set_rule_aliases({'rule_rs72':'Title','rule_9aiy':'Area','rule_m04k':'Status','rule_2z9q':'Price'})
scraper.keep_rules(['rule_rs72', 'rule_9aiy','rule_m04k','rule_2z9q'])
scraper.save('makaan-search')

# %%
results5=scraper.get_result_similar(url5,group_by_alias=True)
results5
# Out:
# {'Title': ['2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Apartment',
#   'Residential Plot',
#   'Residential Plot',
#   'Residential Plot',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '1 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '1 BHK Apartment',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Apartment in C S Homes D 1 12 Chattarpur',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Apartment in Reputed Builder Savera Appartments'],
#  'Area': ['800',
#   '800',
#   '1100',
#   '900',
#   '450',
#   '900',
#   '1250',
#   '1250',
#   '345',
#   '2800',
#   '1500',
#   '2495',
#   '1100',
#   '500',
#   '800',
#   '800',
#   '630',
#   '700',
#   '700',
#   '986'],
#  'Status': ['Ready to move',
#   'Under Construction',
#   'Ready to move',
#   'Resale',
#   'Resale',
# ...

# %%
makaan5=pd.DataFrame(results5)
makaan5.head(20)
# Out:
#                                                 Title  Area  \
# 0                             2 BHK Independent Floor   800
# 1                             2 BHK Independent Floor   800
# 2                                     3 BHK Apartment  1100
# 3                                    Residential Plot   900
# 4                                    Residential Plot   450
# 5                                    Residential Plot   900
# 6                             3 BHK Independent Floor  1250
# 7                             3 BHK Independent Floor  1250
# 8                             1 BHK Independent Floor   345
# 9                             4 BHK Independent Floor  2800
# 10                            3 BHK Independent Floor  1500
# 11                            4 BHK Independent Floor  2495
# 12                            3 BHK Independent Floor  1100
# 13                                    1 BHK Apartment   500
# 14                            2 BHK Independent Floor   800
# ...

# %%
m5=m4.append(makaan5)
m5.head()
# Out:
#                      Title              Location  Area         Status  \
# 0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925  Ready to move
# 1          1 BHK Apartment    Khera Khurd, Delhi   450  Ready to move
# 2  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 3  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 4  4 BHK Independent Floor  Paschim Vihar, Delhi  2250  Ready to move
#
#      Price Year Bathroom
# 0   8.5 Cr  NaN      NaN
# 1    9.5 L  NaN      NaN
# 2  2.35 Cr  NaN      NaN
# 3   2.4 Cr  NaN      NaN
# 4  2.35 Cr  NaN      NaN

# %%
url6="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=7"
wanted_list6=["4 BHK Independent Floor","Paschim Vihar, Delhi","2700","Ready to move","4 Bathrooms","3.5 Cr"]
result6=scraper.build(url6,wanted_list6)
print(result6)

scraper.get_result_similar(url6,grouped=True)
# Out:
# ['4 BHK Independent Floor', '1 BHK Independent Floor', '2 BHK Apartment in Partap Builder Floors', '3 BHK Independent House', '2 BHK Independent Floor', '5 BHK Independent Floor', '3 BHK Independent Floor', '2 BHK Apartment in Reputed Builder Bagwan Apartment', '2 BHK Apartment', '3 BHK Apartment in  Tarun Vihar Apartments', 'Paschim Vihar, Delhi', 'Sector 6 Rohini, Delhi', 'Partap Builder Floors,Uttam Nagar, Delhi', 'Saboli, Delhi', 'Mahavir Enclave, Delhi', 'Shahdara, Delhi', 'Sagar Pur, Delhi', 'Reputed Builder Bagwan Apartment,Sector 28 Rohini, Delhi', 'laxmi nagar, Delhi', 'Dwarka Mor, Delhi', 'Uttam Nagar, Delhi', 'Sector 28 Rohini, Delhi', 'Mundka, Delhi', 'Sector 13 Rohini, Delhi', 'Sector 25 Rohini, Delhi', 'Palam, Delhi', 'Baljeet Nagar, Delhi', '2700', '320', '500', '631', '850', '1980', '1350', '700', '900', '360', '1000', '800', '675', '1200', '1150', '490', '585', '650', 'Ready to move', '4 Bathrooms', '4 - 5 years old', '2 Bathrooms', '3 - 4 years old', '3 Bathrooms', 
# ...

# %%
scraper.set_rule_aliases({'rule_n0dc':'Title','rule_bwv0':'Area','rule_4ukn':'Status','rule_q3p4':'Bathroom','rule_6blj':'Price'})
scraper.keep_rules(['rule_n0dc','rule_bwv0','rule_4ukn','rule_q3p4','rule_6blj'])
scraper.save('makaan-search')
results6=scraper.get_result_similar(url6,group_by_alias=True)
results6
# Out:
# {'Title': ['4 BHK Independent Floor',
#   '1 BHK Independent Floor',
#   '2 BHK Apartment in Partap Builder Floors',
#   '3 BHK Independent House',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '5 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Apartment in Reputed Builder Bagwan Apartment',
#   '1 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Apartment',
#   '3 BHK Apartment in  Tarun Vihar Apartments',
#   '3 BHK Apartment in  Tarun Vihar Apartments',
#   '1 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor'],
#  'Area': ['2700',
#   '320',
#   '500',
#   '631',
#   '850',
#   '900',
#   '1980',
#   '1350',
#   '700',
#   '360',
#   '1000',
#   '800',
#   '675',
#   '1200',
#   '1150',
#   '490',
#   '585',
#   '650',
#   '1000',
#   '900'],
#  'Status': ['Ready to move',
#   'Ready to move',
# ...

# %%
makaan0=pd.DataFrame(results6)
m0=m5.append(makaan0)
m0.head()
# Out:
#                      Title              Location  Area         Status  \
# 0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925  Ready to move
# 1          1 BHK Apartment    Khera Khurd, Delhi   450  Ready to move
# 2  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 3  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 4  4 BHK Independent Floor  Paschim Vihar, Delhi  2250  Ready to move
#
#      Price Year Bathroom
# 0   8.5 Cr  NaN      NaN
# 1    9.5 L  NaN      NaN
# 2  2.35 Cr  NaN      NaN
# 3   2.4 Cr  NaN      NaN
# 4  2.35 Cr  NaN      NaN

# %%
url7="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=8"
wanted_list7=["2 BHK Independent Floor","Mahavir Enclave, Delhi","800","Under Construction","1 Bathrooms","38.5 L"]
result7=scraper.build(url7,wanted_list7)
print(result7)

scraper.get_result_similar(url7,grouped=True)
# Out:
# ['4 BHK Apartment', '2 BHK Apartment', '2 BHK Independent Floor', 'Residential Plot', '1 BHK Apartment', '3 BHK Apartment', '3 BHK Apartment in Swaraj Homes Prateek Apartment', '1 BHK Independent Floor', '3 BHK Independent House', '2 BHK Apartment in CGHS Sita Apartments', '3 BHK Apartment in Reputed Builder Asha Deep Apartments', '2 BHK Independent House', '4 BHK Independent Floor', 'Shahdara, Delhi', 'Sector 2 Rohini, Delhi', 'Mahavir Enclave, Delhi', 'Najafgarh, Delhi', 'Uttam Nagar, Delhi', 'Chattarpur, Delhi', 'Swaraj Homes Prateek Apartment,Paschim Vihar, Delhi', 'Munirka, Delhi', 'Paschim Vihar, Delhi', 'Burari, Delhi', 'Sector 13 Rohini, Delhi', 'Sector 2 Dwarka, Delhi', 'Lajpat Nagar IV, Delhi', 'Najafgarh Road Industrial Area, Delhi', 'Saket, Delhi', 'Sector 11 Rohini, Delhi', '1350', '500', '800', '900', '675', '1100', '1140', '450', '1000', '930', '1500', '950', '2000', 'Under Construction', 'Ready to move', 'Resale', '3 Bathrooms', '2 - 3 years old', '1 Bathrooms', '2 op
# ...

# %%
scraper.set_rule_aliases({'rule_cwli':'Title','rule_2bih':'Area','rule_1pr1':'Status','rule_mjt6':'Bathroom','rule_qd47':'Price'})
scraper.keep_rules(['rule_cwli', 'rule_2bih','rule_1pr1','rule_mjt6','rule_qd47'])
scraper.save('makaan-search')
results7=scraper.get_result_similar(url7,group_by_alias=True)
results7
# Out:
# {'Title': ['2 BHK Independent Floor',
#   '2 BHK Apartment',
#   '4 BHK Apartment',
#   'Residential Plot',
#   '3 BHK Independent House',
#   '2 BHK Apartment in CGHS Sita Apartments',
#   '3 BHK Apartment in Reputed Builder Asha Deep Apartments',
#   '2 BHK Independent Floor',
#   '2 BHK Independent House',
#   '2 BHK Independent Floor',
#   '1 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment in Swaraj Homes Prateek Apartment',
#   '1 BHK Independent Floor',
#   '1 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Apartment',
#   '2 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '2 BHK Apartment'],
#  'Area': ['800',
#   '500',
#   '1350',
#   '900',
#   '900',
#   '930',
#   '1500',
#   '950',
#   '675',
#   '675',
#   '500',
#   '1100',
#   '1140',
#   '450',
#   '450',
#   '1000',
#   '1000',
#   '800',
#   '1800',
#   '1200'],
#  'Status': ['Under Construction',
#   'Ready to move',
#   'Under Construction',
#   'Resale',
# ...

# %%
makaan01=pd.DataFrame(results7)
m01=m0.append(makaan7)
m01.head()
# Out:
#                      Title              Location  Area         Status  \
# 0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925  Ready to move
# 1          1 BHK Apartment    Khera Khurd, Delhi   450  Ready to move
# 2  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 3  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 4  4 BHK Independent Floor  Paschim Vihar, Delhi  2250  Ready to move
#
#      Price Year Bathroom
# 0   8.5 Cr  NaN      NaN
# 1    9.5 L  NaN      NaN
# 2  2.35 Cr  NaN      NaN
# 3   2.4 Cr  NaN      NaN
# 4  2.35 Cr  NaN      NaN

# %%
url8="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=9"
wanted_list8=["3 BHK Apartment","Ghitorni, Delhi","1200","Ready to move","3 Bathrooms","1.15 Cr"]
result8=scraper.build(url8,wanted_list8)
print(result8)

scraper.get_result_similar(url8,grouped=True)
# Out:
# ['3 BHK Apartment in Reputed Builder Bhawani Kunj', '4 BHK Independent Floor', '2 BHK Apartment', '3 BHK Independent Floor', '2 BHK Independent Floor', '1 RK Studio Apartment', '3 BHK Apartment', '5 BHK Independent Floor', '2 BHK Apartment in Reputed Builder Vinayak Apartment', 'Ghitorni, Delhi', 'Malviya Nagar, Delhi', 'Dilshad Garden, Delhi', 'Patel Nagar, Delhi', 'Alaknanda, Delhi', 'Dwarka Mor, Delhi', 'Uttam Nagar, Delhi', 'Karampura, Delhi', 'Pitampura, Delhi', 'Sudarshan Park, Delhi', 'Dashrath Puri, Delhi', 'Shahdara, Delhi', 'Sector 10 Dwarka, Delhi', 'Chittaranjan Park, Delhi', 'Mahavir Enclave, Delhi', 'Chattarpur, Delhi', 'Janakpuri, Delhi', '1200', '1800', '1400', '1100', '620', '1000', '350', '1500', '500', '2750', '700', '1050', '900', '1125', '800', '1350', '540', 'Ready to move', 'Under Construction', '2 - 3 years old', '4 Bathrooms', '2 Bathrooms', '3 Bathrooms', '5 - 6 years old', '1 Bathrooms', 'Resale', '6 years old', '1.15 Cr', '2.5 Cr', '65 L', '1.25 Cr', '1.5 
# ...

# %%
scraper.set_rule_aliases({'rule_idy2':'Title','rule_ryv7':'Location','rule_daf5':'Area','rule_bu9a':'Status','rule_wdj9':'Bathroom','rule_7iqq':'Price'})
scraper.keep_rules(['rule_idy2', 'rule_ryv7','rule_daf5','rule_bu9a','rule_wdj9','rule_7iqq'])
scraper.save('makaan-search')
results8=scraper.get_result_similar(url8,group_by_alias=True)
results8
# Out:
# {'Title': ['3 BHK Apartment in Reputed Builder Bhawani Kunj',
#   '4 BHK Independent Floor',
#   '2 BHK Apartment',
#   '3 BHK Independent Floor',
#   '2 BHK Apartment',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '1 RK Studio Apartment',
#   '3 BHK Apartment',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '5 BHK Independent Floor',
#   '2 BHK Apartment in Reputed Builder Vinayak Apartment',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor'],
#  'Location': ['Ghitorni, Delhi',
#   'Malviya Nagar, Delhi',
#   'Dilshad Garden, Delhi',
#   'Patel Nagar, Delhi',
#   'Alaknanda, Delhi',
#   'Dwarka Mor, Delhi',
#   'Uttam Nagar, Delhi',
#   'Karampura, Delhi',
#   'Pitampura, Delhi',
#   'Sudarshan Park, Delhi',
#   'Dashrath Puri, Delhi',
#   'Shahdara, Delhi',
# ...

# %%
makaan9=pd.DataFrame(results8)
m9=m01.append(makaan9)
m9.head()
# Out:
#                      Title              Location  Area         Status  \
# 0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925  Ready to move
# 1          1 BHK Apartment    Khera Khurd, Delhi   450  Ready to move
# 2  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 3  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 4  4 BHK Independent Floor  Paschim Vihar, Delhi  2250  Ready to move
#
#      Price Year Bathroom
# 0   8.5 Cr  NaN      NaN
# 1    9.5 L  NaN      NaN
# 2  2.35 Cr  NaN      NaN
# 3   2.4 Cr  NaN      NaN
# 4  2.35 Cr  NaN      NaN

# %%
m9.shape
# Out:
# (160, 7)

# %%
url10="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=10"
wanted_list10=["3 BHK Independent Floor","vikaspuri, Delhi","1250","Ready to move","6 years old","2 Bathrooms","1.6 Cr"]
result10=scraper.build(url10,wanted_list10)
print(result10)

scraper.get_result_similar(url10,grouped=True)
# Out:
# ['3 BHK Independent Floor', 'Residential Plot in Swaraj Homes RWA Gemini Park Najafgarh', '1 BHK Apartment', '1 BHK Independent Floor', '2 BHK Apartment in Reputed Builder Krishi Apartments', '3 BHK Apartment in DDA DDA Sector C Pocket 9', '2 BHK Independent Floor', '3 BHK Apartment', '2 BHK Apartment', 'vikaspuri, Delhi', 'Swaraj Homes RWA Gemini Park Najafgarh,Sector 16B Dwarka, Delhi', 'Rohini sector 24, Delhi', 'Chirag Dilli, Delhi', 'Budh Vihar, Delhi', 'Reputed Builder Krishi Apartments,Sector 13 Rohini, Delhi', 'DDA DDA Sector C Pocket 9,Vasant Kunj, Delhi', 'Palam, Delhi', 'Dilshad Garden, Delhi', 'Dwarka Mor, Delhi', 'Sector 16B Dwarka, Delhi', 'Sector 13 Rohini, Delhi', 'Vasant Kunj, Delhi', 'Defence Colony, Delhi', 'Uttam Nagar, Delhi', 'Badarpur, Delhi', 'Dabri, Delhi', 'Mahavir Enclave, Delhi', 'Krishna Nagar, Delhi', '1250', '455', '900', '450', '650', '2600', '675', '1000', '1425', '540', '2018', '680', '800', '1900', '1400', 'Ready to move', 'Resale', '6 years old', '
# ...

# %%
scraper.set_rule_aliases({'rule_hr0z':'Title','rule_57zb':'Area','rule_6lj8':'Status','rule_d50y':'Price'})
scraper.keep_rules(['rule_hr0z', 'rule_57zb','rule_6lj8','rule_d50y'])
scraper.save('makaan-search')
results10=scraper.get_result_similar(url10,group_by_alias=True)
results10
# Out:
# {'Title': ['3 BHK Independent Floor',
#   'Residential Plot in Swaraj Homes RWA Gemini Park Najafgarh',
#   '3 BHK Independent Floor',
#   '1 BHK Apartment',
#   '1 BHK Independent Floor',
#   '2 BHK Apartment in Reputed Builder Krishi Apartments',
#   '3 BHK Apartment in DDA DDA Sector C Pocket 9',
#   '2 BHK Independent Floor',
#   '3 BHK Apartment',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Apartment',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Apartment'],
#  'Area': ['1250',
#   '455',
#   '900',
#   '450',
#   '450',
#   '650',
#   '2600',
#   '675',
#   '1000',
#   '1425',
#   '540',
#   '2018',
#   '2018',
#   '900',
#   '450',
#   '675',
#   '680',
#   '800',
#   '1900',
#   '1400'],
#  'Status': ['Ready to move',
#   'Resale',
#   'Ready to move',
# ...

# %%
makaan10=pd.DataFrame(results10)
m10=m9.append(makaan10)
m10.head()
# Out:
#                      Title              Location  Area         Status  \
# 0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925  Ready to move
# 1          1 BHK Apartment    Khera Khurd, Delhi   450  Ready to move
# 2  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 3  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 4  4 BHK Independent Floor  Paschim Vihar, Delhi  2250  Ready to move
#
#      Price Year Bathroom
# 0   8.5 Cr  NaN      NaN
# 1    9.5 L  NaN      NaN
# 2  2.35 Cr  NaN      NaN
# 3   2.4 Cr  NaN      NaN
# 4  2.35 Cr  NaN      NaN

# %%
url11="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=11"
wanted_list11=["9 BHK Independent House","Uttam Nagar, Delhi","5400","Ready to move","1.49 Cr"]
result11=scraper.build(url11,wanted_list11)
print(result11)

scraper.get_result_similar(url11,grouped=True)
# Out:
# ['2 BHK Independent Floor', '2 BHK Apartment', '3 BHK Independent Floor', '3 BHK Apartment', 'Residential Plot', '4 BHK Independent Floor', '4 BHK Independent Floor in RWA Ashok Vihar Block A', '3 BHK Apartment in Reputed Builder Dwarka House', '2 BHK Apartment in Reputed Builder Dwarka House', '3 BHK Independent House', '1 BHK Apartment', '3 BHK Apartment in Swaraj Homes Pocket L Sarita Vihar RWA', '9 BHK Independent House', 'Sector 19 Dwarka, Delhi', 'Shahabad Mohammadpur, Delhi', 'Gujranwala Town, Delhi', 'Dilshad Garden, Delhi', 'Janakpuri, Delhi', 'Patparganj, Delhi', 'vikaspuri, Delhi', 'Najafgarh, Delhi', 'Babarpur, Delhi', 'Ashok Vihar, Delhi', 'Shahdara, Delhi', 'West End, Delhi', 'Anand Niketan, Delhi', 'Sector 8 Dwarka, Delhi', 'Karawal Nagar, Delhi', 'Jamia Nagar, Delhi', 'Sarita Vihar, Delhi', 'Uttam Nagar, Delhi', '750', '1502', '1119', '1460', '1650', '1250', '1496', '1800', '2700', '760', '1900', '1500', '850', '500', '5400', 'Ready to move', 'Resale', 'Under Construc
# ...

# %%
scraper.set_rule_aliases({'rule_keum':'Title','rule_gyto':'Location','rule_iobm':'Area','rule_rdtv':'Status','rule_fjb7':'Price'})
scraper.keep_rules(['rule_keum', 'rule_gyto','rule_rdtv','rule_fjb7'])
scraper.save('makaan-search')
results11=scraper.get_result_similar(url11,group_by_alias=True)
results11
# Out:
# {'Title': ['2 BHK Independent Floor',
#   '2 BHK Apartment',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Apartment',
#   '3 BHK Independent Floor',
#   'Residential Plot',
#   '4 BHK Independent Floor',
#   '4 BHK Independent Floor in RWA Ashok Vihar Block A',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Apartment in Reputed Builder Dwarka House',
#   '2 BHK Apartment in Reputed Builder Dwarka House',
#   '3 BHK Independent House',
#   '1 BHK Apartment',
#   '3 BHK Apartment in Swaraj Homes Pocket L Sarita Vihar RWA',
#   '9 BHK Independent House',
#   '9 BHK Independent House'],
#  'Location': ['Sector 19 Dwarka, Delhi',
#   'Shahabad Mohammadpur, Delhi',
#   'Gujranwala Town, Delhi',
#   'Dilshad Garden, Delhi',
#   'Janakpuri, Delhi',
#   'Patparganj, Delhi',
#   'vikaspuri, Delhi',
#   'Najafgarh, Delhi',
#   'Babarpur, Delhi',
#   'Ashok Vihar, Delhi',
# ...

# %%
makaan11=pd.DataFrame(results11)
m11=m10.append(makaan11)
m11.head()
# Out:
#                      Title              Location  Area         Status  \
# 0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925  Ready to move
# 1          1 BHK Apartment    Khera Khurd, Delhi   450  Ready to move
# 2  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 3  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 4  4 BHK Independent Floor  Paschim Vihar, Delhi  2250  Ready to move
#
#      Price Year Bathroom
# 0   8.5 Cr  NaN      NaN
# 1    9.5 L  NaN      NaN
# 2  2.35 Cr  NaN      NaN
# 3   2.4 Cr  NaN      NaN
# 4  2.35 Cr  NaN      NaN

# %%
m11.shape
# Out:
# (200, 7)

# %%
m11.dtypes
# Out:
# Title       object
# Location    object
# Area        object
# Status      object
# Price       object
# Year        object
# Bathroom    object
# dtype: object

# %%
m11.to_csv("WebScraped_MakaanData.csv")

# %%
url12="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=12"
wanted_list12=["4 BHK Independent Floor","Greater kailash 1, Delhi","2700","Ready to move","5 Bathrooms","5.5 Cr"]
result12=scraper.build(url12,wanted_list12)
print(result12)

scraper.get_result_similar(url12,grouped=True)
# Out:
# ['9 BHK Independent House', '5 BHK Independent House', '4 BHK Independent House', '1 BHK Independent Floor', '3 BHK Independent Floor', '4 BHK Independent Floor', '1 BHK Apartment', '3 BHK Apartment', '2 BHK Independent Floor', '7 BHK Independent House in Greater Kailash Executive Floor', '5400', '2500', '500', '750', '2700', '504', '1500', '450', '720', '1050', '1200', '1700', '4500', 'Ready to move', 'Under Construction', '1.49 Cr', '1.38 Cr', '52 L', '41 L', '32 L', '5.5 Cr', '1 Cr', '30 L', '2.05 Cr', '16.5 L', '42 L', '1.5 Cr', '3.1 Cr', '22 Cr']
# {'rule_13y4': ['9 BHK Independent House',
#   '9 BHK Independent House',
#   '9 BHK Independent House',
#   '9 BHK Independent House',
#   '9 BHK Independent House',
#   '9 BHK Independent House',
#   '5 BHK Independent House',
#   '4 BHK Independent House',
#   '1 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '4 BHK Independent House',
#   '1 BHK Apartment',
#   '3 BHK Apartment',
# ...

# %%
scraper.set_rule_aliases({'rule_13y4':'Title','rule_qxld':'Area','rule_i8pw':'Status','rule_54z7':'Price'})
scraper.keep_rules(['rule_13y4', 'rule_qxld','rule_i8pw','rule_m04k','rule_54z7'])
scraper.save('makaan-search')
results12=scraper.get_result_similar(url12,group_by_alias=True)
results12
# Out:
# {'Title': ['9 BHK Independent House',
#   '9 BHK Independent House',
#   '9 BHK Independent House',
#   '9 BHK Independent House',
#   '9 BHK Independent House',
#   '9 BHK Independent House',
#   '5 BHK Independent House',
#   '4 BHK Independent House',
#   '1 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '4 BHK Independent House',
#   '1 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Independent Floor',
#   '7 BHK Independent House in Greater Kailash Executive Floor'],
#  'Area': ['5400',
#   '5400',
#   '5400',
#   '5400',
#   '5400',
#   '5400',
#   '5400',
#   '2500',
#   '500',
#   '750',
#   '2700',
#   '2500',
#   '504',
#   '1500',
#   '450',
#   '720',
#   '1050',
#   '1200',
#   '1700',
#   '4500'],
#  'Status': ['Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
# ...

# %%
makaan12=pd.DataFrame(results12)
m12=m11.append(makaan12)
m12.head()
# Out:
#                      Title              Location  Area         Status  \
# 0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925  Ready to move
# 1          1 BHK Apartment    Khera Khurd, Delhi   450  Ready to move
# 2  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 3  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 4  4 BHK Independent Floor  Paschim Vihar, Delhi  2250  Ready to move
#
#      Price Year Bathroom
# 0   8.5 Cr  NaN      NaN
# 1    9.5 L  NaN      NaN
# 2  2.35 Cr  NaN      NaN
# 3   2.4 Cr  NaN      NaN
# 4  2.35 Cr  NaN      NaN

# %%
url13="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=14"
wanted_list13=["3 BHK Apartment","Sukhdev Vihar, Delhi","2100","Ready to move","3 Bathrooms","3 Cr"]
result13=scraper.build(url13,wanted_list13)
print(result13)

scraper.get_result_similar(url13,grouped=True)
# Out:
# ['3 BHK Apartment', '7 BHK Independent House', '3 BHK Independent Floor', '2 BHK Independent Floor', '3 BHK Apartment in Swaraj Homes Sector 7 Jasola Vihar RWA', '3 BHK Independent Floor in Reputed Builder h block', 'Sukhdev Vihar, Delhi', 'Sangam Vihar, Delhi', 'Swaraj Homes Sector 7 Jasola Vihar RWA,Jasola, Delhi', 'Reputed Builder h block,vikaspuri, Delhi', 'vikaspuri, Delhi', 'Mahavir Enclave, Delhi', 'Jasola, Delhi', '2100', '2500', '1800', '1250', '1000', '545', 'Ready to move', 'Resale', '3 Bathrooms', '2 Bathrooms', '4 Bathrooms', '2 - 3 years old', '6 years old', '1 Bathrooms', '3 Cr', '55 L', '2.3 Cr', '1.45 Cr', '83.5 L', '23 L', '1.4 Cr']
# {'rule_2r9y': ['3 BHK Apartment',
#   '7 BHK Independent House',
#   '7 BHK Independent House',
#   '7 BHK Independent House',
#   '3 BHK Apartment',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
# ...

# %%
scraper.set_rule_aliases({'rule_2r9y':'Title','rule_xd65':'Location','rule_5471':'Area','rule_cbrl':'Status','rule_p9ii':'Bathroom','rule_a8gz':'Price'})
scraper.keep_rules(['rule_2r9y', 'rule_xd65','rule_5471','rule_cbrl','rule_p9ii','rule_a8gz'])
scraper.save('makaan-search')
results13=scraper.get_result_similar(url13,group_by_alias=True)
results13
# Out:
# {'Title': ['3 BHK Apartment',
#   '7 BHK Independent House',
#   '7 BHK Independent House',
#   '7 BHK Independent House',
#   '3 BHK Apartment',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor'],
#  'Location': ['Sukhdev Vihar, Delhi',
#   'Sangam Vihar, Delhi',
#   'Sangam Vihar, Delhi',
#   'Sangam Vihar, Delhi',
#   'Jasola, Delhi',
#   'vikaspuri, Delhi',
#   'vikaspuri, Delhi',
#   'Mahavir Enclave, Delhi',
#   'vikaspuri, Delhi',
#   'vikaspuri, Delhi',
#   'vikaspuri, Delhi',
#   'vikaspuri, Delhi',
#   'vikaspuri, Delhi',
#   'vikaspuri, Delhi',
# ...

# %%
makaan13=pd.DataFrame(results13)
m13=m11.append(makaan13)
m13.head()
# Out:
#                      Title              Location  Area         Status  \
# 0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925  Ready to move
# 1          1 BHK Apartment    Khera Khurd, Delhi   450  Ready to move
# 2  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 3  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 4  4 BHK Independent Floor  Paschim Vihar, Delhi  2250  Ready to move
#
#      Price Year Bathroom
# 0   8.5 Cr  NaN      NaN
# 1    9.5 L  NaN      NaN
# 2  2.35 Cr  NaN      NaN
# 3   2.4 Cr  NaN      NaN
# 4  2.35 Cr  NaN      NaN

# %%
m13.to_csv("WebScraped_MakaanData.csv")

# %%
m13.duplicated().sum()
# Out:
# 18

# %%
url14="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=16"
wanted_list14=["3 BHK Independent Floor","Naraina, Delhi","1800","Ready to move","2 Bathrooms","2.5 Cr"]
result14=scraper.build(url14,wanted_list14)
print(result14)

scraper.get_result_similar(url4,grouped=True)
# Out:
# ['3 BHK Independent Floor', '2 BHK Apartment in Reputed Builder Arjun Appartment', '3 BHK Apartment in CGHS Dakshinayan Apartments', '2 BHK Apartment in Reputed Builder Archana Apartment', '2 BHK Independent Floor', '1 BHK Independent Floor', '4 BHK Independent Floor in DDA C8 Vasant Kunj', 'Naraina, Delhi', 'Uttam Nagar, Delhi', 'Reputed Builder Arjun Appartment,vikaspuri, Delhi', 'Dwarka Sector 15, Delhi', 'Sector 23 Rohini, Delhi', 'CGHS Dakshinayan Apartments,Sector 4 Dwarka, Delhi', 'Bindapur, Delhi', 'Dwarka Mor, Delhi', 'vikaspuri, Delhi', 'Sector 4 Dwarka, Delhi', 'Mansa Ram Park, Delhi', 'Paschim Vihar, Delhi', 'Sector 22 Rohini, Delhi', 'Bali Nagar, Delhi', 'Sector 7 Dwarka, Delhi', 'Sector 1 Rohini, Delhi', 'West Sagarpur, Delhi', 'Hastsal, Delhi', 'Vasant Kunj, Delhi', 'Model Town, Delhi', '1800', '1000', '1150', '900', '810', '1275', '1100', '700', '600', '2200', '450', '500', '757', '1200', '445', 'Ready to move', 'Under Construction', 'Resale', '2 Bathrooms', '1 Bathro
# ...

# %%
scraper.set_rule_aliases({'rule_dhft':'Title','rule_wuua':'Area','rule_o4lz':'Status','rule_8l6a':'Bathroom','rule_cwiw':'Price'})
scraper.keep_rules(['rule_dhft','rule_wuua','rule_o4lz','rule_8l6a','rule_cwiw'])
scraper.save('makaan-search')
results14=scraper.get_result_similar(url14,group_by_alias=True)
results14
# Out:
# {'Title': ['1 BHK Independent Floor',
#   '2 BHK Apartment in Reputed Builder East End Apartment',
#   '1 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Apartment in Reputed Builder Arjun Appartment',
#   '2 BHK Independent Floor',
#   '10 BHK Independent House',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor in  Defence Colony',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Apartment in DLF Capital Greens Phase 3',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Apartment in CGHS Dakshinayan Apartments',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor'],
#  'Area': ['445',
#   '1000',
#   '500',
#   '1800',
#   '1150',
#   '545',
#   '4500',
#   '450',
#   '2700',
#   '1000',
#   '757',
#   '1000',
#   '3265',
#   '720',
#   '810',
#   '1275',
#   '1100',
#   '1100',
#   '1100',
#   '1250'],
# ...

# %%
makaan14=pd.DataFrame(results14)
m14=m13.append(makaan14)
m14.head()
# Out:
#                      Title              Location  Area         Status  \
# 0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925  Ready to move
# 1          1 BHK Apartment    Khera Khurd, Delhi   450  Ready to move
# 2  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 3  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 4  4 BHK Independent Floor  Paschim Vihar, Delhi  2250  Ready to move
#
#      Price Year Bathroom
# 0   8.5 Cr  NaN      NaN
# 1    9.5 L  NaN      NaN
# 2  2.35 Cr  NaN      NaN
# 3   2.4 Cr  NaN      NaN
# 4  2.35 Cr  NaN      NaN

# %%
m14.duplicated().sum()
# Out:
# 20

# %%
url15="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=17"
wanted_list15=["2 BHK Apartment","New Ashok Nagar, Delhi","1000","Ready to move","98 L"]
result15=scraper.build(url15,wanted_list15)
print(result15)

scraper.get_result_similar(url15,grouped=True)
# Out:
# ['2 BHK Apartment in Reputed Builder East End Apartment', '3 BHK Independent Floor', '10 BHK Independent House', '4 BHK Apartment in DLF Capital Greens Phase 3', '4 BHK Independent Floor', '3 BHK Apartment in Vikram Vihar Residents Association', '2 BHK Independent Floor', '3 BHK Independent Floor in Reputed Builder h block', '3 BHK Apartment', 'Residential Plot', '2 BHK Apartment in CGHS Philips Towers', '1 BHK Apartment', '2 BHK Apartment', '4 BHK Apartment', 'New Ashok Nagar, Delhi', 'Surajmal Vihar, Delhi', 'Karol Bagh, Delhi', 'Sagar Pur, Delhi', 'Karampura, Delhi', 'Greater Kailash, Delhi', 'Lajpat Nagar, Delhi', 'Dwarka Mor, Delhi', 'Punjabi Bagh, Delhi', 'vikaspuri, Delhi', 'Uttam Nagar, Delhi', 'Palam, Delhi', 'Sector 23 Dwarka, Delhi', 'Manglapuri, Delhi', 'Najafgarh, Delhi', 'Neeti Bagh, Delhi', 'Sector 14 Dwarka, Delhi', '1000', '1782', '4500', '720', '3265', '2018', '1170', '828', '1250', '1252', '810', '1800', '900', '455', '2925', '1550', '550', '500', 'Ready to move', 
# ...

# %%
scraper.set_rule_aliases({'rule_natk':'Title','rule_3q2v':'Location','rule_7hf9':'Area','rule_9zp2':'Status','rule_4l1p':'Price'})
scraper.keep_rules(['rule_natk', 'rule_3q2v','rule_7hf9','rule_9zp2','rule_4l1p'])
scraper.save('makaan-search')
results15=scraper.get_result_similar(url5,group_by_alias=True)
results15
# Out:
# {'Title': ['2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Apartment',
#   'Residential Plot',
#   'Residential Plot',
#   'Residential Plot',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '1 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '1 BHK Apartment',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '1 BHK Independent Floor',
#   '2 BHK Apartment in Partap Builder Floors',
#   '3 BHK Independent House'],
#  'Location': ['Mahavir Enclave, Delhi',
#   'Mahavir Enclave, Delhi',
#   'Jamia Nagar, Delhi',
#   'Karol Bagh, Delhi',
#   'Najafgarh, Delhi',
#   'Najafgarh, Delhi',
#   'vikaspuri, Delhi',
#   'vikaspuri, Delhi',
#   'Sector-7 Rohini, Delhi',
#   'vikaspuri, Delhi',
#   'vikaspuri, Delhi',
#   'Punjabi Bagh, Delhi',
#   'Sector 1 Dwarka, Delhi',
#   'Sector 14 Dwarka, Delhi',
# ...

# %%
makaan15=pd.DataFrame(results15)
m15=m14.append(makaan15)
m15.head()
# Out:
#                      Title              Location  Area         Status  \
# 0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925  Ready to move
# 1          1 BHK Apartment    Khera Khurd, Delhi   450  Ready to move
# 2  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 3  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 4  4 BHK Independent Floor  Paschim Vihar, Delhi  2250  Ready to move
#
#      Price Year Bathroom
# 0   8.5 Cr  NaN      NaN
# 1    9.5 L  NaN      NaN
# 2  2.35 Cr  NaN      NaN
# 3   2.4 Cr  NaN      NaN
# 4  2.35 Cr  NaN      NaN

# %%
url16="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=18"
wanted_list16=["4 BHK Independent Floor","Greater kailash 1, Delhi","2100","Ready to move","5 Bathrooms","5.5 Cr"]
result16=scraper.build(url16,wanted_list16)
print(result16)

scraper.get_result_similar(url16,grouped=True)
# Out:
# ['4 BHK Independent Floor', '2 BHK Apartment', '1 BHK Apartment', '1 BHK Independent Floor', '3 BHK Independent Floor', '1 RK Studio Apartment', '2 BHK Independent Floor', '2 BHK Independent House', '3 BHK Apartment in DDA Rohini Heights', 'Greater kailash 1, Delhi', 'Dwarka Mor, Delhi', 'Uttam Nagar, Delhi', 'New Ashok Nagar, Delhi', 'Hastsal, Delhi', 'Shalimar Bagh, Delhi', 'New Friends Colony, Delhi', 'Pitampura, Delhi', 'Sector-29 Rohini, Delhi', 'Sector 28 Rohini, Delhi', 'Sector 11 Rohini, Delhi', '2100', '585', '405', '360', '990', '300', '550', '700', '450', '1350', '1650', '850', 'Ready to move', '5 Bathrooms', '5 - 6 years old', '1 Bathrooms', '2 Bathrooms', '6 - 7 years old', '3 Bathrooms', '7 - 8 years old', '4 - 5 years old', '5.5 Cr', '29 L', '19.8 L', '29.5 L', '13.8 L', '27 L', '30 L', '7.5 L', '19.5 L', '20 L', '75 L', '24 L', '14 L', '2.8 Cr', '21 L', '1.75 Cr', '1.05 Cr']
# {'rule_u5ht': ['4 BHK Independent Floor',
#   '3 BHK Apartment',
# ...

# %%
scraper.set_rule_aliases({'rule_u5ht':'Title','rule_1xei':'Area','rule_deas':'Status','rule_ofb0':'Price'})
scraper.keep_rules(['rule_u5ht','rule_1xei','rule_deas','rule_ofb0'])
scraper.save('makaan-search')
results16=scraper.get_result_similar(url6,group_by_alias=True)
results16
# Out:
# {'Title': ['2 BHK Independent Floor',
#   '5 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Apartment in Reputed Builder Bagwan Apartment',
#   '2 BHK Independent Floor',
#   '1 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Apartment',
#   '3 BHK Apartment in  Tarun Vihar Apartments',
#   '3 BHK Apartment in  Tarun Vihar Apartments',
#   '1 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Apartment in Reputed Builder Vikas Sheel Apartments',
#   '2 BHK Independent Floor',
#   '2 BHK Apartment',
#   '2 BHK Independent Floor',
#   'Residential Plot'],
#  'Area': ['850',
#   '1980',
#   '1350',
#   '700',
#   '900',
#   '360',
#   '1000',
#   '800',
#   '675',
#   '1200',
#   '1150',
#   '490',
#   '585',
#   '650',
#   '1000',
#   '1650',
#   '900',
#   '500',
#   '800',
#   '900'],
#  'Status': ['Ready to move',
#   'Ready to move',
# ...

# %%
makaan16=pd.DataFrame(results16)
m16=m15.append(makaan16)
m16.head()
# Out:
#                      Title              Location  Area         Status  \
# 0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925  Ready to move
# 1          1 BHK Apartment    Khera Khurd, Delhi   450  Ready to move
# 2  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 3  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 4  4 BHK Independent Floor  Paschim Vihar, Delhi  2250  Ready to move
#
#      Price Year Bathroom
# 0   8.5 Cr  NaN      NaN
# 1    9.5 L  NaN      NaN
# 2  2.35 Cr  NaN      NaN
# 3   2.4 Cr  NaN      NaN
# 4  2.35 Cr  NaN      NaN

# %%
url17="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=19"
wanted_list17=["2 BHK Apartment","Dwarka Mor, Delhi","585","Ready to move","29 L"]
result17=scraper.build(url17,wanted_list17)
print(result17)

scraper.get_result_similar(url17,grouped=True)
# Out:
# ['2 BHK Apartment', '1 BHK Apartment', '1 RK Studio Apartment', '1 BHK Independent Floor', '3 BHK Apartment in DDA Rohini Heights', '3 BHK Independent Floor', '2 BHK Independent Floor', '6 BHK Independent House', 'Dwarka Mor, Delhi', 'New Ashok Nagar, Delhi', 'Hastsal, Delhi', 'Uttam Nagar, Delhi', 'Sector-29 Rohini, Delhi', 'DDA Rohini Heights,Sector 28 Rohini, Delhi', 'Sector 28 Rohini, Delhi', 'Sector 11 Rohini, Delhi', 'Green Park, Delhi', 'Hauz Khas, Delhi', 'DLF Farms, Delhi', 'vikaspuri, Delhi', '585', '405', '300', '360', '450', '1650', '850', '550', '1350', '9000', '1225', 'Ready to move', '29 L', '19.5 L', '7.5 L', '30 L', '29.5 L', '13.8 L', '21 L', '1.75 Cr', '1.05 Cr', '20 L', '1.8 Cr', '2.25 Cr', '75 Cr', '1.4 Cr', '18.5 L']
# {'rule_laby': ['2 BHK Apartment',
#   '1 BHK Apartment',
#   '1 RK Studio Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '1 BHK Independent Floor',
#   '1 BHK Independent Floor',
#   '1 BHK Apartment',
# ...

# %%
scraper.set_rule_aliases({'rule_laby':'Title','rule_4peq':'Area','rule_4aqh':'Status','rule_c8x0':'Price'})
scraper.keep_rules(['rule_laby','rule_4peq','rule_4aqh','rule_c8x0'])
scraper.save('makaan-search')
results17=scraper.get_result_similar(url17,group_by_alias=True)
results17
# Out:
# {'Title': ['2 BHK Apartment',
#   '4 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent House in Reputed Builder Vijay Vihar',
#   '2 BHK Apartment in Reputed Builder Azad Apartments',
#   '6 BHK Independent House',
#   '3 BHK Independent Floor',
#   '2 BHK Apartment',
#   '3 BHK Apartment in Sai Homes',
#   '1 BHK Apartment',
#   '2 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor'],
#  'Area': ['585',
#   '1400',
#   '700',
#   '1250',
#   '540',
#   '1250',
#   '9000',
#   '1225',
#   '500',
#   '950',
#   '450',
#   '600',
#   '900',
#   '570',
#   '770',
#   '510',
#   '600',
#   '1350',
#   '1350',
#   '1750'],
#  'Status': ['Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
# ...

# %%
makaan17=pd.DataFrame(results17)
m17=m16.append(makaan17)
m17.head()
# Out:
#                      Title              Location  Area         Status  \
# 0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925  Ready to move
# 1          1 BHK Apartment    Khera Khurd, Delhi   450  Ready to move
# 2  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 3  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 4  4 BHK Independent Floor  Paschim Vihar, Delhi  2250  Ready to move
#
#      Price Year Bathroom
# 0   8.5 Cr  NaN      NaN
# 1    9.5 L  NaN      NaN
# 2  2.35 Cr  NaN      NaN
# 3   2.4 Cr  NaN      NaN
# 4  2.35 Cr  NaN      NaN

# %%
m17.shape
# Out:
# (300, 7)

# %%
url20="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=21"
wanted_list20=["3 BHK Independent Floor","Pitampura, Delhi","1620","Ready to move","3 Bathrooms","2.8 Cr"]
result20=scraper.build(url20,wanted_list20)
print(result20)

scraper.get_result_similar(url20,grouped=True)
# Out:
# ['3 BHK Independent Floor', '2 BHK Apartment', '2 BHK Independent Floor', '4 BHK Independent Floor', '3 BHK Apartment', '3 BHK Apartment in Chanchal Homes 2', '2 BHK Apartment in Chanchal Homes 2', 'Pitampura, Delhi', 'Kalu Sarai, Delhi', 'laxmi nagar, Delhi', 'Lajpat Nagar, Delhi', 'Mayur Vihar II, Delhi', 'Sector 3 Rohini, Delhi', 'Greater kailash 1, Delhi', 'Green Park, Delhi', 'DLF Phase 5, Delhi', 'Dwarka Mor, Delhi', '1620', '1728', '1350', '1100', '700', '3120', '900', '1800', '850', '1250', '1500', '3600', '2850', '1050', '660', '775', 'Ready to move', 'Under Construction', '3 Bathrooms', '2 Bathrooms', '6 years old', '5 - 6 years old', '3 years old', '4 - 5 years old', '5 Bathrooms', '4 Bathrooms', '0 - 1 year old', '2.8 Cr', '3.5 Cr', '3.35 Cr', '2.5 Cr', '1.55 Cr', '40 L', '4.5 Cr', '1.5 Cr', '2.75 Cr', '2.65 Cr', '82 L', '90 L', '2 Cr', '8.25 Cr', '3.6 Cr', '1.7 Cr', '59.99 L', '27.99 L', '34.99 L']
# {'rule_inp4': ['3 BHK Independent Floor',
# ...

# %%
scraper.set_rule_aliases({'rule_inp4':'Title','rule_hbq3':'Area','rule_qq9f':'Status','rule_my5s':'Bathroom','rule_z4fx':'Price'})
scraper.keep_rules(['rule_inp4','rule_hbq3','rule_qq9f','rule_my5s','rule_z4fx'])
scraper.save('makaan-search')
results20=scraper.get_result_similar(url20,group_by_alias=True)
results20
# Out:
# {'Title': ['3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Apartment',
#   '2 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Apartment',
#   '3 BHK Apartment in Chanchal Homes 2',
#   '2 BHK Apartment in Chanchal Homes 2',
#   '3 BHK Apartment in Chanchal Homes 2'],
#  'Area': ['1620',
#   '1620',
#   '1728',
#   '1350',
#   '1100',
#   '700',
#   '3120',
#   '900',
#   '1800',
#   '1800',
#   '850',
#   '900',
#   '1250',
#   '1500',
#   '3600',
#   '1800',
#   '2850',
#   '1050',
#   '660',
#   '775'],
#  'Status': ['Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Under Construction',
#   'Ready to move',
# ...

# %%
makaan20=pd.DataFrame(results20)
m20=m17.append(makaan20)
m20.head()
# Out:
#                      Title              Location  Area         Status  \
# 0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925  Ready to move
# 1          1 BHK Apartment    Khera Khurd, Delhi   450  Ready to move
# 2  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 3  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 4  4 BHK Independent Floor  Paschim Vihar, Delhi  2250  Ready to move
#
#      Price Year Bathroom
# 0   8.5 Cr  NaN      NaN
# 1    9.5 L  NaN      NaN
# 2  2.35 Cr  NaN      NaN
# 3   2.4 Cr  NaN      NaN
# 4  2.35 Cr  NaN      NaN

# %%
m20.shape
# Out:
# (320, 7)

# %%
url21="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=25"
wanted_list21=["3 BHK Apartment","Sector 12 Dwarka, Delhi","1650","Ready to move","1.8 Cr"]
result21=scraper.build(url6,wanted_list21)
print(result21)

scraper.get_result_similar(url21,grouped=True)
# Out:
# ['2 BHK Independent Floor', '5 BHK Independent Floor', '3 BHK Independent Floor', '2 BHK Apartment', '1 BHK Independent Floor', '3 BHK Apartment', 'Residential Plot', '850', '900', '1980', '1350', '700', '360', '1000', '800', '675', '1200', '1150', '490', '585', '650', '1650', '500', 'Ready to move', 'Under Construction', 'Resale', '45.99 L', '74.99 L', '1.25 Cr', '1 Cr', '7 L', '16.9 L', '1.1 Cr', '39 L', '23 L', '1.8 Cr', '32 L', '34.5 L', '48 L', '1.9 Cr', '36.45 L', '38.5 L', '33 L', '18 L']
# {'rule_walm': ['3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Independent Floor',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '1 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Independent Floor',
# ...

# %%
scraper.set_rule_aliases({'rule_walm':'Title','rule_ce5d':'Area','rule_v4sm':'Status','rule_56mc':'Price'})
scraper.keep_rules(['rule_walm', 'rule_ce5d','rule_v4sm','rule_56mc'])
scraper.save('makaan-search')
results21=scraper.get_result_similar(url21,group_by_alias=True)
results21
# Out:
# {'Title': ['3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Independent Floor',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '1 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor'],
#  'Area': ['1650',
#   '1700',
#   '1450',
#   '1100',
#   '1400',
#   '900',
#   '5236',
#   '5236',
#   '5236',
#   '3740',
#   '3740',
#   '3740',
#   '3740',
#   '548',
#   '1850',
#   '2650',
#   '1650',
#   '2200',
#   '1050',
#   '950'],
#  'Status': ['Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Under Construction',
#   'Under Construction',
#   'Under Construction',
#   'Under Construction',
# ...

# %%
makaan21=pd.DataFrame(results21)
m21=m20.append(makaan21)
m21.head()
# Out:
#                      Title              Location  Area         Status  \
# 0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925  Ready to move
# 1          1 BHK Apartment    Khera Khurd, Delhi   450  Ready to move
# 2  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 3  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 4  4 BHK Independent Floor  Paschim Vihar, Delhi  2250  Ready to move
#
#      Price Year Bathroom
# 0   8.5 Cr  NaN      NaN
# 1    9.5 L  NaN      NaN
# 2  2.35 Cr  NaN      NaN
# 3   2.4 Cr  NaN      NaN
# 4  2.35 Cr  NaN      NaN

# %%
m21.shape
# Out:
# (340, 7)

# %%
m21.to_csv("WebScraped_MakaanData1.csv")

# %%
url22="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=26"
wanted_list22=["2 BHK Apartment","Dwarka Mor, Delhi","1450","Under Construction","2 Bathrooms","32.5 L"]
result22=scraper.build(url22,wanted_list22)
print(result22)

scraper.get_result_similar(url22,grouped=True)
# Out:
# ['2 BHK Apartment in Goyal Sachin Goyal Affordable Homes', '2 BHK Apartment in PK Affordable Homes', '3 BHK Apartment in Kushwaha Smart Homes', '1 BHK Independent Floor in ARE Uttam Nagar Floors', '3 BHK Apartment in Planner N Maker Uttam Nagar Residency', '2 BHK Independent Floor', '1 BHK Independent Floor', '5 BHK Apartment in Unity The Amaryllis', '4 BHK Apartment in Unity The Amaryllis', '3 BHK Apartment in AKY Dream Project', '2 BHK Apartment in AKY Dream Project', '3 BHK Apartment in AKY Affordable Project', '2 BHK Apartment in AKY Affordable Project', '3 BHK Independent Floor', '2 BHK Apartment', '3 BHK Apartment', '5 BHK Apartment', '4 BHK Apartment', 'Dwarka Mor, Delhi', 'Uttam Nagar, Delhi', 'Katwaria Sarai, Delhi', 'Ramesh Nagar, Delhi', 'Palam, Delhi', 'Sector 8 Dwarka, Delhi', 'Karol Bagh, Delhi', 'Sector 7 Dwarka, Delhi', 'Sector 11 Dwarka, Delhi', '1450', '1350', '650', '1850', '900', '400', '5236', '800', '600', '720', '540', '1000', '1200', 'Under Construction', 'Rea
# ...

# %%
scraper.set_rule_aliases({'rule_y2do':'Title','rule_wcev':'Location','rule_gmen':'Area','rule_rnxs':'Status','rule_uuqa':'Bathroom','rule_ary0':'Price'})
scraper.keep_rules(['rule_y2do', 'rule_wcev','rule_gmen','rule_rnxs','rule_uuqa','rule_ary0'])
scraper.save('makaan-search')
results22=scraper.get_result_similar(url22,group_by_alias=True)
results22
# Out:
# {'Title': ['2 BHK Apartment in Goyal Sachin Goyal Affordable Homes',
#   '2 BHK Apartment in PK Affordable Homes',
#   '3 BHK Apartment in Kushwaha Smart Homes',
#   '1 BHK Independent Floor in ARE Uttam Nagar Floors',
#   '3 BHK Apartment in Planner N Maker Uttam Nagar Residency',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '1 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '5 BHK Apartment in Unity The Amaryllis',
#   '4 BHK Apartment in Unity The Amaryllis',
#   '3 BHK Apartment in AKY Dream Project',
#   '2 BHK Apartment in AKY Dream Project',
#   '3 BHK Apartment in AKY Affordable Project',
#   '2 BHK Apartment in AKY Affordable Project',
#   '3 BHK Apartment in AKY Affordable Project',
#   '2 BHK Apartment in AKY Affordable Project',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Apartment'],
#  'Location': ['Dwarka Mor, Delhi',
#   'Uttam Nagar, Delhi',
#   'Uttam Nagar, Delhi',
#   'Uttam Nagar, Delhi',
# ...

# %%
makaan22=pd.DataFrame(results22)
m22=m21.append(makaan22)
m22.head()
# Out:
#                      Title              Location  Area         Status  \
# 0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925  Ready to move
# 1          1 BHK Apartment    Khera Khurd, Delhi   450  Ready to move
# 2  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 3  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 4  4 BHK Independent Floor  Paschim Vihar, Delhi  2250  Ready to move
#
#      Price Year Bathroom
# 0   8.5 Cr  NaN      NaN
# 1    9.5 L  NaN      NaN
# 2  2.35 Cr  NaN      NaN
# 3   2.4 Cr  NaN      NaN
# 4  2.35 Cr  NaN      NaN

# %%
url23="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=27"
wanted_list23=["4 BHK Apartment","Karol Bagh, Delhi","3740","Under Construction","4 Bathrooms","7.25 Cr"]
result23=scraper.build(url23,wanted_list23)
print(result23)

scraper.get_result_similar(url23,grouped=True)
# Out:
# ['4 BHK Apartment', '3 BHK Independent Floor', '3 BHK Apartment', '2 BHK Independent Floor', 'Karol Bagh, Delhi', 'Sector 8 Dwarka, Delhi', 'Chattarpur, Delhi', 'Dwarka Mor, Delhi', 'Patparganj, Delhi', 'Karampura, Delhi', 'Lajpat Nagar II, Delhi', '3740', '2701', '2618', '1890', '3300', '648', '900', '1100', '1686', '1700', '1575', 'Under Construction', 'Ready to move', 'New', '3 Bathrooms', '4 Bathrooms', '2 Bathrooms', 'Resale', '3 years old', 'Possession by Feb 2023', 'Possession by Jan 2023', '6 - 7 years old', '7.25 Cr', '5.65 Cr', '5.4 Cr', '5.15 Cr', '5.5 Cr', '5.3 Cr', '5.05 Cr', '1.66 Cr', '4.95 Cr', '5.78 Cr', '47 L', '62.5 L', '1 Cr', '2.79 Cr', '3.03 Cr', '3.09 Cr', '3.12 Cr', '2.25 Cr']
# {'rule_5kte': ['4 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Independent Floor',
#   '4 BHK Apartment',
# ...

# %%
scraper.set_rule_aliases({'rule_5kte':'Title','rule_clt0':'Location','rule_k1gr':'Area','rule_cghs':'Status','rule_nc4x':'Bathroom','rule_zgwu':'Price'})
scraper.keep_rules(['rule_5kte', 'rule_clt0','rule_k1gr','rule_cghs','rule_nc4x','rule_zgwu'])
scraper.save('makaan-search')
results23=scraper.get_result_similar(url23,group_by_alias=True)
results23
# Out:
# {'Title': ['4 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Independent Floor',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Independent Floor',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment'],
#  'Location': ['Karol Bagh, Delhi',
#   'Karol Bagh, Delhi',
#   'Karol Bagh, Delhi',
#   'Karol Bagh, Delhi',
#   'Karol Bagh, Delhi',
#   'Karol Bagh, Delhi',
#   'Karol Bagh, Delhi',
#   'Karol Bagh, Delhi',
#   'Karol Bagh, Delhi',
#   'Sector 8 Dwarka, Delhi',
#   'Karol Bagh, Delhi',
#   'Chattarpur, Delhi',
#   'Sector 8 Dwarka, Delhi',
#   'Dwarka Mor, Delhi',
#   'Patparganj, Delhi',
#   'Karampura, Delhi',
#   'Karampura, Delhi',
#   'Karampura, Delhi',
#   'Karampura, Delhi',
# ...

# %%
makaan23=pd.DataFrame(results23)
m23=m22.append(makaan23)
m23.head()
# Out:
#                      Title              Location  Area         Status  \
# 0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925  Ready to move
# 1          1 BHK Apartment    Khera Khurd, Delhi   450  Ready to move
# 2  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 3  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 4  4 BHK Independent Floor  Paschim Vihar, Delhi  2250  Ready to move
#
#      Price Year Bathroom
# 0   8.5 Cr  NaN      NaN
# 1    9.5 L  NaN      NaN
# 2  2.35 Cr  NaN      NaN
# 3   2.4 Cr  NaN      NaN
# 4  2.35 Cr  NaN      NaN

# %%
m23.shape
# Out:
# (380, 7)

# %%
m23.duplicated().sum()
# Out:
# 21

# %%
url24="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=32"
wanted_list24=["2 BHK Apartment","Uttam Nagar, Delhi","1350","Ready to move","21 L"]
result24=scraper.build(url24,wanted_list24)
print(result24)

scraper.get_result_similar(url24,grouped=True)
# Out:
# ['2 BHK Apartment', '2 BHK Independent Floor', '3 BHK Apartment', '4 BHK Independent Floor', '3 BHK Independent Floor', '1 BHK Independent House', '4 BHK Apartment', 'Uttam Nagar, Delhi', 'Neb Sarai, Delhi', 'Vasant Kunj, Delhi', 'Shastri Nagar, Delhi', 'Rohini sector 24, Delhi', 'Sector 22 Rohini, Delhi', 'Sector 25 Rohini, Delhi', 'Shahdara, Delhi', 'Sector-18 Dwarka, Delhi', 'Sector 19 Dwarka, Delhi', 'Sector 6 Dwarka, Delhi', 'Sector 5 Dwarka, Delhi', 'Janakpuri, Delhi', 'Anand Vihar, Delhi', '1350', '850', '1700', '500', '3000', '750', '1600', '480', '800', '900', '432', '1000', '1850', '2650', '1650', '2200', 'Ready to move', 'Under Construction', '21 L', '27 L', '3 Cr', '42 L', '3.6 Cr', '54 L', '2.1 Cr', '25.5 L', '48 L', '68 L', '25 L', '75 L', '70 L', '47 L', '2 Cr', '2.5 Cr', '1.3 Cr', '1.9 Cr', '1.15 Cr', '4 Cr']
# {'rule_vq2r': ['4 BHK Independent Floor',
#   '2 BHK Independent House',
#   '2 BHK Independent Floor',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
# ...

# %%
scraper.set_rule_aliases({'rule_vq2r':'Title','rule_fi7u':'Location','rule_cnx5':'Area','rule_rtje':'Status','rule_zdpa':'Price'})
scraper.keep_rules(['rule_vq2r', 'rule_fi7u','rule_cnx5','rule_rtje','rule_zdpa'])
scraper.save('makaan-search')
results24=scraper.get_result_similar(url24,group_by_alias=True)
results24
# Out:
# {'Title': ['2 BHK Apartment',
#   '2 BHK Independent Floor',
#   '3 BHK Apartment',
#   '2 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '1 BHK Independent House',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor'],
#  'Location': ['Uttam Nagar, Delhi',
#   'Neb Sarai, Delhi',
#   'Vasant Kunj, Delhi',
#   'Shastri Nagar, Delhi',
#   'Rohini sector 24, Delhi',
#   'Sector 22 Rohini, Delhi',
#   'Rohini sector 24, Delhi',
#   'Sector 22 Rohini, Delhi',
#   'Rohini sector 24, Delhi',
#   'Rohini sector 24, Delhi',
#   'Sector 22 Rohini, Delhi',
#   'Sector 25 Rohini, Delhi',
#   'Shahdara, Delhi',
#   'Uttam Nagar, Delhi',
# ...

# %%
makaan24=pd.DataFrame(results24)
m24=m23.append(makaan24)
m24.head()
# Out:
#                      Title              Location  Area         Status  \
# 0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925  Ready to move
# 1          1 BHK Apartment    Khera Khurd, Delhi   450  Ready to move
# 2  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 3  3 BHK Independent Floor  Paschim Vihar, Delhi  1620  Ready to move
# 4  4 BHK Independent Floor  Paschim Vihar, Delhi  2250  Ready to move
#
#      Price Year Bathroom
# 0   8.5 Cr  NaN      NaN
# 1    9.5 L  NaN      NaN
# 2  2.35 Cr  NaN      NaN
# 3   2.4 Cr  NaN      NaN
# 4  2.35 Cr  NaN      NaN

# %%
m24.shape
# Out:
# (400, 7)

# %%
m24.to_csv("WebScrapped_MakaanRough.csv")

# %%
df=pd.read_csv("WebScrapped_MakaanRough.csv")
df.head()
# Out:
#    Unnamed: 0                    Title              Location    Area  \
# 0           0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925.0
# 1           1          1 BHK Apartment    Khera Khurd, Delhi   450.0
# 2           2  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0
# 3           3  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0
# 4           4  4 BHK Independent Floor  Paschim Vihar, Delhi  2250.0
#
#           Status    Price Year Bathroom
# 0  Ready to move   8.5 Cr  NaN      NaN
# 1  Ready to move    9.5 L  NaN      NaN
# 2  Ready to move  2.35 Cr  NaN      NaN
# 3  Ready to move   2.4 Cr  NaN      NaN
# 4  Ready to move  2.35 Cr  NaN      NaN

# %%
url25="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=33"
wanted_list25=["3 BHK Independent Floor","Pitampura, Delhi","1728","Ready to move","3 Bathrooms","3.9 Cr"]
result25=scraper.build(url25,wanted_list25)
print(result25)
# Out:
# ['3 BHK Independent Floor', '4 BHK Independent Floor', '3 BHK Independent House', '2 BHK Independent Floor', '3 BHK Apartment in DLF Capital Greens', '3 BHK Apartment', '1 BHK Apartment', '2 BHK Apartment', 'Pitampura, Delhi', 'Govindpuri, Delhi', 'East of Kailash, Delhi', 'DLF Capital Greens,Karampura, Delhi', 'South Extension 1, Delhi', 'Karampura, Delhi', 'Malviya Nagar, Delhi', 'SULTANPUR, Delhi', 'Alaknanda, Delhi', '1728', '2700', '1350', '1730', '600', '1750', '1580', '1800', '1125', '900', '450', '750', '700', '2000', 'Ready to move', '3 Bathrooms', '4 Bathrooms', '2 Bathrooms', '5 - 6 years old', '6 - 7 years old', '4 - 5 years old', '1 Bathrooms', 'Resale', 'New', '3.9 Cr', '6 Cr', '2.5 Cr', '2.4 Cr', '3.8 Cr', '27 L', '3.25 Cr', '2.57 Cr', '3 Cr', '1.45 Cr', '1.25 Cr', '72 L', '17 L', '22.5 L', '16 L', '35 L', '36 L', '21 L', '2.45 Cr']

# %%
scraper.get_result_similar(url25,grouped=True)
# Out:
# {'rule_9mrn': ['3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent House',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Apartment in DLF Capital Greens',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Apartment',
#   '1 BHK Apartment',
#   '1 BHK Apartment',
#   '1 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '1 BHK Apartment',
#   '3 BHK Apartment'],
#  'rule_3cpl': ['3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent House',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Apartment in DLF Capital Greens',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
# ...

# %%
scraper.set_rule_aliases({'rule_9mrn':'Title','rule_md3i':'Area','rule_8cah':'Status','rule_19f2':'Bathroom','rule_qq8h':'Price'})
scraper.keep_rules(['rule_9mrn','rule_md3i','rule_8cah','rule_19f2','rule_qq8h'])
scraper.save('makaan-search')
results25=scraper.get_result_similar(url25,group_by_alias=True)
results25
# Out:
# {'Title': ['3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent House',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Apartment in DLF Capital Greens',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Apartment',
#   '1 BHK Apartment',
#   '1 BHK Apartment',
#   '1 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '1 BHK Apartment',
#   '3 BHK Apartment'],
#  'Area': ['1728',
#   '2700',
#   '1350',
#   '1350',
#   '1350',
#   '1730',
#   '600',
#   '1750',
#   '1580',
#   '1800',
#   '1125',
#   '900',
#   '1350',
#   '450',
#   '450',
#   '450',
#   '750',
#   '700',
#   '450',
#   '2000'],
#  'Status': ['Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
# ...

# %%
makaan25=pd.DataFrame(results25)
m25=df.append(makaan25)
m25.head()
# Out:
#    Unnamed: 0                    Title              Location    Area  \
# 0         0.0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925.0
# 1         1.0          1 BHK Apartment    Khera Khurd, Delhi   450.0
# 2         2.0  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0
# 3         3.0  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0
# 4         4.0  4 BHK Independent Floor  Paschim Vihar, Delhi  2250.0
#
#           Status    Price Year Bathroom
# 0  Ready to move   8.5 Cr  NaN      NaN
# 1  Ready to move    9.5 L  NaN      NaN
# 2  Ready to move  2.35 Cr  NaN      NaN
# 3  Ready to move   2.4 Cr  NaN      NaN
# 4  Ready to move  2.35 Cr  NaN      NaN

# %%
m25.shape
# Out:
# (420, 8)

# %%
url26="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=34"
wanted_list26=["2 BHK Independent Floor","Malviya Nagar, Delhi","1125","Ready to move","1.5 Cr"]
result26=scraper.build(url26,wanted_list26)
print(result26)

scraper.get_result_similar(url26,grouped=True)
# Out:
# ['3 BHK Independent Floor', '2 BHK Independent Floor', '2 BHK Apartment', '1 BHK Apartment', '4 BHK Independent Floor', 'Malviya Nagar, Delhi', 'Defence Colony, Delhi', 'SULTANPUR, Delhi', 'Dwarka Sector 15, Delhi', 'Pitampura, Delhi', '1125', '900', '2925', '650', '450', '675', '585', '1683', '1854', '902', '1198', '2500', '2700', '1575', '1350', '903', '1665', '1194', '904', '2160', 'Ready to move', 'Under Construction', '1.5 Cr', '1.38 Cr', '19 Cr', '38 L', '20 L', '95 L', '26 L', '3.5 Cr', '3.6 Cr', '1.35 Cr', '2.35 Cr', '4 Cr', '5 Cr', '3.1 Cr', '2.25 Cr', '1.45 Cr', '3 Cr', '2 Cr', '1.55 Cr', '3.4 Cr']
# {'rule_fpsx': ['3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Apartment',
#   '1 BHK Apartment',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
# ...

# %%
scraper.set_rule_aliases({'rule_fpsx':'Title','rule_lint':'Area','rule_rq5p':'Status','rule_7t87':'Price'})
scraper.keep_rules(['rule_fpsx','rule_lint','rule_rq5p','rule_7t87'])
scraper.save('makaan-search')
results26=scraper.get_result_similar(url26,group_by_alias=True)
results26
# Out:
# {'Title': ['3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Apartment',
#   '1 BHK Apartment',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor'],
#  'Area': ['1125',
#   '900',
#   '2925',
#   '650',
#   '450',
#   '675',
#   '585',
#   '1683',
#   '1854',
#   '902',
#   '1198',
#   '2500',
#   '2700',
#   '1575',
#   '1350',
#   '903',
#   '1665',
#   '1194',
#   '904',
#   '2160'],
#  'Status': ['Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
# ...

# %%
makaan26=pd.DataFrame(results26)
m26=m25.append(makaan26)
m26.head()
# Out:
#    Unnamed: 0                    Title              Location    Area  \
# 0         0.0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925.0
# 1         1.0          1 BHK Apartment    Khera Khurd, Delhi   450.0
# 2         2.0  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0
# 3         3.0  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0
# 4         4.0  4 BHK Independent Floor  Paschim Vihar, Delhi  2250.0
#
#           Status    Price Year Bathroom
# 0  Ready to move   8.5 Cr  NaN      NaN
# 1  Ready to move    9.5 L  NaN      NaN
# 2  Ready to move  2.35 Cr  NaN      NaN
# 3  Ready to move   2.4 Cr  NaN      NaN
# 4  Ready to move  2.35 Cr  NaN      NaN

# %%
m26.shape
# Out:
# (440, 8)

# %%
url27="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=39"
wanted_list27=["2 BHK Apartment","SULTANPUR, Delhi","750","Ready to move","30.5 L"]
result27=scraper.build(url27,wanted_list27)
print(result27)

scraper.get_result_similar(url27,grouped=True)
# Out:
# ['2 BHK Apartment', '3 BHK Apartment', '3 BHK Independent Floor', '2 BHK Independent Floor', '1 BHK Independent Floor', '1 BHK Apartment', 'SULTANPUR, Delhi', 'Lajpat Nagar II, Delhi', '750', '1250', '900', '1080', '745', '1125', '1800', '500', '700', '702', '450', 'Ready to move', '30.5 L', '30 L', '75 L', '72 L', '62 L', '31 L', '90 L', '70 L', '42 L', '65 L', '26 L', '3.5 Cr', '23 L', '32 L', '32.5 L', '23.5 L']
# {'rule_6tq1': ['2 BHK Apartment',
#   '2 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Apartment',
#   '3 BHK Independent Floor',
#   '1 BHK Independent Floor',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '1 BHK Apartment'],
#  'rule_77nz': ['2 BHK Apartment',
# ...

# %%
scraper.set_rule_aliases({'rule_6tq1':'Title','rule_771a':'Location','rule_mvrh':'Area','rule_sgg1':'Status','rule_mfmq':'Price'})
scraper.keep_rules(['rule_6tq1','rule_771a','rule_mvrh','rule_sgg1','rule_mfmq'])
scraper.save('makaan-search')
results27=scraper.get_result_similar(url27,group_by_alias=True)
results27
# Out:
# {'Title': ['3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '4 BHK Apartment in Unity The Amaryllis',
#   '4 BHK Apartment in Unity The Amaryllis',
#   '5 BHK Apartment in Unity The Amaryllis',
#   '4 BHK Apartment in Unity The Amaryllis',
#   '4 BHK Apartment in Unity The Amaryllis',
#   '4 BHK Apartment in Unity The Amaryllis',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Apartment',
#   '2 BHK Independent Floor in Reputed Builder Gh14 Paschim Vihar',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '4 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '4 BHK Independent Floor'],
#  'Location': ['Dwarka Sector 15, Delhi',
#   'Raju Parak Extension, Delhi',
#   'Karol Bagh, Delhi',
#   'Karol Bagh, Delhi',
#   'Karol Bagh, Delhi',
#   'Karol Bagh, Delhi',
#   'Karol Bagh, Delhi',
#   'Karol Bagh, Delhi',
#   'Paschim Vihar, Delhi',
# ...

# %%
makaan27=pd.DataFrame(results27)
m27=m26.append(makaan27)
m27.shape
# Out:
# (460, 8)

# %%
url28="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=41"
wanted_list28=["4 BHK Independent Floor","Defence Colony, Delhi","3348","Ready to move","11 Cr"]
result28=scraper.build(url28,wanted_list28)
print(result28)
# Out:
# ['4 BHK Independent Floor', '3 BHK Independent Floor', '2 BHK Independent Floor', '5 BHK Apartment in Unity The Amaryllis', 'Defence Colony, Delhi', 'Sewak Park, Delhi', 'Raju Parak Extension, Delhi', 'Unity The Amaryllis,Karol Bagh, Delhi', 'Tri Nagar, Delhi', 'Shastri Nagar, Delhi', 'Pitampura, Delhi', 'Karol Bagh, Delhi', 'Dwarka Sector 15, Delhi', '3348', '1050', '810', '520', '5402', '900', '2493', '1800', '2699', '901', '1195', '1620', '650', '820', '1100', 'Ready to move', 'Under Construction', '11 Cr', '48 L', '42 L', '27 L', '10 Cr', '45 L', '1.1 Cr', '84 L', '3.75 Cr', '3.25 Cr', '2.9 Cr', '5.5 Cr', '1.45 Cr', '2.2 Cr', '2.8 Cr', '26 L', '47 L', '62 L', '55 L']

# %%
scraper.get_result_similar(url28,grouped=True)
# Out:
# {'rule_2ei0': ['4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '5 BHK Apartment in Unity The Amaryllis',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor'],
#  'rule_ytyo': ['4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '5 BHK Apartment in Unity The Amaryllis',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
# ...

# %%
scraper.set_rule_aliases({'rule_2ei0':'Title','rule_8n1t':'Area','rule_6o3h':'Status','rule_aep5':'Price'})
scraper.keep_rules(['rule_2ei0','rule_8n1t','rule_6o3h','rule_aep5'])
scraper.save('makaan-search')
results28=scraper.get_result_similar(url28,group_by_alias=True)
results28
# Out:
# {'Title': ['4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '5 BHK Apartment in Unity The Amaryllis',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor'],
#  'Area': ['3348',
#   '1050',
#   '810',
#   '520',
#   '5402',
#   '810',
#   '1050',
#   '900',
#   '2493',
#   '1800',
#   '1800',
#   '2699',
#   '901',
#   '1195',
#   '1620',
#   '650',
#   '1050',
#   '820',
#   '1100',
#   '1050'],
#  'Status': ['Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
# ...

# %%
makaan28=pd.DataFrame(results28)
m28=m27.append(makaan28)
m28.head()
# Out:
#    Unnamed: 0                    Title              Location    Area  \
# 0         0.0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925.0
# 1         1.0          1 BHK Apartment    Khera Khurd, Delhi   450.0
# 2         2.0  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0
# 3         3.0  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0
# 4         4.0  4 BHK Independent Floor  Paschim Vihar, Delhi  2250.0
#
#           Status    Price Year Bathroom
# 0  Ready to move   8.5 Cr  NaN      NaN
# 1  Ready to move    9.5 L  NaN      NaN
# 2  Ready to move  2.35 Cr  NaN      NaN
# 3  Ready to move   2.4 Cr  NaN      NaN
# 4  Ready to move  2.35 Cr  NaN      NaN

# %%
m28.shape
# Out:
# (480, 8)

# %%
url29="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=50"
wanted_list29=["4 BHK Independent Floor","Paschim Vihar, Delhi","2700","Ready to move","4.3 Cr"]
result29=scraper.build(url29,wanted_list29)
print(result29)

scraper.get_result_similar(url29,grouped=True)
# Out:
# ['4 BHK Independent Floor', '4 BHK Independent Floor in Reputed Builder Bhera Enclave', '3 BHK Independent Floor', '2 BHK Independent House', 'Paschim Vihar, Delhi', 'Reputed Builder Bhera Enclave,Paschim Vihar, Delhi', 'South Extension 2, Delhi', 'Sector 13 Dwarka, Delhi', '2700', '2250', '2205', '1800', '765', '2150', 'Ready to move', 'Under Construction', '4.3 Cr', '4.4 Cr', '4.5 Cr', '6 Cr', '3.5 Cr', '3.4 Cr', '3.3 Cr', '4.6 Cr', '5.75 Cr', '5.25 Cr', '2 Cr', '4 Cr', '1.75 Cr']
# {'rule_pcbn': ['2 BHK Apartment',
#   '2 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Apartment',
#   '3 BHK Independent Floor',
#   '1 BHK Independent Floor',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
# ...

# %%
scraper.set_rule_aliases({'rule_pcbn':'Title','rule_rivv':'Area','rule_jfzc':'Status','rule_7zif':'Price'})
scraper.keep_rules(['rule_pcbn','rule_rivv','rule_jfzc','rule_7zif'])
scraper.save('makaan-search')
results29=scraper.get_result_similar(url29,group_by_alias=True)
results29
# Out:
# {'Title': ['4 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '4 BHK Independent Floor in Reputed Builder Bhera Enclave',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '4 BHK Independent Floor in Reputed Builder Bhera Enclave',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent House',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor'],
#  'Area': ['2700',
#   '2700',
#   '2700',
#   '2700',
#   '2250',
#   '2700',
#   '2700',
#   '2700',
#   '2700',
#   '2250',
#   '2250',
#   '2700',
#   '2700',
#   '2250',
#   '2250',
#   '2205',
#   '1800',
#   '765',
#   '2150',
#   '1800'],
#  'Status': ['Ready to move',
#   'Ready to move',
# ...

# %%
makaan29=pd.DataFrame(results29)
m29=m28.append(makaan29)
m29.head()
# Out:
#    Unnamed: 0                    Title              Location    Area  \
# 0         0.0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925.0
# 1         1.0          1 BHK Apartment    Khera Khurd, Delhi   450.0
# 2         2.0  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0
# 3         3.0  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0
# 4         4.0  4 BHK Independent Floor  Paschim Vihar, Delhi  2250.0
#
#           Status    Price Year Bathroom
# 0  Ready to move   8.5 Cr  NaN      NaN
# 1  Ready to move    9.5 L  NaN      NaN
# 2  Ready to move  2.35 Cr  NaN      NaN
# 3  Ready to move   2.4 Cr  NaN      NaN
# 4  Ready to move  2.35 Cr  NaN      NaN

# %%
m29.shape
# Out:
# (500, 8)

# %%
url30="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=60"
wanted_list30=["2 BHK Apartment","Uttam Nagar, Delhi","600","Ready to move","22 L"]
result30=scraper.build(url30,wanted_list30)
print(result30)

scraper.get_result_similar(url30,grouped=True)
# Out:
# ['2 BHK Apartment', '1 BHK Apartment', '3 BHK Apartment', '2 BHK Independent Floor', '3 BHK Independent Floor', 'Dwarka Mor, Delhi', 'Uttam Nagar, Delhi', 'Sector 22 Dwarka, Delhi', 'Sector 19 Dwarka, Delhi', 'Sector-18 Dwarka, Delhi', 'Sector 6 Dwarka, Delhi', 'Shanti Park Dwarka, Delhi', 'Lajpat Nagar, Delhi', 'Lajpat Nagar II, Delhi', 'Jangpura, Delhi', '700', '450', '650', '850', '600', '1600', '1550', '1700', '1250', '950', '900', '1800', 'Ready to move', '28 L', '16 L', '25 L', '32 L', '22 L', '1.5 Cr', '1.6 Cr', '2.05 Cr', '1.78 Cr', '1.1 Cr', '1.45 Cr', '1.3 Cr', '4.75 Cr', '4.5 Cr']
# {'rule_2k99': ['2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Apartment',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Apartment',
#   '2 BHK Independent Floor',
#   '2 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
# ...

# %%
scraper.set_rule_aliases({'rule_2k99':'Title','rule_bjd4':'Location','rule_37hw':'Area','rule_im7y':'Status','rule_8vi5':'Price'})
scraper.keep_rules(['rule_2k99', 'rule_bjd4','rule_37hw','rule_im7y','rule_8vi5'])
scraper.save('makaan-search')
results30=scraper.get_result_similar(url30,group_by_alias=True)
results30
# Out:
# {'Title': ['2 BHK Apartment',
#   '1 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor'],
#  'Location': ['Dwarka Mor, Delhi',
#   'Uttam Nagar, Delhi',
#   'Dwarka Mor, Delhi',
#   'Uttam Nagar, Delhi',
#   'Uttam Nagar, Delhi',
#   'Dwarka Mor, Delhi',
#   'Uttam Nagar, Delhi',
#   'Dwarka Mor, Delhi',
#   'Uttam Nagar, Delhi',
#   'Sector 22 Dwarka, Delhi',
#   'Sector 19 Dwarka, Delhi',
#   'Sector-18 Dwarka, Delhi',
#   'Sector 6 Dwarka, Delhi',
#   'Shanti Park Dwarka, Delhi',
#   'Lajpat Nagar, Delhi',
#   'Lajpat Nagar II, Delhi',
#   'Jangpura, Delhi',
# ...

# %%
makaan30=pd.DataFrame(results30)
m30=m29.append(makaan30)
m30.head()
# Out:
#    Unnamed: 0                    Title              Location    Area  \
# 0         0.0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925.0
# 1         1.0          1 BHK Apartment    Khera Khurd, Delhi   450.0
# 2         2.0  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0
# 3         3.0  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0
# 4         4.0  4 BHK Independent Floor  Paschim Vihar, Delhi  2250.0
#
#           Status    Price Year Bathroom
# 0  Ready to move   8.5 Cr  NaN      NaN
# 1  Ready to move    9.5 L  NaN      NaN
# 2  Ready to move  2.35 Cr  NaN      NaN
# 3  Ready to move   2.4 Cr  NaN      NaN
# 4  Ready to move  2.35 Cr  NaN      NaN

# %%
m30.shape
# Out:
# (520, 8)

# %%
url31="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=65"
wanted_list31=["3 BHK Independent Floor","Rajouri Garden, Delhi","2000","Ready to move","3.25 Cr"]
result31=scraper.build(url31,wanted_list31)
print(result31)

scraper.get_result_similar(url31,grouped=True)
# Out:
# ['3 BHK Independent Floor', '4 BHK Independent Floor', '2 BHK Independent Floor', '4 BHK Apartment', '3 BHK Apartment in Reputed Builder Air India Apartment', '3 BHK Apartment in Cooperative Group Bhrigu Apartments', '3 BHK Apartment in CGHS Chitrakoot Apartments', '4 BHK Apartment in CGHS Dream Apartments', '2 BHK Apartment in DDA Rosewood Apartment', '3 BHK Apartment in Reputed Builder Om Satyam Apartment', '3 BHK Apartment in Reputed Builder Guru Ramdas Apartment', '3 BHK Apartment in Reputed Builder Mahalaxmi Apartment', '3 BHK Apartment', '4 BHK Apartment in Reputed Builder Upkari Apartment', '2 BHK Apartment in Reputed Builder Sapna Ghar Apartment', 'Rajouri Garden, Delhi', 'Punjabi Bagh, Delhi', 'Tagore Garden Extension, Delhi', 'Sector 11 Dwarka, Delhi', 'Reputed Builder Air India Apartment,Sector 3 Dwarka, Delhi', 'Cooperative Group Bhrigu Apartments,Sector 9 Dwarka, Delhi', 'CGHS Chitrakoot Apartments,Sector 22 Dwarka, Delhi', 'Sector 3 Dwarka, Delhi', 'Sector 9 Dwarka, Del
# ...

# %%
scraper.set_rule_aliases({'rule_fa4d':'Title','rule_nopt':'Location','rule_mzsf':'Area','rule_tpg3':'Status','rule_n315':'Price'})
scraper.keep_rules(['rule_fa4d', 'rule_nopt','rule_mzsf','rule_tpg3','rule_n315'])
scraper.save('makaan-search')
results31=scraper.get_result_similar(url31,group_by_alias=True)
results31
# Out:
# {'Title': ['4 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Apartment',
#   '3 BHK Apartment in Reputed Builder Air India Apartment',
#   '3 BHK Apartment in Cooperative Group Bhrigu Apartments',
#   '3 BHK Apartment in CGHS Chitrakoot Apartments',
#   '4 BHK Apartment in CGHS Dream Apartments',
#   '2 BHK Apartment in DDA Rosewood Apartment',
#   '3 BHK Apartment in Reputed Builder Om Satyam Apartment',
#   '3 BHK Apartment in Reputed Builder Guru Ramdas Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment in Reputed Builder Mahalaxmi Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment in Reputed Builder Upkari Apartment',
#   '2 BHK Apartment in Reputed Builder Sapna Ghar Apartment'],
#  'Location': ['Rajouri Garden, Delhi',
#   'Rajouri Garden, Delhi',
#   'Punjabi Bagh, Delhi',
# ...

# %%
makaan31=pd.DataFrame(results31)
m31=m30.append(makaan31)
m31.shape
# Out:
# (540, 8)

# %%
url32="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=72"
wanted_list32=["4 BHK Apartment","Sector-18 Dwarka, Delhi","2400","Ready to move","2.5 Cr"]
result32=scraper.build(url32,wanted_list32)
print(result32)

scraper.get_result_similar(url32,grouped=True)
# Out:
# ['4 BHK Apartment', '3 BHK Apartment', '3 BHK Independent Floor', '2 BHK Independent Floor', '2 BHK Independent House', '1 RK Studio Apartment', '3 BHK Apartment in CGHS Pragya Apartment', '3 BHK Independent Floor in Reputed Builder Sector 8 B 81', '4 BHK Apartment in DDA Tara Apartments', '3 BHK Apartment in Reputed Builder Mandakini Enclave', 'Sector-18 Dwarka, Delhi', 'CGHS Pragya Apartment,Sector 2 Dwarka, Delhi', 'Reputed Builder Sector 8 B 81,Sector 8 Dwarka, Delhi', 'Bali Nagar, Delhi', 'Shastri Nagar, Delhi', 'DDA Tara Apartments,Kalkaji, Delhi', 'Sector 2 Dwarka, Delhi', 'Sector 8 Dwarka, Delhi', 'Kalkaji, Delhi', 'greater kailash Enclave 1, Delhi', '2400', '1800', '1890', '1250', '900', '720', '1600', '450', '1950', '950', '1000', 'Ready to move', '2.5 Cr', '2.3 Cr', '1.55 Cr', '1 Cr', '70 L', '65 L', '2.25 Cr', '1.27 Cr', '45 L', '75 L', '3.1 Cr', '90 L', '32 L', '50 L', '1.86 Cr']
# {'rule_kvwn': ['4 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Independent Floor',
# ...

# %%
scraper.set_rule_aliases({'rule_kvwn':'Title','rule_8497':'Area','rule_l0h8':'Status','rule_hrq3':'Price'})
scraper.keep_rules(['rule_kvwn','rule_8497','rule_l0h8','rule_hrq3'])
scraper.save('makaan-search')
results32=scraper.get_result_similar(url32,group_by_alias=True)
results32
# Out:
# {'Title': ['4 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '4 BHK Apartment',
#   '2 BHK Independent House',
#   '2 BHK Independent Floor',
#   '1 RK Studio Apartment',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Apartment'],
#  'Area': ['2400',
#   '1800',
#   '1890',
#   '1250',
#   '900',
#   '720',
#   '1600',
#   '450',
#   '450',
#   '720',
#   '900',
#   '1950',
#   '950',
#   '950',
#   '950',
#   '1000',
#   '450',
#   '900',
#   '950',
#   '1800'],
#  'Status': ['Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
# ...

# %%
makaan32=pd.DataFrame(results32)
m32=m31.append(makaan32)
m32.head()
# Out:
#    Unnamed: 0                    Title              Location    Area  \
# 0         0.0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925.0
# 1         1.0          1 BHK Apartment    Khera Khurd, Delhi   450.0
# 2         2.0  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0
# 3         3.0  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0
# 4         4.0  4 BHK Independent Floor  Paschim Vihar, Delhi  2250.0
#
#           Status    Price Year Bathroom
# 0  Ready to move   8.5 Cr  NaN      NaN
# 1  Ready to move    9.5 L  NaN      NaN
# 2  Ready to move  2.35 Cr  NaN      NaN
# 3  Ready to move   2.4 Cr  NaN      NaN
# 4  Ready to move  2.35 Cr  NaN      NaN

# %%
m32.shape
# Out:
# (560, 8)

# %%
url33="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=77"
wanted_list33=["2 BHK Apartment","Sector 19 Dwarka, Delhi","1200","Ready to move","96 L"]
result33=scraper.build(url33,wanted_list33)
print(result33)

scraper.get_result_similar(url33,grouped=True)
# Out:
# ['2 BHK Apartment', '4 BHK Apartment', '4 BHK Independent Floor', '2 BHK Independent Floor', '3 BHK Independent Floor', '3 BHK Apartment', 'Sector 19 Dwarka, Delhi', 'Sector 22 Dwarka, Delhi', 'Chittaranjan Park, Delhi', 'Govindpuri, Delhi', 'Janakpuri, Delhi', 'Pitampura, Delhi', 'Sector 8 Dwarka, Delhi', 'Sector-18 Dwarka, Delhi', 'Sector 7 Dwarka, Delhi', 'Sector 10 Dwarka, Delhi', 'Karampura, Delhi', 'Sector 23 Dwarka, Delhi', 'Sector 12 Dwarka, Delhi', 'Sector 9 Dwarka, Delhi', '1200', '2300', '3100', '600', '1000', '1350', '800', '1685', '720', '648', '2400', '1700', '1600', '1750', '3250', '1379', 'Ready to move', '96 L', '2.08 Cr', '6.75 Cr', '20 L', '1.18 Cr', '1.75 Cr', '35 L', '3.25 Cr', '53 L', '55 L', '2.25 Cr', '1.55 Cr', '1.54 Cr', '2.65 Cr', '1.35 Cr', '1.98 Cr', '9.75 Cr', '2.1 Cr', '1.45 Cr']
# {'rule_mqxj': ['2 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
# ...

# %%
scraper.set_rule_aliases({'rule_mqxj':'Title','rule_i7wc':'Location','rule_ocg6':'Area','rule_5tkk':'Status','rule_61gf':'Price'})
scraper.keep_rules(['rule_mqxj', 'rule_i7wc','rule_ocg6','rule_5tkk','rule_61gf'])
scraper.save('makaan-search')
results33=scraper.get_result_similar(url33,group_by_alias=True)
results33
# Out:
# {'Title': ['3 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '1 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Independent Floor',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment'],
#  'Location': ['Bindapur, Delhi',
#   'Sector-18 Dwarka, Delhi',
#   'Sector 10 Dwarka, Delhi',
#   'Sector 14 Dwarka, Delhi',
#   'Sector 4 Dwarka, Delhi',
#   'Sector 22 Dwarka, Delhi',
#   'Sector 12 Dwarka, Delhi',
#   'Sector 13 Dwarka, Delhi',
#   'Sector 22 Dwarka, Delhi',
#   'Chittaranjan Park, Delhi',
#   'Sector 6 Dwarka, Delhi',
#   'Sector 22 Dwarka, Delhi',
#   'Sector 19 Dwarka, Delhi',
#   'Sector 23 Dwarka, Delhi',
#   'Sector 9 Dwarka, Delhi',
#   'Sector 3 Dwarka, Delhi',
# ...

# %%
makaan33=pd.DataFrame(results33)
m33=m32.append(makaan33)
m33.shape
# Out:
# (580, 8)

# %%
m33.duplicated().sum()
# Out:
# 6

# %%
url34="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=85"
wanted_list34=["3 BHK Independent Floor","Sector 8 Dwarka, Delhi","1890","Ready to move","1.52 Cr"]
result34=scraper.build(url34,wanted_list34)
print(result34)

scraper.get_result_similar(url34,grouped=True)
# Out:
# ['4 BHK Independent Floor', '2 BHK Independent Floor', '3 BHK Independent Floor', '3 BHK Apartment in Reputed Builder Mayurdhwaj', '2 BHK Apartment in Reputed Builder Mayurdhwaj', '2 BHK Apartment in Swaraj Homes Prashant Apartments', '3 BHK Apartment in Reputed Builder Trilok Apartment', '3 BHK Apartment', '3 BHK Apartment in Reputed Builder Vidhisha Apartment', '3 BHK Apartment in CGHS Dream Apartments', '3 BHK Apartment in Reputed Builder DIN Apartments', '3 BHK Apartment in Reputed Builder Asha Deep Apartments', '3 BHK Apartment in Reputed Builder Highland Apartment', 'Pitampura, Delhi', 'Sector 8 Dwarka, Delhi', 'Rohini sector 24, Delhi', 'Safdarjung Enclave, Delhi', 'Reputed Builder Mayurdhwaj,Patparganj, Delhi', 'Swaraj Homes Prashant Apartments,IP Extension, Delhi', 'Reputed Builder Trilok Apartment,Patparganj, Delhi', 'Patparganj, Delhi', 'IP Extension, Delhi', 'Sector 22 Dwarka, Delhi', 'Sector 4 Dwarka, Delhi', 'Sector 11 Rohini, Delhi', 'Sector 2 Dwarka, Delhi', 'Sector 1
# ...

# %%
scraper.set_rule_aliases({'rule_lkgx':'Title','rule_t7kw':'Area','rule_c863':'Status','rule_f6zf':'Price'})
scraper.keep_rules(['rule_lkgx','rule_t7kw','rule_c863','rule_f6zf'])
scraper.save('makaan-search')
results34=scraper.get_result_similar(url34,group_by_alias=True)
results34
# Out:
# {'Title': ['3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment in Swaraj Homes Panchmahal Awas',
#   '3 BHK Apartment in CGHS Panchsheel Apartment',
#   '3 BHK Apartment in Reputed Builder Katyayani Apartment',
#   '3 BHK Apartment in Reputed Builder Indraprastha Apartments',
#   '1 BHK Independent House in Swaraj Homes RWA Yamuna Vihar Block C4',
#   '3 BHK Apartment',
#   '2 BHK Apartment in DDA Arunodaya Apartment',
#   '3 BHK Apartment in Reputed Builder DIN Apartments',
#   '3 BHK Apartment in CGHS Kesarwani Apartments',
#   '2 BHK Apartment in CGHS Fakhruddin Apartment'],
#  'Area': ['1890',
#   '2160',
#   '2800',
#   '1800',
#   '2000',
#   '1100',
#   '750',
#   '1500',
#   '1350',
#   '1350',
#   '1250',
#   '1700',
# ...

# %%
makaan34=pd.DataFrame(results34)
m34=m33.append(makaan34)
m34.head()
# Out:
#    Unnamed: 0                    Title              Location    Area  \
# 0         0.0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925.0
# 1         1.0          1 BHK Apartment    Khera Khurd, Delhi   450.0
# 2         2.0  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0
# 3         3.0  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0
# 4         4.0  4 BHK Independent Floor  Paschim Vihar, Delhi  2250.0
#
#           Status    Price Year Bathroom
# 0  Ready to move   8.5 Cr  NaN      NaN
# 1  Ready to move    9.5 L  NaN      NaN
# 2  Ready to move  2.35 Cr  NaN      NaN
# 3  Ready to move   2.4 Cr  NaN      NaN
# 4  Ready to move  2.35 Cr  NaN      NaN

# %%
m34.shape
# Out:
# (600, 8)

# %%
m34.to_csv("Makaan_WebScraped.csv")

# %%
url35="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=87"
wanted_list35=["2 BHK Independent Floor","Babarpur, Delhi","675","Ready to move","40 L"]
result35=scraper.build(url35,wanted_list35)
print(result35)

scraper.get_result_similar(url35,grouped=True)
# Out:
# ['2 BHK Independent Floor', '3 BHK Apartment', '4 BHK Apartment', '2 BHK Apartment', '1 BHK Apartment', '1 BHK Independent Floor', '3 BHK Independent Floor', '3 BHK Apartment in CGHS Udyog Vihar', '4 BHK Apartment in CGHS Chandanwari Apartments', '3 BHK Apartment in Guru Ji Ashiyana Homes 1', '2 BHK Apartment in Guru Ji Ashiyana Homes 1', '1 BHK Apartment in Guru Ji Ashiyana Homes 1', '2 BHK Independent Floor in Guru Ji Shyam Kunj', '1 BHK Independent Floor in Guru Ji Shyam Kunj', '3 BHK Independent Floor in Guru Ji Shyam Kunj', 'Babarpur, Delhi', 'CGHS Udyog Vihar,Sector 22 Dwarka, Delhi', 'CGHS Chandanwari Apartments,Sector 10 Dwarka, Delhi', 'Sector-18 Dwarka, Delhi', 'Sector 6 Dwarka, Delhi', 'Sector 3 Dwarka, Delhi', 'Hauz Khas, Delhi', 'Guru Ji Ashiyana Homes 1,Dwarka Mor, Delhi', 'Sector 22 Dwarka, Delhi', 'Sector 10 Dwarka, Delhi', 'Dwarka Mor, Delhi', '675', '1700', '2400', '1750', '4500', '900', '500', '400', '350', '800', '600', '550', '450', '750', 'Ready to move', '40 L'
# ...

# %%
scraper.set_rule_aliases({'rule_7z63':'Title','rule_h6u2':'Location','rule_xp52':'Area','rule_wqun':'Status','rule_tbjp':'Price'})
scraper.keep_rules(['rule_7z63', 'rule_h6u2','rule_xp52','rule_wqun','rule_tbjp'])
scraper.save('makaan-search')
results35=scraper.get_result_similar(url35,group_by_alias=True)
results35
# Out:
# {'Title': ['3 BHK Independent House',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Independent Floor',
#   '1 BHK Independent Floor',
#   '1 BHK Independent Floor',
#   '1 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '1 BHK Apartment'],
#  'Location': ['Gokalpur, Delhi',
#   'Sector 22 Dwarka, Delhi',
#   'Sector 10 Dwarka, Delhi',
#   'Sector-18 Dwarka, Delhi',
#   'Sector 6 Dwarka, Delhi',
#   'Sector 3 Dwarka, Delhi',
#   'Sector 6 Dwarka, Delhi',
#   'Sector 10 Dwarka, Delhi',
#   'Dwarka Mor, Delhi',
#   'Dwarka Mor, Delhi',
#   'Dwarka Mor, Delhi',
#   'Dwarka Mor, Delhi',
#   'Dwarka Mor, Delhi',
#   'Dwarka Mor, Delhi',
#   'Dwarka Mor, Delhi',
#   'Dwarka Mor, Delhi',
# ...

# %%
makaan35=pd.DataFrame(results35)
m35=m34.append(makaan35)
m35.head()
# Out:
#    Unnamed: 0                    Title              Location    Area  \
# 0         0.0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925.0
# 1         1.0          1 BHK Apartment    Khera Khurd, Delhi   450.0
# 2         2.0  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0
# 3         3.0  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0
# 4         4.0  4 BHK Independent Floor  Paschim Vihar, Delhi  2250.0
#
#           Status    Price Year Bathroom
# 0  Ready to move   8.5 Cr  NaN      NaN
# 1  Ready to move    9.5 L  NaN      NaN
# 2  Ready to move  2.35 Cr  NaN      NaN
# 3  Ready to move   2.4 Cr  NaN      NaN
# 4  Ready to move  2.35 Cr  NaN      NaN

# %%
m35.shape
# Out:
# (620, 8)

# %%
m35.duplicated().sum()
# Out:
# 6

# %%
m35.to_csv("Makaan_WebScraped0.csv")

# %%
m35.head()
# Out:
#    Unnamed: 0                    Title              Location    Area  \
# 0         0.0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925.0
# 1         1.0          1 BHK Apartment    Khera Khurd, Delhi   450.0
# 2         2.0  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0
# 3         3.0  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0
# 4         4.0  4 BHK Independent Floor  Paschim Vihar, Delhi  2250.0
#
#           Status    Price Year Bathroom
# 0  Ready to move   8.5 Cr  NaN      NaN
# 1  Ready to move    9.5 L  NaN      NaN
# 2  Ready to move  2.35 Cr  NaN      NaN
# 3  Ready to move   2.4 Cr  NaN      NaN
# 4  Ready to move  2.35 Cr  NaN      NaN

# %%
df=pd.read_csv("Makaan_WebScraped0.csv")
df.head()
print(df.shape)
# Out:
# (620, 9)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
url37="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=91"
wanted_list37=["2 BHK Independent Floor","Safdarjung Enclave, Delhi","1000","Ready to move","2 Bathrooms", "1.3 Cr"]
result37=scraper.build(url37,wanted_list37)
print(result37)

scraper.get_result_similar(url37,grouped=True)
# Out:
# ['3 BHK Apartment in Reputed Builder Trilok Apartment', '3 BHK Apartment', '3 BHK Apartment in Reputed Builder Vidhisha Apartment', '3 BHK Apartment in CGHS Dream Apartments', '2 BHK Independent Floor', '3 BHK Apartment in Reputed Builder DIN Apartments', '3 BHK Independent Floor', '3 BHK Apartment in Reputed Builder Asha Deep Apartments', '3 BHK Apartment in Reputed Builder Highland Apartment', '2 BHK Apartment in Swaraj Homes Panchmahal Awas', '2 BHK Apartment', '1 BHK Independent Floor', '4 BHK Independent Floor', 'Reputed Builder Trilok Apartment,Patparganj, Delhi', 'Patparganj, Delhi', 'Reputed Builder Vidhisha Apartment,Patparganj, Delhi', 'CGHS Dream Apartments,Sector 22 Dwarka, Delhi', 'Safdarjung Enclave, Delhi', 'Reputed Builder DIN Apartments,Sector 4 Dwarka, Delhi', 'Sector 11 Rohini, Delhi', 'Reputed Builder Asha Deep Apartments,Sector 2 Dwarka, Delhi', 'Reputed Builder Highland Apartment,Sector 12 Dwarka, Delhi', 'Sector 22 Dwarka, Delhi', 'Sector 4 Dwarka, Delhi', 'Sec
# ...

# %%
scraper.set_rule_aliases({'rule_3kqe':'Title','rule_7mga':'Area','rule_lnf2':'Status','rule_gg7w':'Price'})
scraper.keep_rules(['rule_3kqe','rule_7mga','rule_lnf2','rule_gg7w'])
scraper.save('makaan-search')
results37=scraper.get_result_similar(url37,group_by_alias=True)
results37
# Out:
# {'Title': ['2 BHK Apartment in Reputed Builder Mayurdhwaj',
#   '2 BHK Apartment in Swaraj Homes Prashant Apartments',
#   '3 BHK Apartment in Reputed Builder Trilok Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment in Reputed Builder Vidhisha Apartment',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent House',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment in Umang Winter Hills',
#   '3 BHK Apartment in Swaraj Homes RWA Vipin Garden',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent House in Swaraj Homes RWA Yamuna Vihar Block C11',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor'],
#  'Area': ['1400',
#   '1000',
#   '1350',
#   '1350',
#   '1450',
#   '1100',
#   '750',
#   '675',
#   '2000',
#   '900',
#   '570',
#   '950',
#   '1250',
#   '810',
#   '1800',
#   '1800',
# ...

# %%
makaan37=pd.DataFrame(results37)
m37=df.append(makaan37)
m37.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                    Title              Location  \
# 0         0.0           0.0  4 BHK Independent Floor     Neeti Bagh, Delhi
# 1         1.0           1.0          1 BHK Apartment    Khera Khurd, Delhi
# 2         2.0           2.0  3 BHK Independent Floor  Paschim Vihar, Delhi
# 3         3.0           3.0  3 BHK Independent Floor  Paschim Vihar, Delhi
# 4         4.0           4.0  4 BHK Independent Floor  Paschim Vihar, Delhi
#
#      Area         Status    Price Year Bathroom
# 0  2925.0  Ready to move   8.5 Cr  NaN      NaN
# 1   450.0  Ready to move    9.5 L  NaN      NaN
# 2  1620.0  Ready to move  2.35 Cr  NaN      NaN
# 3  1620.0  Ready to move   2.4 Cr  NaN      NaN
# 4  2250.0  Ready to move  2.35 Cr  NaN      NaN

# %%
url38="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=92"
wanted_list38=["2 BHK Independent Floor","Dwarka Sector 15, Delhi","650","Ready to move","2 Bathrooms", "35 L"]
result38=scraper.build(url38,wanted_list38)
print(result38)

scraper.get_result_similar(url38,grouped=True)
# Out:
# ['2 BHK Independent Floor', '3 BHK Independent Floor', '4 BHK Independent Floor', '1 BHK Independent Floor', 'Dwarka Sector 15, Delhi', 'Rohini sector 24, Delhi', 'Sector 23 Rohini, Delhi', 'Sector 20 Rohini, Delhi', 'Sector 25 Rohini, Delhi', '650', '450', '800', '1120', '2200', '1125', '700', '400', '780', '830', '3600', '550', '1400', '880', 'Ready to move', 'New', '2 Bathrooms', '4 Bathrooms', '3 Bathrooms', '1 Bathrooms', '5 - 6 years old', '35 L', '36 L', '58 L', '67 L', '2 Cr', '1.3 Cr', '60 L', '30 L', '80 L', '95 L', '50 L', '51 L', '4.65 Cr', '45 L', '56 L', '68 L', '1.68 Cr', '75 L', '1.65 Cr']
# {'rule_fyrk': ['2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '1 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
# ...

# %%
scraper.set_rule_aliases({'rule_fyrk':'Title','rule_h38h':'Area','rule_lj86':'Status','rule_dzy6':'Bathroom','rule_daq4':'Price'})
scraper.keep_rules(['rule_fyrk','rule_h38h','rule_lj86','rule_dzy6','rule_daq4'])
scraper.save('makaan-search')
results38=scraper.get_result_similar(url38,group_by_alias=True)
results38
# Out:
# {'Title': ['2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '1 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor'],
#  'Area': ['650',
#   '450',
#   '880',
#   '1400',
#   '650',
#   '3600',
#   '550',
#   '650',
#   '780',
#   '800',
#   '1400',
#   '800',
#   '1120',
#   '800',
#   '900',
#   '400',
#   '2300',
#   '2200',
#   '1125',
#   '700'],
#  'Status': ['Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
# ...

# %%
makaan38=pd.DataFrame(results38)
m38=m37.append(makaan38)
m38.shape
# Out:
# (660, 9)

# %%
url39="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=95"
wanted_list39=["3 BHK Apartment","Sector 23 Dwarka, Delhi","1750","Ready to move", "1.88 Cr"]
result39=scraper.build(url39,wanted_list39)
print(result39)

scraper.get_result_similar(url39,grouped=True)
# Out:
# ['3 BHK Apartment', '4 BHK Independent Floor', '2 BHK Independent Floor', '4 BHK Apartment', '1 BHK Apartment', '2 BHK Apartment', '1 BHK Independent Floor', '4 BHK Apartment in Guru Ji Gopal Dham Homes', '3 BHK Apartment in Guru Ji Gopal Dham Homes', '1 BHK Apartment in Guru Ji Gopal Dham Homes', '2 BHK Apartment in Guru Ji Gopal Dham Homes', '3 BHK Apartment in Reputed Builder Dabbas Apartments', '1 BHK Apartment in DDA Flats Sector 14', 'Vasant Kunj, Delhi', 'Sector 8 Dwarka, Delhi', 'Dwarka Mor, Delhi', 'Sector 23 Dwarka, Delhi', 'Sector 14 Dwarka, Delhi', 'Sector 3 Rohini, Delhi', 'East of Kailash, Delhi', '2000', '1890', '740', '1500', '1000', '1300', '500', '400', '700', '650', '750', '600', '1750', '720', '550', '2700', 'Ready to move', 'Under Construction', '2.1 Cr', '1.55 Cr', '53 L', '1 Cr', '52 L', '92 L', '25 L', '18 L', '35 L', '32 L', '60 L', '38 L', '28 L', '1.88 Cr', '50.9 L', '48 L', '74 L', '57 L', '45 L', '7.5 Cr']
# {'rule_4x6z': ['3 BHK Apartment',
# ...

# %%
scraper.set_rule_aliases({'rule_4x6z':'Title','rule_bi0q':'Location','rule_ixgu':'Area','rule_quue':'Status','rule_f508':'Price'})
scraper.keep_rules(['rule_4x6z','rule_bi0q','rule_ixgu','rule_quue','rule_f508'])
scraper.save('makaan-search')
results39=scraper.get_result_similar(url39,group_by_alias=True)
results39
# Out:
# {'Title': ['1 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '1 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '3 BHK Apartment',
#   '1 BHK Independent Floor',
#   '4 BHK Independent Floor'],
#  'Location': ['Dwarka Mor, Delhi',
#   'Dwarka Mor, Delhi',
#   'Dwarka Mor, Delhi',
#   'Dwarka Mor, Delhi',
#   'Dwarka Mor, Delhi',
#   'Dwarka Mor, Delhi',
#   'Sector 8 Dwarka, Delhi',
#   'Sector 8 Dwarka, Delhi',
#   'Sector 14 Dwarka, Delhi',
#   'Sector 23 Dwarka, Delhi',
#   'Sector 8 Dwarka, Delhi',
#   'Sector 8 Dwarka, Delhi',
#   'Sector 8 Dwarka, Delhi',
#   'Sector 8 Dwarka, Delhi',
#   'Vasant Kunj, Delhi',
#   'Vasant Kunj, Delhi',
# ...

# %%
makaan39=pd.DataFrame(results39)
m39=m38.append(makaan39)
m39.shape
# Out:
# (680, 9)

# %%
url40="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=96"
wanted_list40=["3 BHK Independent Floor","Jangpura, Delhi","1650","Ready to move", "3 Bathrooms", "4 Cr"]
result40=scraper.build(url40,wanted_list40)
print(result40)

scraper.get_result_similar(url40,grouped=True)
# Out:
# ['3 BHK Apartment in Reputed Builder Azad Apartments', '3 BHK Independent Floor', '4 BHK Independent Floor', '2 BHK Independent Floor', '3 BHK Apartment in Reputed Builder Aakriti Apartments', '4 BHK Apartment in DLF One Midtown', '3 BHK Apartment in DLF Capital Greens', '2 BHK Apartment', '3 BHK Apartment in CGHS Dream Apartments', '3 BHK Apartment in Reputed Builder Ispatika Apartments', '3 BHK Apartment', '3 BHK Apartment in CGHS The Shabad', '2 BHK Apartment in DDA Suryodaya', 'Reputed Builder Azad Apartments,Sheikh Sarai, Delhi', 'Greater Kailash, Delhi', 'Saket, Delhi', 'Ramesh Nagar, Delhi', 'Moti Nagar, Delhi', 'Reputed Builder Aakriti Apartments,Sector 4 Dwarka, Delhi', 'DLF One Midtown,Karampura, Delhi', 'DLF Capital Greens,Karampura, Delhi', 'Jangpura, Delhi', 'Sheikh Sarai, Delhi', 'Sector 4 Dwarka, Delhi', 'Karampura, Delhi', 'Mayur Vihar II, Delhi', 'Sector 22 Dwarka, Delhi', 'Sector-18 Dwarka, Delhi', 'Sector 13 Dwarka, Delhi', 'Sector 19 Dwarka, Delhi', 'Sector 12 Dwa
# ...

# %%
scraper.set_rule_aliases({'rule_gcj1':'Title','rule_wuok':'Area','rule_bqvm':'Status','rule_n2qr':'Bathroom','rule_m6f6':'Price'})
scraper.keep_rules(['rule_gcj1','rule_wuok','rule_bqvm','rule_n2qr','rule_m6f6'])
scraper.save('makaan-search')
results40=scraper.get_result_similar(url40,group_by_alias=True)
results40
# Out:
# {'Title': ['3 BHK Apartment in Reputed Builder Azad Apartments',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Apartment in Reputed Builder Aakriti Apartments',
#   '4 BHK Independent Floor',
#   '4 BHK Apartment in DLF One Midtown',
#   '3 BHK Apartment in DLF Capital Greens',
#   '3 BHK Independent Floor',
#   '2 BHK Apartment',
#   '2 BHK Independent Floor',
#   '3 BHK Apartment in CGHS Dream Apartments',
#   '3 BHK Apartment in Reputed Builder Ispatika Apartments',
#   '3 BHK Apartment',
#   '3 BHK Apartment in CGHS The Shabad',
#   '2 BHK Apartment',
#   '2 BHK Apartment in DDA Suryodaya',
#   '3 BHK Apartment in DLF Capital Greens',
#   '3 BHK Apartment in DLF Capital Greens'],
#  'Area': ['1600',
#   '1800',
#   '2250',
#   '900',
#   '900',
#   '1700',
#   '2250',
#   '3030',
#   '1600',
#   '1650',
#   '1000',
#   '900',
#   '1700',
#   '1750',
#   '1700',
#   '1700',
#   '1200',
# ...

# %%
makaan40=pd.DataFrame(results40)
m40=m39.append(makaan40)
m40.shape
# Out:
# (700, 9)

# %%
url41="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=98"
wanted_list41=["3 BHK Independent Floor","vikaspuri, Delhi","1150","Ready to move", "1.55 Cr"]
result41=scraper.build(url41,wanted_list41)
print(result41)

scraper.get_result_similar(url41,grouped=True)
# Out:
# ['3 BHK Independent Floor', '2 BHK Independent Floor', '3 BHK Apartment in Raheja Navin Minar', '4 BHK Apartment in Raheja Navin Minar', '4 BHK Independent Floor', '4 BHK Apartment', '5 BHK Apartment', '8 BHK Apartment', 'vikaspuri, Delhi', 'Tri Nagar, Delhi', 'Pitampura, Delhi', 'Dwarka Sector 15, Delhi', 'Raheja Navin Minar,Shadipur, Delhi', 'South Extension 2, Delhi', 'Greater Kailash II, Delhi', 'Shadipur, Delhi', 'Sarita Vihar, Delhi', 'Greater kailash 1, Delhi', 'Saket, Delhi', 'Sector 12 Dwarka, Delhi', 'Sector 8 Dwarka, Delhi', 'Neb Sarai, Delhi', '1150', '450', '1200', '1080', '2306', '3901', '675', '1100', '3600', '4950', '1450', '1872', '2250', '4500', '3750', '3700', '4100', '648', '900', 'Ready to move', 'Under Construction', '1.55 Cr', '33 L', '2.3 Cr', '60 L', '6 Cr', '8.5 Cr', '34 L', '65 L', '7.75 Cr', '12 Cr', '1.75 Cr', '4.35 Cr', '4.95 Cr', '4.5 Cr', '6.5 Cr', '5 Cr', '5.25 Cr', '48 L', '35 L']
# {'rule_ktqh': ['3 BHK Independent Floor',
# ...

# %%
scraper.set_rule_aliases({'rule_ktqh':'Title','rule_241q':'Area','rule_qi9l':'Status','rule_pt79':'Price'})
scraper.keep_rules(['rule_ktqh','rule_241q','rule_qi9l','rule_pt79'])
scraper.save('makaan-search')
results41=scraper.get_result_similar(url41,group_by_alias=True)
results41
# Out:
# {'Title': ['3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Apartment in Raheja Navin Minar',
#   '4 BHK Apartment in Raheja Navin Minar',
#   '2 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '4 BHK Apartment',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '5 BHK Apartment',
#   '5 BHK Apartment',
#   '5 BHK Apartment',
#   '8 BHK Apartment',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor'],
#  'Area': ['1150',
#   '450',
#   '1200',
#   '1080',
#   '2306',
#   '3901',
#   '675',
#   '1100',
#   '3600',
#   '4950',
#   '1450',
#   '1872',
#   '2250',
#   '1872',
#   '4500',
#   '3750',
#   '3700',
#   '4100',
#   '648',
#   '900'],
#  'Status': ['Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Under Construction',
# ...

# %%
makaan41=pd.DataFrame(results41)
m41=m40.append(makaan41)
m41.shape
# Out:
# (720, 9)

# %%
url42="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=102"
wanted_list42=["4 BHK Apartment","Sector 19 Dwarka Mor, Delhi","2400","Ready to move", "2.15 Cr"]
result42=scraper.build(url42,wanted_list42)
print(result42)

scraper.get_result_similar(url42,grouped=True)
# Out:
# ['4 BHK Apartment', '3 BHK Apartment', '2 BHK Apartment', '5 BHK Apartment', '4 BHK Apartment in CGHS Kohinoor Residency', '3 BHK Apartment in CGHS Dream Apartments', '4 BHK Apartment in CGHS Sanchar Vihar Apartments', '3 BHK Apartment in Reputed Builder Shivani Apartment', '2 BHK Apartment in The Antriksh Suruchi Apartments', '3 BHK Apartment in Reputed Builder Kaveri Apartment', '3 BHK Apartment in Reputed Builder DIN Apartments', '3 BHK Apartment in Reputed Builder Vrindavan Apartment', '3 BHK Apartment in CGHS PNB Employees Apartment', '3 BHK Apartment in CGHS Roop Villa Apartment', '3 BHK Apartment in Reputed Builder Ashirwad Apartments Dwarka', '3 BHK Apartment in CGHS Apoorva Apartments', '4 BHK Apartment in Reputed Builder Badhwar Apartments', '3 BHK Apartment in CGHS Sri Niketan Apartments', '2400', '1700', '2350', '1200', '1800', '1650', '1850', '2050', '1750', '2250', '1725', '2150', '2100', 'Ready to move', '2.15 Cr', '1.55 Cr', '1.65 Cr', '1.91 Cr', '2.4 Cr', '1.25 Cr', 
# ...

# %%
scraper.set_rule_aliases({'rule_2j9p':'Title','rule_m716':'Area','rule_u37s':'Status','rule_lv9h':'Price'})
scraper.keep_rules(['rule_2j9p','rule_m716','rule_u37s','rule_lv9h'])
scraper.save('makaan-search')
results42=scraper.get_result_similar(url42,group_by_alias=True)
results42
# Out:
# {'Title': ['4 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '5 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment'],
#  'Area': ['2400',
#   '1700',
#   '1700',
#   '2400',
#   '2350',
#   '1200',
#   '1700',
#   '1700',
#   '2400',
#   '1800',
#   '1650',
#   '1850',
#   '2050',
#   '1750',
#   '2250',
#   '1700',
#   '1725',
#   '2150',
#   '2100',
#   '1850'],
#  'Status': ['Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
# ...

# %%
makaan42=pd.DataFrame(results42)
m42=m41.append(makaan42)
m42.shape
# Out:
# (740, 9)

# %%
url43="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=103"
wanted_list43=["4 BHK Apartment","Sector 6 Dwarka, Delhi","2050","Ready to move","3 Bathrooms", "2.11 Cr"]
result43=scraper.build(url43,wanted_list43)
print(result43)

scraper.get_result_similar(url43,grouped=True)
# Out:
# ['4 BHK Apartment in Reputed Builder Pragjyotishpur Apartments', '3 BHK Apartment in Reputed Builder Princess Park Apartment', '3 BHK Apartment in Reputed Builder Bandhu Vihar', '3 BHK Apartment', '3 BHK Apartment in Reputed Builder Jagran Apartment', '4 BHK Apartment in Reputed Builder KM Apartment', '3 BHK Apartment in Reputed Builder Baroda Apartment', '3 BHK Apartment in Reputed Builder Crescent Apartment', '3 BHK Apartment in CGHS The Elephanta Heights Apartments', '3 BHK Apartment in Reputed Builder NTPC Apartment', '3 BHK Apartment in Reputed Builder Swami Dayanand', '4 BHK Apartment in CGHS Solomon Heights', '4 BHK Apartment in MK MK Residency', '2 BHK Apartment', '4 BHK Apartment in Reputed Builder Neelachal Apartments', '3 BHK Apartment in CGHS Sahita Apartment', '4 BHK Apartment', '3 BHK Apartment in Reputed Builder Rudra Apartment', '3 BHK Apartment in Lakshmi Builders New Delhi Jhelum Arorvansh Apartments', '3 BHK Independent Floor', 'Reputed Builder Pragjyotishpur Apart
# ...

# %%
scraper.set_rule_aliases({'rule_2a64':'Title','rule_suyl':'Location','rule_rrfv':'Area','rule_6mtn':'Status','rule_fe23':'Bathroom','rule_8ue2':'Price'})
scraper.keep_rules(['rule_2a64','rule_suyl','rule_rrfv','rule_6mtn','rule_fe23','rule_8ue2'])
scraper.save('makaan-search')
results43=scraper.get_result_similar(url43,group_by_alias=True)
results43
# Out:
# {'Title': ['4 BHK Apartment in Reputed Builder Pragjyotishpur Apartments',
#   '3 BHK Apartment in Reputed Builder Princess Park Apartment',
#   '3 BHK Apartment in Reputed Builder Bandhu Vihar',
#   '3 BHK Apartment',
#   '3 BHK Apartment in Reputed Builder Jagran Apartment',
#   '4 BHK Apartment in Reputed Builder KM Apartment',
#   '3 BHK Apartment in Reputed Builder Baroda Apartment',
#   '3 BHK Apartment in Reputed Builder Crescent Apartment',
#   '3 BHK Apartment in CGHS The Elephanta Heights Apartments',
#   '3 BHK Apartment in Reputed Builder NTPC Apartment',
#   '3 BHK Apartment in Reputed Builder Swami Dayanand',
#   '4 BHK Apartment in CGHS Solomon Heights',
#   '4 BHK Apartment in MK MK Residency',
#   '2 BHK Apartment',
#   '4 BHK Apartment in Reputed Builder Neelachal Apartments',
#   '3 BHK Apartment in CGHS Sahita Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment in Reputed Builder Rudra Apartment',
# ...

# %%
makaan43=pd.DataFrame(results43)
m43=m42.append(makaan43)
m43.shape
# Out:
# (760, 9)

# %%
m43.duplicated().sum()
# Out:
# 0

# %%
url44="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=104"
wanted_list44=["2 BHK Independent Floor","Tri Nagar, Delhi","900","Ready to move","2 Bathrooms", "42 L"]
result44=scraper.build(url44,wanted_list44)
print(result44)

scraper.get_result_similar(url44,grouped=True)
# Out:
# ['2 BHK Independent Floor', '3 BHK Independent Floor', '1 BHK Independent Floor', '3 BHK Apartment in Sai Affordable Floors', '2 BHK Apartment in Sai Affordable Floors', '1 BHK Apartment in Sai Affordable Floors', '4 BHK Independent Floor', '3 BHK Apartment in CGHS Solomon Heights', '3 BHK Apartment in CGHS Himalayan Residency', 'Tri Nagar, Delhi', 'Green Park, Delhi', 'Dwarka Sector 15, Delhi', 'Lajpat Nagar, Delhi', 'Sai Affordable Floors,Uttam Nagar, Delhi', 'Uttam Nagar, Delhi', 'Vishnu Garden, Delhi', 'Greater kailash 1, Delhi', 'Babarpur, Delhi', 'Sector 19 Dwarka, Delhi', 'Sector 22 Dwarka, Delhi', '900', '1170', '500', '720', '540', '450', '400', '800', '750', '600', '700', '3800', '2160', '1700', 'Ready to move', 'Resale', '1 Bathrooms', 'New', '2 Bathrooms', '3 Bathrooms', '5 - 6 years old', '0 - 1 year old', '4 Bathrooms', '4 - 5 years old', '16 - 17 years old', '42 L', '85 L', '1.65 Cr', '18 L', '1.2 Cr', '45 L', '32 L', '60 L', '28 L', '16 L', '14 L', '50 L', '48 L', '35
# ...

# %%
scraper.set_rule_aliases({'rule_uv2b':'Title','rule_oqzr':'Area','rule_04q9':'Status','rule_prua':'Bathroom','rule_t86i':'Price'})
scraper.keep_rules(['rule_uv2b','rule_oqzr','rule_04q9','rule_prua','rule_t86i'])
scraper.save('makaan-search')
results44=scraper.get_result_similar(url44,group_by_alias=True)
results44
# Out:
# {'Title': ['2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '1 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Apartment in Sai Affordable Floors',
#   '2 BHK Apartment in Sai Affordable Floors',
#   '3 BHK Apartment in Sai Affordable Floors',
#   '2 BHK Apartment in Sai Affordable Floors',
#   '1 BHK Apartment in Sai Affordable Floors',
#   '1 BHK Apartment in Sai Affordable Floors',
#   '3 BHK Apartment in Sai Affordable Floors',
#   '3 BHK Apartment in Sai Affordable Floors',
#   '2 BHK Apartment in Sai Affordable Floors',
#   '3 BHK Apartment in Sai Affordable Floors',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Apartment in CGHS Solomon Heights',
#   '3 BHK Apartment in CGHS Himalayan Residency'],
#  'Area': ['900',
#   '900',
#   '1170',
#   '500',
#   '900',
#   '720',
#   '540',
#   '900',
#   '500',
#   '450',
#   '400',
#   '800',
#   '750',
#   '600',
# ...

# %%
makaan44=pd.DataFrame(results44)
m44=m43.append(makaan44)
m44.shape
# Out:
# (780, 9)

# %%
url45="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=106"
wanted_list45=["2 BHK Apartment","Sector-18 Dwarka, Delhi","1200","Ready to move","2 Bathrooms", "1.2 Cr"]
result45=scraper.build(url45,wanted_list45)
print(result45)

scraper.get_result_similar(url45,grouped=True)
# Out:
# ['2 BHK Apartment', '4 BHK Apartment in CGHS Shakti Apartments', '3 BHK Apartment in CGHS Bank Vihar Apartments', '3 BHK Apartment', '4 BHK Apartment in Reputed Builder The New Rajput', '3 BHK Apartment in Cooperative Group Bhrigu Apartments', '3 BHK Apartment in Reputed Builder Sri Vinayak Apartment', '4 BHK Apartment in CGHS Sanchar Vihar Apartments', '3 BHK Apartment in CGHS Roop Villa Apartment', '3 BHK Apartment in CGHS Himalayan Residency', '3 BHK Apartment in CGHS Fakhruddin Apartment', '3 BHK Apartment in CGHS Ashadeep Apartment', '3 BHK Apartment in Swaraj Homes Him Hit Sadbhavna Apartments', '4 BHK Apartment in Reputed Builder Gulistan Residency', '3 BHK Apartment in CGHS Sarve Sanjhi Apartments', '3 BHK Apartment in Reputed Builder The Ishwar Apartments', '3 BHK Apartment in CGHS Hum Sub Apartment', 'Sector-18 Dwarka, Delhi', 'CGHS Shakti Apartments,Sector 5 Dwarka, Delhi', 'CGHS Bank Vihar Apartments,Sector 22 Dwarka, Delhi', 'Sector 10 Dwarka, Delhi', 'Reputed Builder Th
# ...

# %%
scraper.set_rule_aliases({'rule_lqog':'Title','rule_e887':'Area','rule_e5dw':'Status','rule_0x7q':'Price'})
scraper.keep_rules(['rule_lqog','rule_e887','rule_e5dw','rule_0x7q'])
scraper.save('makaan-search')
results45=scraper.get_result_similar(url45,group_by_alias=True)
results45
# Out:
# {'Title': ['3 BHK Apartment in CGHS Solomon Heights',
#   '3 BHK Apartment in CGHS Himalayan Residency',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment in CGHS Dream Apartments',
#   '3 BHK Apartment in Swaraj Homes Him Hit Sadbhavna Apartments',
#   '3 BHK Apartment in Reputed Builder Air India Apartment',
#   '2 BHK Apartment in Reputed Builder Nishat Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment in CGHS Sarve Sanjhi Apartments',
#   '3 BHK Apartment in Reputed Builder The Ishwar Apartments',
#   '3 BHK Apartment in CGHS Hum Sub Apartment',
#   '3 BHK Apartment in Reputed Builder Beverly Park Apartments',
#   '4 BHK Apartment in CGHS Mandakini Apartment',
#   '3 BHK Apartment in Reputed Builder Kaveri Apartment',
#   '3 BHK Apartment in CGHS Roop Villa Apartment',
#   '4 BHK Apartment in CGHS The Eligible',
#   '3 BHK Apartment in Reputed Builder Shivani Apartment',
#   '3 BHK Apartment in Reputed Builder Highland Apartment',
#   '3 BHK Apartment'],
# ...

# %%
makaan45=pd.DataFrame(results45)
m45=m44.append(makaan45)
m45.shape
# Out:
# (800, 9)

# %%
m45.tail()
# Out:
#     Unnamed: 0  Unnamed: 0.1  \
# 15         NaN           NaN
# 16         NaN           NaN
# 17         NaN           NaN
# 18         NaN           NaN
# 19         NaN           NaN
#
#                                                 Title Location  Area  \
# 15       3 BHK Apartment in CGHS Roop Villa Apartment      NaN  1700
# 16               4 BHK Apartment in CGHS The Eligible      NaN  2400
# 17  3 BHK Apartment in Reputed Builder Shivani Apa...      NaN  1750
# 18  3 BHK Apartment in Reputed Builder Highland Ap...      NaN  1700
# 19                                    3 BHK Apartment      NaN  1750
#
#            Status    Price Year Bathroom
# 15  Ready to move  1.76 Cr  NaN      NaN
# 16  Ready to move  2.55 Cr  NaN      NaN
# 17  Ready to move   1.9 Cr  NaN      NaN
# 18  Ready to move  1.65 Cr  NaN      NaN
# 19  Ready to move  1.45 Cr  NaN      NaN

# %%
m45.to_csv("Makaan_WebScraped1.csv")

# %%
df=pd.read_csv("Makaan_WebScraped1.csv")
df.head()
# Out:
#                      Title              Location    Area         Status  \
# 0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925.0  Ready to move
# 1          1 BHK Apartment    Khera Khurd, Delhi   450.0  Ready to move
# 2  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0  Ready to move
# 3  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0  Ready to move
# 4  4 BHK Independent Floor  Paschim Vihar, Delhi  2250.0  Ready to move
#
#      Price Year Bathroom
# 0   8.5 Cr  NaN      NaN
# 1    9.5 L  NaN      NaN
# 2  2.35 Cr  NaN      NaN
# 3   2.4 Cr  NaN      NaN
# 4  2.35 Cr  NaN      NaN

# %%
url46="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=112"
wanted_list46=["4 BHK Apartment","Sector 22 Dwarka, Delhi","2400","Ready to move", "1.75 Cr"]
result46=scraper.build(url46,wanted_list46)
print(result46)

scraper.get_result_similar(url46,grouped=True)
# Out:
# ['4 BHK Apartment in CGHS Udyog Vihar', '4 BHK Apartment in Reputed Builder Chandralook Apartments', '3 BHK Apartment in Reputed Builder Sri Vinayak Apartment', '3 BHK Apartment in Reputed Builder Prodhyogiki Apartments', '3 BHK Apartment in CGHS Philips Towers', '3 BHK Apartment in CGHS PNB Employees Apartment', '3 BHK Apartment', '3 BHK Apartment in Reputed Builder Karor Society', '2 BHK Independent Floor', '4 BHK Apartment in Reputed Builder Meera Bai Apartments', '4 BHK Apartment', '3 BHK Independent Floor', '2 BHK Apartment in Guru Ji Homes', '1 BHK Apartment in Guru Ji Homes 3', '1 BHK Apartment in Guru Ji Affordable And Luxury Homes', '3 BHK Apartment in Guru Ji Affordable And Luxury Homes', '2 BHK Apartment in Guru Ji Affordable And Luxury Homes', '2 BHK Apartment in Guru Ji Homes Part 1', '2 BHK Apartment', '1 BHK Apartment', 'Sector 22 Dwarka, Delhi', 'Sector 19 Dwarka, Delhi', 'Sector 3 Dwarka, Delhi', 'Sector 23 Dwarka, Delhi', 'Sector 4 Dwarka, Delhi', 'Sector 7 Dwarka, 
# ...

# %%
scraper.set_rule_aliases({'rule_i08g':'Title','rule_iwdb':'Location','rule_p00b':'Area','rule_a5h5':'Status','rule_cqhu':'Price'})
scraper.keep_rules(['rule_i08g','rule_iwdb','rule_p00b','rule_a5h5','rule_cqhu'])
scraper.save('makaan-search')
results46=scraper.get_result_similar(url46,group_by_alias=True)
results46
# Out:
# {'Title': ['2 BHK Apartment',
#   '3 BHK Apartment in CGHS Royal Residency',
#   '3 BHK Apartment in Reputed Builder Pushpanjali Apartment',
#   '3 BHK Apartment in CGHS National Apartment',
#   '3 BHK Apartment in Reputed Builder Heritage Tower',
#   '4 BHK Apartment in CGHS Udyog Vihar',
#   '4 BHK Apartment in Reputed Builder Chandralook Apartments',
#   '3 BHK Apartment in Reputed Builder Sri Vinayak Apartment',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '4 BHK Apartment in Reputed Builder Meera Bai Apartments',
#   '4 BHK Apartment',
#   '3 BHK Independent Floor',
#   '2 BHK Apartment in Guru Ji Homes',
#   '1 BHK Apartment in Guru Ji Homes 3',
#   '1 BHK Apartment in Guru Ji Affordable And Luxury Homes',
#   '3 BHK Apartment in Guru Ji Affordable And Luxury Homes',
#   '2 BHK Apartment in Guru Ji Affordable And Luxury Homes',
#   '2 BHK Apartment in Guru Ji Homes Part 1',
#   '2 BHK Apartment in Guru Ji Homes'],
#  'Location': ['Sector-18 Dwarka, Delhi',
# ...

# %%
makaan46=pd.DataFrame(results46)
m46=df.append(makaan46)
m46.shape
# Out:
# (820, 7)

# %%
url47="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=113"
wanted_list47=["2 BHK Independent Floor","Dwarka Mor, Delhi","550","Ready to move", "29 L"]
result47=scraper.build(url47,wanted_list47)
print(result47)

scraper.get_result_similar(url47,grouped=True)
# Out:
# ['2 BHK Independent Floor', '3 BHK Apartment', '2 BHK Apartment', '4 BHK Apartment', '1 BHK Apartment', 'Dwarka Mor, Delhi', 'Uttam Nagar, Delhi', '550', '850', '520', '500', '1175', '770', '425', '525', '560', '620', '450', '750', '530', '510', 'Ready to move', '29 L', '45 L', '19.5 L', '20.5 L', '75 L', '40 L', '15.5 L', '22.75 L', '27.5 L', '32 L', '22.5 L', '18 L', '33 L', '22.11 L', '21.5 L', '20 L', '22 L', '21 L']
# {'rule_y3mn': ['2 BHK Independent Floor',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '1 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '1 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment'],
#  'rule_8gwv': ['Dwarka Mor, Delhi',
#   'Dwarka Mor, Delhi',
#   'Dwarka Mor, Delhi',
# ...

# %%
scraper.set_rule_aliases({'rule_y3mn':'Title','rule_8gwv':'Location','rule_esfp':'Area','rule_abka':'Status','rule_1q7p':'Price'})
scraper.keep_rules(['rule_y3mn','rule_8gwv','rule_esfp','rule_abka','rule_1q7p'])
scraper.save('makaan-search')
results47=scraper.get_result_similar(url47,group_by_alias=True)
results47
# Out:
# {'Title': ['2 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '4 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '1 BHK Apartment',
#   '1 BHK Apartment',
#   '1 BHK Apartment',
#   '1 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Independent Floor',
#   '2 BHK Apartment'],
#  'Location': ['Dwarka Mor, Delhi',
#   'Dwarka Mor, Delhi',
#   'Dwarka Mor, Delhi',
#   'Dwarka Mor, Delhi',
#   'Dwarka Mor, Delhi',
#   'Dwarka Mor, Delhi',
#   'Dwarka Mor, Delhi',
#   'Dwarka Mor, Delhi',
#   'Dwarka Mor, Delhi',
#   'Dwarka Mor, Delhi',
#   'Uttam Nagar, Delhi',
#   'Uttam Nagar, Delhi',
#   'Uttam Nagar, Delhi',
#   'Uttam Nagar, Delhi',
#   'Uttam Nagar, Delhi',
#   'Uttam Nagar, Delhi',
#   'Uttam Nagar, Delhi',
#   'Dwarka Mor, Delhi',
#   'Dwarka Mor, Delhi',
#   'Dwarka Mor, Delhi'],
# ...

# %%
makaan47=pd.DataFrame(results47)
m47=m46.append(makaan47)
m47.duplicated().sum()
# Out:
# 31

# %%
url48="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=114"
wanted_list48=["2 BHK Apartment","Dwarka Mor, Delhi","550","Ready to move", "22 L"]
result48=scraper.build(url48,wanted_list48)
print(result48)

scraper.get_result_similar(url48,grouped=True)
# Out:
# ['2 BHK Apartment', '3 BHK Apartment', '1 BHK Apartment', '2 BHK Independent Floor', '3 BHK Independent Floor', '4 BHK Apartment', 'Dwarka Mor, Delhi', 'Lajpat Nagar, Delhi', 'Saket, Delhi', 'Malviya Nagar, Delhi', 'Sector 19 Dwarka, Delhi', 'Bharat Vihar, Delhi', 'Sector-18 Dwarka, Delhi', 'Sector 23 Dwarka, Delhi', '550', '510', '750', '530', '420', '410', '520', '900', '1350', '1800', '1600', '1500', '2400', '760', '1700', 'Ready to move', 'Under Construction', '22 L', '22.11 L', '37 L', '23.51 L', '24 L', '16.5 L', '16 L', '21 L', '1.35 Cr', '2.6 Cr', '3.25 Cr', '3.8 Cr', '1.65 Cr', '2.5 Cr', '1.45 Cr', '2 Cr', '2.35 Cr', '40 L', '1.55 Cr']
# {'rule_tkg2': ['2 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '1 BHK Apartment',
#   '1 BHK Apartment',
#   '1 BHK Apartment',
#   '1 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
# ...

# %%
scraper.set_rule_aliases({'rule_tkg2':'Title','rule_6g7j':'Location','rule_rfyc':'Area','rule_fb5s':'Status','rule_bdp8':'Price'})
scraper.keep_rules(['rule_tkg2','rule_6g7j','rule_rfyc','rule_fb5s','rule_bdp8'])
scraper.save('makaan-search')
results48=scraper.get_result_similar(url48,group_by_alias=True)
results48
# Out:
# {'Title': ['2 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '1 BHK Apartment',
#   '1 BHK Apartment',
#   '1 BHK Apartment',
#   '1 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Independent Floor',
#   '4 BHK Apartment',
#   '3 BHK Independent Floor',
#   '3 BHK Apartment',
#   '2 BHK Apartment'],
#  'Location': ['Dwarka Mor, Delhi',
#   'Uttam Nagar, Delhi',
#   'Uttam Nagar, Delhi',
#   'Uttam Nagar, Delhi',
#   'Uttam Nagar, Delhi',
#   'Uttam Nagar, Delhi',
#   'Uttam Nagar, Delhi',
#   'Uttam Nagar, Delhi',
#   'Lajpat Nagar, Delhi',
#   'Lajpat Nagar, Delhi',
#   'Lajpat Nagar, Delhi',
#   'Lajpat Nagar, Delhi',
#   'Lajpat Nagar, Delhi',
#   'Saket, Delhi',
#   'Saket, Delhi',
#   'Malviya Nagar, Delhi',
#   'Sector 19 Dwarka, Delhi',
# ...

# %%
makaan48=pd.DataFrame(results48)
m48=m47.append(makaan48)
m48.shape
# Out:
# (860, 7)

# %%
url49="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=115"
wanted_list49=["3 BHK Apartment","Sector 23 Dwarka, Delhi","1700","Ready to move","3 Bathrooms", "1.45 Cr"]
result49=scraper.build(url49,wanted_list49)
print(result49)

scraper.get_result_similar(url49,grouped=True)
# Out:
# ['3 BHK Apartment', '4 BHK Apartment', '3 BHK Apartment in Reputed Builder DJA Apartment', '3 BHK Apartment in CGHS Palm Court Apartment', '3 BHK Apartment in Reputed Builder Rajasthan Apartments', '3 BHK Apartment in Reputed Builder Shivani Apartment', '4 BHK Apartment in CGHS Dream Apartments', '4 BHK Apartment in CGHS ShivLok Apartment', '3 BHK Apartment in Swaraj Homes Mothers Apartment', '3 BHK Apartment in CGHS Shakti Apartments', '3 BHK Apartment in Reputed Builder United Friends', '3 BHK Apartment in CGHS Sarve Sanjhi Apartments', '3 BHK Apartment in Manchanda Brahma Apartments', '3 BHK Apartment in Reputed Builder Gulmohar Apartment', '3 BHK Apartment in CGHS Shubham Apartments', '3 BHK Apartment in CGHS Evergreen Apartment', 'Reputed Builder DJA Apartment,Sector 13 Dwarka, Delhi', 'Sector-18 Dwarka, Delhi', 'CGHS Palm Court Apartment,Sector 19 Dwarka, Delhi', 'Reputed Builder Rajasthan Apartments,Sector 4 Dwarka, Delhi', 'Sector 23 Dwarka, Delhi', 'Reputed Builder Shivani A
# ...

# %%
scraper.set_rule_aliases({'rule_3t7l':'Title','rule_ozsf':'Area','rule_2pvx':'Status','rule_szoe':'Bathroom','rule_dx1g':'Price'})
scraper.keep_rules(['rule_3t7l','rule_ozsf','rule_2pvx','rule_szoe','rule_dx1g'])
scraper.save('makaan-search')
results49=scraper.get_result_similar(url49,group_by_alias=True)
results49
# Out:
# {'Title': ['3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment'],
#  'Area': ['1800',
#   '1700',
#   '1750',
#   '1700',
#   '1750',
#   '1700',
#   '1700',
#   '1700',
#   '1700',
#   '1750',
#   '1800',
#   '1700',
#   '1700',
#   '1200',
#   '2400',
#   '2400',
#   '2600',
#   '1700',
#   '1750',
#   '1700'],
#  'Status': ['Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
# ...

# %%
makaan49=pd.DataFrame(results49)
m49=m48.append(makaan49)
m49.shape
# Out:
# (880, 7)

# %%
url50="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=116"
wanted_list50=["2 BHK Apartment","Sector 12 Dwarka, Delhi","1200","Ready to move","2 Bathrooms", "1.4 Cr"]
result50=scraper.build(url50,wanted_list50)
print(result50)

scraper.get_result_similar(url50,grouped=True)
# Out:
# ['2 BHK Apartment', '3 BHK Apartment', '4 BHK Apartment', '4 BHK Independent Floor', '3 BHK Independent Floor', '2 BHK Apartment in Reputed Builder Classic Apartment', '3 BHK Apartment in CGHS Fakhruddin Apartment', '3 BHK Apartment in Reputed Builder Swami Dayanand', '3 BHK Apartment in CGHS NPSC Apartment', '3 BHK Apartment in CGHS Azad Hind', '3 BHK Apartment in Reputed Builder Mahabhadrakali Apartments', '2 BHK Apartment in Guru Ji Homes', 'Sector 12 Dwarka, Delhi', 'Sector-18 Dwarka, Delhi', 'Sector 10 Dwarka, Delhi', 'Sector 23 Dwarka, Delhi', 'Sector 6 Dwarka, Delhi', 'Sector 2 Dwarka, Delhi', 'Sector 9 Dwarka, Delhi', 'Sector 13 Dwarka, Delhi', 'Vasant Kunj, Delhi', 'Greater Kailash, Delhi', 'Tri Nagar, Delhi', 'Ashok Vihar, Delhi', 'Sector 25 Rohini, Delhi', 'Sector 4 Dwarka, Delhi', 'Shahdara, Delhi', 'Dwarka Mor, Delhi', '1200', '1700', '2600', '1750', '2000', '1400', '5400', '450', '1710', '900', '1100', '540', 'Ready to move', 'Under Construction', '2 Bathrooms', '6 - 7 
# ...

# %%
scraper.set_rule_aliases({'rule_2skj':'Title','rule_gq54':'Location','rule_6rmc':'Area','rule_qm6o':'Status','rule_wgek':'Bathroom','rule_4q9q':'Price'})
scraper.keep_rules(['rule_2skj','rule_gq54','rule_6rmc','rule_qm6o','rule_wgek','rule_4q9q'])
scraper.save('makaan-search')
results50=scraper.get_result_similar(url50,group_by_alias=True)
results50
# Out:
# {'Title': ['2 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '4 BHK Independent Floor',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Apartment',
#   '3 BHK Independent Floor',
#   '2 BHK Apartment'],
#  'Location': ['Sector 7 Dwarka, Delhi',
#   'Sector 13 Dwarka, Delhi',
#   'Sector-18 Dwarka, Delhi',
#   'Sector 19 Dwarka, Delhi',
#   'Sector 19 Dwarka, Delhi',
#   'Sector 9 Dwarka, Delhi',
#   'Sector 4 Dwarka, Delhi',
#   'Sector-18 Dwarka, Delhi',
#   'Sector 10 Dwarka, Delhi',
#   'Vasant Kunj, Delhi',
#   'Vasant Kunj, Delhi',
#   'Greater Kailash, Delhi',
#   'Sector 12 Dwarka, Delhi',
#   'Tri Nagar, Delhi',
#   'Ashok Vihar, Delhi',
#   'Sector 25 Rohini, Delhi',
# ...

# %%
makaan50=pd.DataFrame(results50)
m50=m49.append(makaan50)
m50.duplicated().sum()
# Out:
# 40

# %%
m50.shape
# Out:
# (900, 7)

# %%
url51="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=117"
wanted_list51=["3 BHK Apartment","Dwarka Mor, Delhi","1050","Ready to move", "60 L"]
result51=scraper.build(url51,wanted_list51)
print(result51)

scraper.get_result_similar(url51,grouped=True)
# Out:
# ['3 BHK Apartment', '2 BHK Apartment', '2 BHK Independent Floor', '4 BHK Independent Floor', 'Residential Plot', 'Khatushhyam The Home,Dwarka Mor, Delhi', 'Dwarka Mor, Delhi', 'Lajpat Nagar, Delhi', 'Sector 8 Dwarka, Delhi', 'Najafgarh, Delhi', 'Bharat Vihar, Delhi', 'Dwarka Sector 15, Delhi', 'Suraj Vihar, Delhi', '1050', '660', '775', '860', '910', '600', '550', '1000', '900', '1890', '1080', '14500', '2250', '747', '675', 'Ready to move', 'New', 'Resale', '60 L', '28 L', '35 L', '40 L', '45 L', '25 L', '23 L', '25.5 L', '48.5 L', '4.5 Cr', '4.52 Cr', '3.25 Cr', '9 Cr', '79 L', '2 Cr', '80 L', '4.25 Cr', '90 L']
# {'rule_ancb': ['3 BHK Apartment',
#   '2 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '4 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   'Residential Plot',
#   'Residential Plot',
#   'Residential Plot',
#   'Residential Plot',
#   'Residential Plot',
# ...

# %%
scraper.set_rule_aliases({'rule_ancb':'Title','rule_z8hz':'Area','rule_259u':'Status','rule_esm4':'Price'})
scraper.keep_rules(['rule_ancb','rule_z8hz','rule_259u','rule_esm4'])
scraper.save('makaan-search')
results51=scraper.get_result_similar(url51,group_by_alias=True)
results51
# Out:
# {'Title': ['2 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   'Residential Plot',
#   'Residential Plot',
#   'Residential Plot',
#   'Residential Plot',
#   'Residential Plot',
#   'Residential Plot',
#   'Residential Plot',
#   'Residential Plot',
#   'Residential Plot',
#   'Residential Plot',
#   'Residential Plot',
#   'Residential Plot'],
#  'Area': ['660',
#   '775',
#   '860',
#   '910',
#   '600',
#   '550',
#   '550',
#   '1000',
#   '900',
#   '1890',
#   '1080',
#   '14500',
#   '1080',
#   '2250',
#   '900',
#   '900',
#   '900',
#   '747',
#   '675',
#   '765'],
#  'Status': ['Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'New',
#   'Resale',
#   'Resale',
#   'New',
#   'New',
#   'New',
#   'New',
# ...

# %%
makaan51=pd.DataFrame(results51)
m51=m50.append(makaan51)
m51.duplicated().sum()
# Out:
# 41

# %%
url52="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=120"
wanted_list52=["1 BHK Independent Floor","Okhla Induatrial Area, Delhi","824","Under Construction", "2.45 Cr"]
result52=scraper.build(url52,wanted_list52)
print(result52)

scraper.get_result_similar(url52,grouped=True)
# Out:
# ['1 BHK Independent Floor', '2 BHK Independent Floor', '3 BHK Apartment', '3 BHK Independent Floor', '4 BHK Independent Floor', '2 BHK Independent Floor in Swaraj Homes RWA Lajpat Nagar 4 Colonies', '824', '765', '1118', '1050', '1150', '900', '700', '1450', '800', '550', '1800', '950', '650', 'Under Construction', 'Ready to move', '2.45 Cr', '33.5 L', '97 L', '50 L', '57 L', '1.22 Cr', '1.75 Cr', '1.35 Cr', '67 L', '1.8 Cr', '1.65 Cr', '80 L', '48 L', '65 L', '95 L', '1.42 Cr', '1.32 Cr', '53 L', '45.5 L']
# {'rule_h6at': ['1 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Apartment',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
# ...

# %%
scraper.set_rule_aliases({'rule_h6at':'Title','rule_ggaw':'Area','rule_9iqm':'Status','rule_i4xs':'Price'})
scraper.keep_rules(['rule_h6at','rule_ggaw','rule_9iqm','rule_i4xs'])
scraper.save('makaan-search')
results52=scraper.get_result_similar(url52,group_by_alias=True)
results52
# Out:
# {'Title': ['2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Apartment in Reputed Builder Hind Apartment'],
#  'Area': ['650',
#   '550',
#   '2250',
#   '650',
#   '550',
#   '700',
#   '550',
#   '700',
#   '1800',
#   '950',
#   '3600',
#   '2250',
#   '1100',
#   '1600',
#   '800',
#   '1200',
#   '2300',
#   '800',
#   '1650',
#   '1750'],
#  'Status': ['Under Construction',
#   'Ready to move',
#   'Ready to move',
#   'Under Construction',
# ...

# %%
makaan52=pd.DataFrame(results52)
m52=m51.append(makaan52)
m52.duplicated().sum()
# Out:
# 42

# %%
url53="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=121"
wanted_list53=["3 BHK Apartment","Sector 4 Dwarka, Delhi","1700","Ready to move", "1.7 Cr"]
result53=scraper.build(url53,wanted_list53)
print(result53)

scraper.get_result_similar(url53,grouped=True)
# Out:
# ['3 BHK Apartment', '4 BHK Apartment', '2 BHK Apartment', '3 BHK Apartment in Swaraj Homes Jai Maa Kalyani Apartment', '3 BHK Apartment in Reputed Builder Sukh Sagar Apartments', '3 BHK Apartment in Reputed Builder Kaveri Apartment', '3 BHK Apartment in CGHS Sahita Apartment', '4 BHK Apartment in CGHS Sanchar Vihar Apartments', '3 BHK Apartment in CGHS Sarve Sanjhi Apartments', '3 BHK Apartment in Reputed Builder Hind Apartment', '3 BHK Apartment in Reputed Builder Vidya Sagar Apartments', '3 BHK Apartment in CGHS Roop Villa Apartment', '4 BHK Apartment in Reputed Builder Vishrantika', '3 BHK Apartment in CGHS Bank Vihar Apartments', '3 BHK Apartment in DDA Kautilya Apartment', '3 BHK Apartment in CGHS Dream Apartments', '4 BHK Apartment in Reputed Builder Sapna Ghar Apartment', 'Sector 4 Dwarka, Delhi', 'Sector 9 Dwarka, Delhi', 'Sector 6 Dwarka, Delhi', 'Sector 11 Dwarka, Delhi', 'Sector-18 Dwarka, Delhi', 'Sector 5 Dwarka, Delhi', 'Sector 7 Dwarka, Delhi', 'Sector 19 Dwarka, Delhi
# ...

# %%
scraper.set_rule_aliases({'rule_f1xg':'Title','rule_b9ec':'Area','rule_u7sa':'Status','rule_n9e8':'Price'})
scraper.keep_rules(['rule_f1xg','rule_b9ec','rule_u7sa','rule_n9e8'])
scraper.save('makaan-search')
results53=scraper.get_result_similar(url53,group_by_alias=True)
results53
# Out:
# {'Title': ['3 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '2 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment'],
#  'Area': ['1700',
#   '1750',
#   '2400',
#   '1200',
#   '2400',
#   '1700',
#   '1800',
#   '2400',
#   '1700',
#   '1700',
#   '1700',
#   '2400',
#   '1700',
#   '2400',
#   '2400',
#   '1700',
#   '2200',
#   '1700',
#   '1750',
#   '2400'],
#  'Status': ['Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
# ...

# %%
makaan53=pd.DataFrame(results53)
m53=m52.append(makaan53)
m53.duplicated().sum()
# Out:
# 46

# %%
url55="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=122"
wanted_list55=["3 BHK Apartment","Sector 5 Dwarka, Delhi","1750","Ready to move","3 Bathrooms", "1.75 Cr"]
result55=scraper.build(url55,wanted_list55)
print(result55)

scraper.get_result_similar(url55,grouped=True)
# Out:
# ['1 BHK Apartment', '3 BHK Apartment', '2 BHK Independent Floor', '2 BHK Apartment', '4 BHK Apartment', '1 BHK Apartment in Reputed Builder Harsh Apartment', '1 BHK Apartment in DDA Flats Sector 14', '3 BHK Apartment in Reputed Builder Manglik Appartment', '3 BHK Apartment in CGHS PNB Employees Apartment', '3 BHK Apartment in CGHS Dakshinayan Apartments', '3 BHK Apartment in Swaraj Homes Batukji Apartments CGHS', '2 BHK Apartment in Reputed Builder Classic Apartment', '3 BHK Apartment in Reputed Builder Great India Apartments', '3 BHK Apartment in Reputed Builder Kaveri Apartment', '3 BHK Apartment in Reputed Builder Shiv Shakti', '3 BHK Apartment in Reputed Builder Maharani Aventi Bai', '3 BHK Apartment in Guru Ji Infratech 1', 'Reputed Builder Harsh Apartment,Sector 10 Dwarka, Delhi', 'Sector 5 Dwarka, Delhi', 'DDA Flats Sector 14,Sector 14 Dwarka, Delhi', 'Reputed Builder Manglik Appartment,Sector 6 Dwarka, Delhi', 'CGHS PNB Employees Apartment,Sector 4 Dwarka, Delhi', 'CGHS Daksh
# ...

# %%
scraper.set_rule_aliases({'rule_lwsi':'Title','rule_70yy':'Area','rule_y1kb':'Status','rule_siz4':'Bathroom','rule_kkf2':'Price'})
scraper.keep_rules(['rule_lwsi','rule_70yy','rule_y1kb','rule_siz4','rule_kkf2'])
scraper.save('makaan-search')
results55=scraper.get_result_similar(url55,group_by_alias=True)
results55
# Out:
# {'Title': ['3 BHK Apartment',
#   '1 BHK Apartment',
#   '3 BHK Apartment',
#   '1 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment'],
#  'Area': ['1750',
#   '800',
#   '1700',
#   '550',
#   '1700',
#   '1700',
#   '900',
#   '900',
#   '1650',
#   '1600',
#   '1250',
#   '1700',
#   '1600',
#   '2600',
#   '2400',
#   '1700',
#   '1600',
#   '1700',
#   '1000',
#   '900'],
#  'Status': ['Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
# ...

# %%
makaan55=pd.DataFrame(results55)
m55=m53.append(makaan55)
m55.duplicated().sum()
# Out:
# 47

# %%
url56="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=124"
wanted_list56=["3 BHK Apartment","Sector 5 Dwarka, Delhi","1750","Ready to move", "1.75 Cr"]
result56=scraper.build(url56,wanted_list56)
print(result56)

scraper.get_result_similar(url56,grouped=True)
# Out:
# ['3 BHK Apartment', '4 BHK Apartment', '2 BHK Apartment', '2 BHK Independent Floor', '3 BHK Apartment in Swaraj Homes Mothers Apartment', '3 BHK Apartment in CGHS Sahita Apartment', '4 BHK Apartment in CGHS Dream Apartments', '4 BHK Apartment in CGHS Chitrakoot Apartments', '3 BHK Apartment in CGHS Bank Vihar Apartments', '2 BHK Apartment in DDA Rosewood Apartment', '4 BHK Apartment in Reputed Builder Classic Apartment', '3 BHK Apartment in Trishul Anant Apartments', 'Sector 5 Dwarka, Delhi', 'Sector 4 Dwarka, Delhi', 'Sector 22 Dwarka, Delhi', 'Sector 11 Dwarka, Delhi', 'Sector 12 Dwarka, Delhi', 'Sector 23 Dwarka, Delhi', 'Sector 13 Dwarka, Delhi', 'Dwarka Mor, Delhi', 'Lajpat Nagar, Delhi', 'Dwarka Sector 15, Delhi', '1750', '2400', '1700', '1200', '900', '650', 'Ready to move', 'Under Construction', '1.75 Cr', '2.1 Cr', '1.8 Cr', '2.75 Cr', '1.95 Cr', '2.25 Cr', '3.1 Cr', '1.45 Cr', '1.52 Cr', '1.05 Cr', '2.5 Cr', '1.65 Cr', '1.6 Cr', '1.46 Cr', '1.47 Cr', '1.5 Cr', '40 L']
# ...

# %%
scraper.set_rule_aliases({'rule_dx7y':'Title','rule_eucf':'Location','rule_26nz':'Area','rule_6miu':'Status','rule_5nxu':'Price'})
scraper.keep_rules(['rule_dx7y','rule_eucf','rule_26nz','rule_6miu','rule_5nxu'])
scraper.save('makaan-search')
results56=scraper.get_result_similar(url56,group_by_alias=True)
results56
# Out:
# {'Title': ['3 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor'],
#  'Location': ['Sector 5 Dwarka, Delhi',
#   'Sector 4 Dwarka, Delhi',
#   'Sector 4 Dwarka, Delhi',
#   'Sector 22 Dwarka, Delhi',
#   'Sector 11 Dwarka, Delhi',
#   'Sector 22 Dwarka, Delhi',
#   'Sector 12 Dwarka, Delhi',
#   'Sector 23 Dwarka, Delhi',
#   'Sector 22 Dwarka, Delhi',
#   'Sector 13 Dwarka, Delhi',
#   'Sector 22 Dwarka, Delhi',
#   'Dwarka Mor, Delhi',
#   'Lajpat Nagar, Delhi',
#   'Lajpat Nagar, Delhi',
#   'Lajpat Nagar, Delhi',
# ...

# %%
makaan56=pd.DataFrame(results56)
m56=m55.append(makaan56)
m56.duplicated().sum()
# Out:
# 49

# %%
url57="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=125"
wanted_list57=["4 BHK Apartment","Sector 19 Dwarka, Delhi","2400","Ready to move","4 Bathrooms", "2.38 Cr"]
result57=scraper.build(url57,wanted_list57)
print(result57)

scraper.get_result_similar(url57,grouped=True)
# Out:
# ['2 BHK Apartment', '3 BHK Apartment', '4 BHK Apartment', '1 BHK Apartment', '2 BHK Independent Floor', '1 BHK Independent House', '3 BHK Independent Floor', 'Sector 12 Dwarka, Delhi', 'Sector 5 Dwarka, Delhi', 'Sector 2 Dwarka, Delhi', 'Sector 7 Dwarka, Delhi', 'Sector 19 Dwarka, Delhi', 'Sector 14 Dwarka, Delhi', 'Sector 8 Dwarka, Delhi', 'Vasant Kunj, Delhi', 'Sector 3 Rohini, Delhi', 'Razapur Khurd, Delhi', 'Sector 11 Dwarka, Delhi', 'Sector 4 Dwarka, Delhi', 'Sector 3 Dwarka, Delhi', '1200', '1750', '1700', '2400', '640', '720', '1100', '350', '1500', '900', '1800', '1300', '850', '2200', '1690', 'Ready to move', '2 Bathrooms', '6 - 7 years old', '13 - 14 years old', '3 Bathrooms', '4 Bathrooms', '20 - 21 years old', '3 - 4 years old', '4 - 5 years old', '17 - 18 years old', '14 - 15 years old', '1.4 Cr', '2.25 Cr', '1.88 Cr', '1.98 Cr', '2.05 Cr', '2.38 Cr', '47 L', '50 L', '2.8 Cr', '60 L', '2.4 Cr', '46 L', '1.8 Cr', '1.1 Cr', '65 L', '2.18 Cr', '1.95 Cr', '1.6 Cr', '1.75 Cr'
# ...

# %%
scraper.set_rule_aliases({'rule_stob':'Title','rule_14ve':'Location','rule_wpr0':'Area','rule_85yt':'Status','rule_rnr3':'Price'})
scraper.keep_rules(['rule_stob','rule_14ve','rule_wpr0''rule_85yt','rule_rnr3'])
scraper.save('makaan-search')
results57=scraper.get_result_similar(url57,group_by_alias=True)
results57
# Out:
# {'Title': ['2 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '2 BHK Independent Floor',
#   '1 BHK Apartment',
#   '3 BHK Apartment',
#   '1 BHK Independent House',
#   '3 BHK Apartment',
#   '3 BHK Independent Floor',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Independent Floor',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment'],
#  'Location': ['Sector 12 Dwarka, Delhi',
#   'Sector 5 Dwarka, Delhi',
#   'Sector 2 Dwarka, Delhi',
#   'Sector 7 Dwarka, Delhi',
#   'Sector 5 Dwarka, Delhi',
#   'Sector 19 Dwarka, Delhi',
#   'Sector 8 Dwarka, Delhi',
#   'Sector 14 Dwarka, Delhi',
#   'Vasant Kunj, Delhi',
#   'Sector 3 Rohini, Delhi',
#   'Vasant Kunj, Delhi',
#   'Razapur Khurd, Delhi',
#   'Sector 5 Dwarka, Delhi',
#   'Sector 11 Dwarka, Delhi',
#   'Sector 19 Dwarka, Delhi',
#   'Sector 19 Dwarka, Delhi',
# ...

# %%
makaan57=pd.DataFrame(results57)
m57=m56.append(makaan57)
m57.duplicated().sum()
# Out:
# 49

# %%
url58="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=126"
wanted_list58=["2 BHK Apartment","Sector 19 Dwarka, Delhi","1500","Ready to move", "1.48 Cr"]
result58=scraper.build(url58,wanted_list58)
print(result58)

scraper.get_result_similar(url58,grouped=True)
# Out:
# ['2 BHK Apartment', '4 BHK Apartment', '3 BHK Apartment', 'Sector 19 Dwarka, Delhi', 'Sector 5 Dwarka, Delhi', 'Sector 6 Dwarka, Delhi', 'Sector 23 Dwarka, Delhi', 'Sector 10 Dwarka, Delhi', 'Sector 13 Dwarka, Delhi', 'Sector 4 Dwarka, Delhi', 'Sector 22 Dwarka, Delhi', 'Sector 7 Dwarka, Delhi', 'Sector 11 Dwarka, Delhi', 'Sector 12 Dwarka, Delhi', '1500', '2000', '1400', '1800', '1700', '1200', '1650', '2200', '1300', '1600', 'Ready to move', '1.48 Cr', '2.2 Cr', '1.4 Cr', '1.61 Cr', '1.65 Cr', '1.16 Cr', '1.55 Cr', '1.95 Cr', '2.55 Cr', '1.85 Cr', '1.8 Cr', '1.69 Cr', '1.35 Cr', '1.3 Cr', '1.5 Cr']
# {'rule_9kkb': ['2 BHK Apartment',
#   '4 BHK Apartment',
#   '2 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
# ...

# %%
scraper.set_rule_aliases({'rule_9kkb':'Title','rule_xmat':'Location','rule_urik':'Area','rule_48g2':'Status','rule_ai2f':'Price'})
scraper.keep_rules(['rule_9kkb','rule_xmat','rule_urik','rule_48g2','rule_ai2f'])
scraper.save('makaan-search')
results58=scraper.get_result_similar(url58,group_by_alias=True)
results58
# Out:
# {'Title': ['2 BHK Apartment',
#   '4 BHK Apartment',
#   '2 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment'],
#  'Location': ['Sector 19 Dwarka, Delhi',
#   'Sector 5 Dwarka, Delhi',
#   'Sector 6 Dwarka, Delhi',
#   'Sector 23 Dwarka, Delhi',
#   'Sector 10 Dwarka, Delhi',
#   'Sector 13 Dwarka, Delhi',
#   'Sector 4 Dwarka, Delhi',
#   'Sector 5 Dwarka, Delhi',
#   'Sector 6 Dwarka, Delhi',
#   'Sector 22 Dwarka, Delhi',
#   'Sector 7 Dwarka, Delhi',
#   'Sector 11 Dwarka, Delhi',
#   'Sector 10 Dwarka, Delhi',
#   'Sector 10 Dwarka, Delhi',
#   'Sector 11 Dwarka, Delhi',
#   'Sector 5 Dwarka, Delhi',
# ...

# %%
makaan58=pd.DataFrame(results58)
m58=m57.append(makaan58)
m58.duplicated().sum()
# Out:
# 50

# %%
url59="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=127"
wanted_list59=["3 BHK Apartment","Sector 3 Dwarka, Delhi","1700","Ready to move","2 Bathrooms", "1.58 Cr"]
result59=scraper.build(url59,wanted_list59)
print(result59)

scraper.get_result_similar(url59,grouped=True)
# Out:
# ['3 BHK Apartment', '4 BHK Apartment', '2 BHK Independent Floor', '4 BHK Independent Floor', '3 BHK Independent Floor', 'Sector 3 Dwarka, Delhi', 'Sector 12 Dwarka, Delhi', 'Sector 4 Dwarka, Delhi', 'Sector 11 Dwarka, Delhi', 'Uttam Nagar, Delhi', 'Sector 22 Dwarka, Delhi', 'Sector 10 Dwarka, Delhi', 'Dwarka Mor, Delhi', 'Sector 5 Dwarka, Delhi', '1700', '2000', '2400', '1800', '1750', '540', '1600', '1400', '900', '750', 'Ready to move', '2 Bathrooms', '3 Bathrooms', '14 - 15 years old', '4 Bathrooms', '13 - 14 years old', '11 - 12 years old', '5 - 6 years old', '18 - 19 years old', 'Resale', 'New', '1.58 Cr', '1.73 Cr', '1.9 Cr', '2.99 Cr', '1.61 Cr', '1.83 Cr', '1.65 Cr', '35 L', '1.48 Cr', '1.7 Cr', '1.85 Cr', '1.5 Cr', '1.2 Cr', '55.5 L', '39.5 L', '1.95 Cr', '2.35 Cr', '2.9 Cr']
# {'rule_pmii': ['3 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
# ...

# %%
scraper.set_rule_aliases({'rule_pmii':'Title','rule_zhff':'Area','rule_mf5r':'Status','rule_gc5t':'Price'})
scraper.keep_rules(['rule_pmii','rule_zhff','rule_mf5r','rule_gc5t'])
scraper.save('makaan-search')
results59=scraper.get_result_similar(url59,group_by_alias=True)
results59
# Out:
# {'Title': ['2 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '2 BHK Independent Floor',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Independent Floor',
#   '3 BHK Apartment'],
#  'Area': ['1400',
#   '1800',
#   '1700',
#   '1200',
#   '1700',
#   '1800',
#   '1800',
#   '2000',
#   '540',
#   '1600',
#   '1700',
#   '1700',
#   '2400',
#   '1750',
#   '1800',
#   '1800',
#   '2400',
#   '1700',
#   '1400',
#   '1700'],
#  'Status': ['Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
# ...

# %%
makaan59=pd.DataFrame(results59)
m59=m58.append(makaan59)
m59.duplicated().sum()
# Out:
# 52

# %%
m59.to_csv("Raw_Makaan.com_Data.csv")

# %%
df1=pd.read_csv("Raw_Makaan.com_Data.csv")
df1.shape
df1.head()
# Out:
#    Unnamed: 0                    Title              Location    Area  \
# 0           0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925.0
# 1           1          1 BHK Apartment    Khera Khurd, Delhi   450.0
# 2           2  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0
# 3           3  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0
# 4           4  4 BHK Independent Floor  Paschim Vihar, Delhi  2250.0
#
#           Status    Price Year Bathroom
# 0  Ready to move   8.5 Cr  NaN      NaN
# 1  Ready to move    9.5 L  NaN      NaN
# 2  Ready to move  2.35 Cr  NaN      NaN
# 3  Ready to move   2.4 Cr  NaN      NaN
# 4  Ready to move  2.35 Cr  NaN      NaN

# %%
df=pd.read_csv("Cleaned_Makaan.com_Data.csv")
df.shape
df.head()
# Out:
#                      Title             Location1    Area         Status  \
# 0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925.0  Ready to move
# 1          1 BHK Apartment    Khera Khurd, Delhi   450.0  Ready to move
# 2  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0  Ready to move
# 3  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0  Ready to move
# 4  4 BHK Independent Floor  Paschim Vihar, Delhi  2250.0  Ready to move
#
#    Price Year Bathroom             Location
# 0   8.50  NaN      NaN  South/Central Delhi
# 1   9.50  NaN      NaN  South/Central Delhi
# 2   2.35  NaN      NaN  South/Central Delhi
# 3   2.40  NaN      NaN  South/Central Delhi
# 4   2.35  NaN      NaN  South/Central Delhi

# %%
df.duplicated().sum()
# Out:
# 70

# %%
df.duplicated().sum()
# Out:
# 60

# %%
url60="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=134"
wanted_list60=["3 BHK Apartment","Dwarka Mor, Delhi","720","Ready to move","2 Bathrooms", "35.5 L"]
result60=scraper.build(url60,wanted_list60)
print(result60)

scraper.get_result_similar(url60,grouped=True)
# Out:
# ['3 BHK Apartment', '2 BHK Independent Floor', 'Residential Plot', '4 BHK Independent Floor', '3 BHK Independent Floor', '3 BHK Apartment in Reputed Builder KM Apartment', 'Dwarka Mor, Delhi', 'Uttam Nagar, Delhi', 'Reputed Builder KM Apartment,Sector 12 Dwarka, Delhi', 'Dwarka Sector 15, Delhi', 'Sector 22 Rohini, Delhi', 'Sector 23 Rohini, Delhi', 'Rohini sector 24, Delhi', 'Sector 25 Rohini, Delhi', 'Sector 12 Dwarka, Delhi', 'Sector 26 Rohini, Delhi', 'Sector 21 Rohini, Delhi', '720', '600', '1800', '900', '2250', '2300', '700', '650', '3600', '680', '800', '1100', '550', 'Ready to move', 'New', '2 Bathrooms', '3 Bathrooms', 'West facing', '4 Bathrooms', '5 Bathrooms', '5 - 6 years old', '6 - 7 years old', '5 years old', '6 years old', '3 - 4 years old', '35.5 L', '31.5 L', '2.25 Cr', '79 L', '2.2 Cr', '2.4 Cr', '71 L', '2.05 Cr', '54 L', '4.4 Cr', '1.78 Cr', '52 L', '4.6 Cr', '72 L', '83 L', '42 L', '53 L', '70 L']
# {'rule_9vo2': ['3 BHK Apartment',
# ...

# %%
scraper.set_rule_aliases({'rule_9vo2':'Title','rule_kfog':'Area','rule_q7pa':'Status','rule_9l2c':'Price'})
scraper.keep_rules(['rule_9vo2','rule_kfog','rule_q7pa','rule_9l2c'])
scraper.save('makaan-search')
results60=scraper.get_result_similar(url60,group_by_alias=True)
results60
# Out:
# {'Title': ['3 BHK Apartment',
#   '2 BHK Independent Floor',
#   '3 BHK Apartment',
#   'Residential Plot',
#   '4 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor'],
#  'Area': ['720',
#   '600',
#   '1800',
#   '900',
#   '2250',
#   '2300',
#   '700',
#   '1800',
#   '650',
#   '3600',
#   '2300',
#   '1800',
#   '680',
#   '3600',
#   '800',
#   '1100',
#   '550',
#   '800',
#   '1800',
#   '800'],
#  'Status': ['Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'New',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
# ...

# %%
makaan60=pd.DataFrame(results60)
m60=df1.append(makaan60)
m60.shape
# Out:
# (1080, 8)

# %%
makaan600=pd.DataFrame(results60)
m600=df.append(makaan60)
m600.head()
# Out:
#                      Title             Location1    Area         Status Price  \
# 0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925.0  Ready to move   8.5
# 1          1 BHK Apartment    Khera Khurd, Delhi   450.0  Ready to move   9.5
# 2  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0  Ready to move  2.35
# 3  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0  Ready to move   2.4
# 4  4 BHK Independent Floor  Paschim Vihar, Delhi  2250.0  Ready to move  2.35
#
#   Year Bathroom             Location
# 0  NaN      NaN  South/Central Delhi
# 1  NaN      NaN  South/Central Delhi
# 2  NaN      NaN  South/Central Delhi
# 3  NaN      NaN  South/Central Delhi
# 4  NaN      NaN  South/Central Delhi

# %%
url61="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=135"
wanted_list61=["2 BHK Independent Floor","Sector 23 Rohini, Delhi","800","Ready to move", "57 L"]
result61=scraper.build(url61,wanted_list61)
print(result61)

scraper.get_result_similar(url61,grouped=True)
# Out:
# ['3 BHK Independent Floor', '4 BHK Independent Floor', '1 BHK Independent Floor', '2 BHK Independent Floor', '2 BHK Apartment in S Gambhir Premium Homes', '3 BHK Apartment in S Gambhir Premium Homes', 'Sector 23 Rohini, Delhi', 'Rohini sector 24, Delhi', 'Sector 25 Rohini, Delhi', 'Sector 26 Rohini, Delhi', 'Sector 22 Rohini, Delhi', 'Sector 3 Rohini, Delhi', 'Sector 28 Rohini, Delhi', 'Sector-29 Rohini, Delhi', 'Uttam Nagar, Delhi', 'Dwarka Mor, Delhi', '800', '1450', '400', '550', '1125', '1600', '1400', '650', '2300', '350', '700', '495', '855', '900', 'Ready to move', '57 L', '1.6 Cr', '27 L', '41 L', '1.18 Cr', '67 L', '2 Cr', '1.05 Cr', '26 L', '73 L', '48 L', '2.9 Cr', '1.75 Cr', '65 L', '25 L', '23 L', '45 L', '23.75 L', '60 L', '52.3 L']
# {'rule_w36o': ['3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '1 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
# ...

# %%
scraper.set_rule_aliases({'rule_w36o':'Title','rule_5csn':'Area','rule_b2ee':'Status','rule_wxpw':'Price'})
scraper.keep_rules(['rule_w36o','rule_5csn','rule_b2ee','rule_wxpw'])
scraper.save('makaan-search')
results61=scraper.get_result_similar(url61,group_by_alias=True)
results61
# Out:
# {'Title': ['3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '1 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '1 BHK Independent Floor',
#   '1 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Apartment in S Gambhir Premium Homes',
#   '2 BHK Apartment in S Gambhir Premium Homes',
#   '3 BHK Independent Floor'],
#  'Area': ['1100',
#   '800',
#   '550',
#   '800',
#   '1800',
#   '650',
#   '3600',
#   '680',
#   '400',
#   '550',
#   '1125',
#   '800',
#   '1600',
#   '1400',
#   '400',
#   '400',
#   '700',
#   '855',
#   '495',
#   '900'],
#  'Status': ['Ready to move',
#   'Ready to move',
#   'Ready to move',
#   'Ready to move',
# ...

# %%
makaan61=pd.DataFrame(results61)
m61=m60.append(makaan61)
m61.head()
# Out:
#                      Title             Location1    Area         Status Price  \
# 0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925.0  Ready to move   8.5
# 1          1 BHK Apartment    Khera Khurd, Delhi   450.0  Ready to move   9.5
# 2  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0  Ready to move  2.35
# 3  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0  Ready to move   2.4
# 4  4 BHK Independent Floor  Paschim Vihar, Delhi  2250.0  Ready to move  2.35
#
#   Year Bathroom             Location
# 0  NaN      NaN  South/Central Delhi
# 1  NaN      NaN  South/Central Delhi
# 2  NaN      NaN  South/Central Delhi
# 3  NaN      NaN  South/Central Delhi
# 4  NaN      NaN  South/Central Delhi

# %%
m61.shape
# Out:
# (1100, 8)

# %%
makaan610=pd.DataFrame(results61)
m610=m600.append(makaan61)
m610.tail()
# Out:
#                                          Title Location1 Area         Status  \
# 15                     1 BHK Independent Floor       NaN  400  Ready to move
# 16                     2 BHK Independent Floor       NaN  700  Ready to move
# 17  3 BHK Apartment in S Gambhir Premium Homes       NaN  855  Ready to move
# 18  2 BHK Apartment in S Gambhir Premium Homes       NaN  495  Ready to move
# 19                     3 BHK Independent Floor       NaN  900  Ready to move
#
#       Price Year Bathroom Location
# 15     23 L  NaN      NaN      NaN
# 16     45 L  NaN      NaN      NaN
# 17     60 L  NaN      NaN      NaN
# 18  23.75 L  NaN      NaN      NaN
# 19   52.3 L  NaN      NaN      NaN

# %%
url62="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=136"
wanted_list62=["3 BHK Apartment","Sector 7 Dwarka, Delhi","1700","Ready to move","3 Bathrooms", "1.75 Cr"]
result62=scraper.build(url62,wanted_list62)
print(result62)

scraper.get_result_similar(url62,grouped=True)
# Out:
# ['3 BHK Apartment', '4 BHK Apartment', '1 RK Studio Apartment', '1 BHK Independent Floor', '3 BHK Independent Floor', '2 BHK Independent Floor', 'Sector 7 Dwarka, Delhi', 'Sector 6 Dwarka, Delhi', 'Sector 5 Dwarka, Delhi', 'Sector 12 Dwarka, Delhi', 'Sector 10 Dwarka, Delhi', 'Sector 22 Dwarka, Delhi', 'laxmi nagar, Delhi', 'Dwarka Sector 15, Delhi', 'Uttam Nagar, Delhi', 'Sector 28 Rohini, Delhi', 'Dwarka Mor, Delhi', 'Rohini sector 24, Delhi', '1700', '1750', '2400', '1800', '330', '495', '810', '1150', '850', '750', '800', '550', '900', '650', 'Ready to move', 'Resale', '3 Bathrooms', '2 Bathrooms', '1 Bathrooms', 'New', '6 - 7 years old', '4 Bathrooms', '15 - 16 years old', '6 years old', '3 - 4 years old', '5 - 6 years old', '7 - 8 years old', '1.75 Cr', '2 Cr', '1.88 Cr', '2.1 Cr', '1.82 Cr', '1.7 Cr', '18 L', '18.5 L', '47.5 L', '65 L', '49.5 L', '40 L', '48 L', '48.5 L', '40.25 L', '28.5 L', '55.2 L', '21 L', '24.25 L', '1 Cr']
# {'rule_c1mc': ['3 BHK Apartment',
# ...

# %%
scraper.set_rule_aliases({'rule_c1mc':'Title','rule_kpbb':'Location1','rule_vwrp':'Area','rule_v30j':'Status','rule_53e7':'Price'})
scraper.keep_rules(['rule_c1mc','rule_kpbb','rule_vwrp','rule_v30j','rule_53e7'])
scraper.save('makaan-search')
results62=scraper.get_result_similar(url62,group_by_alias=True)
results62
# Out:
# {'Title': ['4 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '1 RK Studio Apartment',
#   '1 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor'],
#  'Location1': ['Sector 12 Dwarka, Delhi',
#   'Sector 5 Dwarka, Delhi',
#   'Sector 10 Dwarka, Delhi',
#   'Sector 22 Dwarka, Delhi',
#   'Sector 7 Dwarka, Delhi',
#   'Sector 6 Dwarka, Delhi',
#   'laxmi nagar, Delhi',
#   'Dwarka Sector 15, Delhi',
#   'Dwarka Sector 15, Delhi',
#   'Dwarka Sector 15, Delhi',
#   'Uttam Nagar, Delhi',
#   'Sector 28 Rohini, Delhi',
#   'Dwarka Mor, Delhi',
# ...

# %%
makaan62=pd.DataFrame(results62)
m62=m61.append(makaan62)
m62.tail()
# Out:
#                       Title                Location1 Area         Status  \
# 15  2 BHK Independent Floor       Uttam Nagar, Delhi  550  Ready to move
# 16  2 BHK Independent Floor       Uttam Nagar, Delhi  550  Ready to move
# 17  2 BHK Independent Floor       Uttam Nagar, Delhi  650  Ready to move
# 18  3 BHK Independent Floor  Rohini sector 24, Delhi  850  Ready to move
# 19  3 BHK Independent Floor       Uttam Nagar, Delhi  900  Ready to move
#
#       Price Year Bathroom Location
# 15   28.5 L  NaN      NaN      NaN
# 16     21 L  NaN      NaN      NaN
# 17  24.25 L  NaN      NaN      NaN
# 18     1 Cr  NaN      NaN      NaN
# 19   55.2 L  NaN      NaN      NaN

# %%
makaan620=pd.DataFrame(results62)
m620=m61.append(makaan62)
m620.head()
m620.shape
# Out:
# (1120, 8)

# %%
url63="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=137"
wanted_list63=["3 BHK Independent Floor","Uttam Nagar, Delhi","750","Ready to move","2 Bathrooms", "30 L"]
result63=scraper.build(url63,wanted_list63)
print(result63)

scraper.get_result_similar(url63,grouped=True)
# Out:
# ['3 BHK Apartment in Reputed Builder Katyayani Apartment', '3 BHK Apartment in CGHS Roop Villa Apartment', '3 BHK Apartment in CGHS Evergreen Apartment', '3 BHK Apartment in CGHS Chopra Apartment', '3 BHK Apartment in Reputed Builder Vidya Sagar Apartments', '3 BHK Apartment in Reputed Builder DJA Apartment', '3 BHK Independent Floor', '2 BHK Independent Floor in Ashima Ashima Floors - 7', '2 BHK Independent Floor', '3 BHK Apartment', '4 BHK Apartment in Reputed Builder Sapna Ghar Apartment', '3 BHK Apartment in DDA Sanskriti Apartments', '3 BHK Apartment in CGHS Bank Vihar Apartments', '3 BHK Apartment in Reputed Builder Highland Apartment', '3 BHK Apartment in CGHS Sri Agrasen Apartments', '2 BHK Independent Floor in Ashima Properties Floors 6', '3 BHK Apartment in Reputed Builder Sapna Ghar Apartment', '3 BHK Apartment in Reputed Builder Kamakshi Apartment', '4 BHK Apartment in Reputed Builder The New Rajput', 'Reputed Builder Katyayani Apartment,Sector 6 Dwarka, Delhi', 'CGHS Roo
# ...

# %%
scraper.set_rule_aliases({'rule_f9i4':'Title','rule_10zw':'Area','rule_hfvd':'Status','rule_eryi':'Price'})
scraper.keep_rules(['rule_f9i4','rule_10zw','rule_hfvd','rule_eryi'])
scraper.save('makaan-search')
results63=scraper.get_result_similar(url63,group_by_alias=True)
results63
# Out:
# {'Title': ['3 BHK Apartment in Reputed Builder Katyayani Apartment',
#   '3 BHK Apartment in CGHS Roop Villa Apartment',
#   '3 BHK Apartment in CGHS Evergreen Apartment',
#   '3 BHK Apartment in CGHS Chopra Apartment',
#   '3 BHK Apartment in Reputed Builder Vidya Sagar Apartments',
#   '3 BHK Apartment in Reputed Builder DJA Apartment',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor in Ashima Ashima Floors - 7',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Apartment',
#   '4 BHK Apartment in Reputed Builder Sapna Ghar Apartment',
#   '3 BHK Apartment in DDA Sanskriti Apartments',
#   '3 BHK Apartment in CGHS Bank Vihar Apartments',
#   '3 BHK Apartment in Reputed Builder Highland Apartment',
#   '3 BHK Apartment in CGHS Sri Agrasen Apartments',
#   '2 BHK Independent Floor in Ashima Properties Floors 6',
#   '3 BHK Apartment in Reputed Builder Sapna Ghar Apartment',
#   '3 BHK Apartment in Reputed Builder Kamakshi Apartment',
# ...

# %%
makaan63=pd.DataFrame(results63)
m63=m62.append(makaan63)
m63.head()
# Out:
#                      Title             Location1    Area         Status Price  \
# 0  4 BHK Independent Floor     Neeti Bagh, Delhi  2925.0  Ready to move   8.5
# 1          1 BHK Apartment    Khera Khurd, Delhi   450.0  Ready to move   9.5
# 2  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0  Ready to move  2.35
# 3  3 BHK Independent Floor  Paschim Vihar, Delhi  1620.0  Ready to move   2.4
# 4  4 BHK Independent Floor  Paschim Vihar, Delhi  2250.0  Ready to move  2.35
#
#   Year Bathroom             Location
# 0  NaN      NaN  South/Central Delhi
# 1  NaN      NaN  South/Central Delhi
# 2  NaN      NaN  South/Central Delhi
# 3  NaN      NaN  South/Central Delhi
# 4  NaN      NaN  South/Central Delhi

# %%
url64="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=138"
wanted_list64=["3 BHK Apartment","Sector 19 Dwarka, Delhi","1700","Ready to move","2 Bathrooms", "1.53 Cr"]
result64=scraper.build(url64,wanted_list64)
print(result64)

scraper.get_result_similar(url64,grouped=True)
# Out:
# ['3 BHK Apartment in CGHS Roop Villa Apartment', '3 BHK Apartment', '3 BHK Apartment in Reputed Builder Ekta Apartment', '4 BHK Apartment in Reputed Builder Sapna Ghar Apartment', '3 BHK Apartment in Reputed Builder Sapna Ghar Apartment', '3 BHK Apartment in Reputed Builder Kamakshi Apartment', '3 BHK Apartment in CGHS The Shabad', '3 BHK Apartment in Reputed Builder Swami Dayanand', '3 BHK Independent Floor', '2 BHK Independent Floor', '3 BHK Apartment in Reputed Builder Kaveri Apartment', '3 BHK Apartment in Reputed Builder Navin Residency', '3 BHK Apartment in Reputed Builder Crescent Apartment', '3 BHK Apartment in JP Beverly Park CGHS', '4 BHK Apartment in Reputed Builder Kamakshi Apartment', '3 BHK Apartment in Reputed Builder Kanak Durga Apartment', '4 BHK Apartment', 'Sector 19 Dwarka, Delhi', 'Sector 4 Dwarka, Delhi', 'Sector 3 Dwarka, Delhi', 'Sector 11 Dwarka, Delhi', 'Sector 6 Dwarka, Delhi', 'Sector 13 Dwarka, Delhi', 'Sector-18 Dwarka, Delhi', 'Uttam Nagar, Delhi', 'Sec
# ...

# %%
scraper.set_rule_aliases({'rule_rpnh':'Title','rule_smf1':'Location1','rule_x1n4':'Area','rule_byko':'Status','rule_r5di':'Price'})
scraper.keep_rules(['rule_rpnh','rule_smf1','rule_x1n4','rule_byko','rule_r5di'])
scraper.save('makaan-search')
results64=scraper.get_result_similar(url64,group_by_alias=True)
results64
# Out:
# {'Title': ['3 BHK Apartment in CGHS Roop Villa Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment in Reputed Builder Ekta Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment in Reputed Builder Sapna Ghar Apartment',
#   '3 BHK Apartment in Reputed Builder Sapna Ghar Apartment',
#   '3 BHK Apartment in Reputed Builder Kamakshi Apartment',
#   '3 BHK Apartment in CGHS The Shabad',
#   '3 BHK Apartment',
#   '3 BHK Apartment in Reputed Builder Swami Dayanand',
#   '3 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Apartment in Reputed Builder Kaveri Apartment',
#   '3 BHK Apartment in Reputed Builder Navin Residency',
#   '3 BHK Apartment in Reputed Builder Crescent Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment in JP Beverly Park CGHS',
#   '4 BHK Apartment in Reputed Builder Kamakshi Apartment',
#   '3 BHK Apartment in Reputed Builder Kanak Durga Apartment',
#   '3 BHK Apartment'],
#  'Location1': ['Sector 19 Dwarka, Delhi',
# ...

# %%
makaan64=pd.DataFrame(results64)
m64=m63.append(makaan64)
m64.shape
# Out:
# (1160, 8)

# %%
url65="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=139"
wanted_list65=["3 BHK Apartment","Sector 7 Dwarka, Delhi","1700","Ready to move","3 Bathrooms", "1.4 Cr"]
result65=scraper.build(url65,wanted_list65)
print(result65)

scraper.get_result_similar(url65,grouped=True)
# Out:
# ['3 BHK Apartment', '2 BHK Apartment', '4 BHK Apartment', '2 BHK Independent Floor', '3 BHK Independent Floor', 'Sector 6 Dwarka, Delhi', 'Sector 10 Dwarka, Delhi', 'Sector 23 Dwarka, Delhi', 'Sector 3 Dwarka, Delhi', 'Sector 4 Dwarka, Delhi', 'Sector-18 Dwarka, Delhi', 'Sector 12 Dwarka, Delhi', 'Sector 22 Dwarka, Delhi', 'Sector 7 Dwarka, Delhi', 'Uttam Nagar, Delhi', 'Dwarka Mor, Delhi', '1700', '1300', '2200', '1100', '1600', '2400', '2500', '1800', '540', '810', '500', 'Ready to move', '2 Bathrooms', '3 Bathrooms', '6 - 7 years old', '2 - 3 years old', '19 - 20 years old', '4 Bathrooms', '5 - 6 years old', '7 - 8 years old', 'Resale', 'New', '1.6 Cr', '1.18 Cr', '1.9 Cr', '1.58 Cr', '1.1 Cr', '2.25 Cr', '2.7 Cr', '2.1 Cr', '2.2 Cr', '1.55 Cr', '1.65 Cr', '1.4 Cr', '1.5 Cr', '26 L', '45 L', '25.5 L', '42 L']
# {'rule_k5i4': ['3 BHK Apartment',
#   '2 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
# ...

# %%
scraper.set_rule_aliases({'rule_k5i4':'Title','rule_cpna':'Location1','rule_rtgv':'Area','rule_e0et':'Status','rule_5p9d':'Price'})
scraper.keep_rules(['rule_k5i4','rule_cpna','rule_rtgv','rule_e0et','rule_5p9d'])
scraper.save('makaan-search')
results65=scraper.get_result_similar(url65,group_by_alias=True)
results65
# Out:
# {'Title': ['3 BHK Apartment',
#   '2 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '4 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '3 BHK Apartment',
#   '2 BHK Apartment',
#   '2 BHK Apartment',
#   '3 BHK Independent Floor',
#   '2 BHK Apartment'],
#  'Location1': ['Sector 6 Dwarka, Delhi',
#   'Sector 10 Dwarka, Delhi',
#   'Sector 6 Dwarka, Delhi',
#   'Sector 6 Dwarka, Delhi',
#   'Sector 23 Dwarka, Delhi',
#   'Sector 3 Dwarka, Delhi',
#   'Sector 4 Dwarka, Delhi',
#   'Sector-18 Dwarka, Delhi',
#   'Sector 12 Dwarka, Delhi',
#   'Sector 22 Dwarka, Delhi',
#   'Sector 12 Dwarka, Delhi',
#   'Sector 4 Dwarka, Delhi',
#   'Sector 10 Dwarka, Delhi',
#   'Sector 10 Dwarka, Delhi',
#   'Sector 7 Dwarka, Delhi',
#   'Sector 4 Dwarka, Delhi',
# ...

# %%
makaan65=pd.DataFrame(results65)
m65=m64.append(makaan65)
m65.shape
# Out:
# (1180, 8)

# %%
url66="https://www.makaan.com/delhi-residential-property/buy-property-in-delhi-city?page=140"
wanted_list66=["2 BHK Independent Floor","Uttam Nagar, Delhi","540","Ready to move","2 Bathrooms", "26 L"]
result66=scraper.build(url66,wanted_list66)
print(result66)

scraper.get_result_similar(url66,grouped=True)
# Out:
# ['3 BHK Independent Floor', '2 BHK Apartment in S Gambhir Affordables And Luxury Homes', '2 BHK Independent Floor', '3 BHK Independent Floor in J R Floors', '4 BHK Independent Floor', '4 BHK Apartment in CGHS Guru Apartments', '3 BHK Apartment in CGHS Kunj Vihar Apartment', '3 BHK Apartment in CGHS Sri Niketan Apartments', '3 BHK Apartment', '3 BHK Apartment in Reputed Builder Veena Residency', '3 BHK Apartment in Reputed Builder Shiv Bhole Apartments', '3 BHK Apartment in CGHS Kesarwani Apartments', '3 BHK Apartment in Reputed Builder Sanmati Kunj', '3 BHK Apartment in CGHS Udyog Vihar', '3 BHK Apartment in Reputed Builder Nuovo Apartments', '3 BHK Apartment in CGHS ShivLok Apartment', 'Dwarka Mor, Delhi', 'S Gambhir Affordables And Luxury Homes,Dwarka Mor, Delhi', 'Uttam Nagar, Delhi', 'J R Floors,Sector 24 Rohini, Delhi', 'Rohini sector 24, Delhi', 'Sector 25 Rohini, Delhi', 'Sector 28 Rohini, Delhi', 'CGHS Guru Apartments,Sector 6 Dwarka, Delhi', 'Sector-29 Rohini, Delhi', 'Secto
# ...

# %%
scraper.set_rule_aliases({'rule_hgnp':'Title','rule_pjby':'Area','rule_n3gw':'Status','rule_3hbr':'Price'})
scraper.keep_rules(['rule_hgnp','rule_pjby','rule_n3gw','rule_3hbr'])
scraper.save('makaan-search')
results66=scraper.get_result_similar(url66,group_by_alias=True)
results66
# Out:
# {'Title': ['2 BHK Independent Floor',
#   '2 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor in J R Floors',
#   '3 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '3 BHK Independent Floor',
#   '4 BHK Independent Floor',
#   '4 BHK Apartment in CGHS Guru Apartments',
#   '3 BHK Apartment in Reputed Builder Shiv Bhole Apartments',
#   '3 BHK Apartment in Reputed Builder United Apartment',
#   '3 BHK Apartment in CGHS Udyog Vihar',
#   '3 BHK Apartment in Reputed Builder Nuovo Apartments',
#   '3 BHK Apartment in CGHS Ganinath Nikunj',
#   '3 BHK Apartment',
#   '4 BHK Apartment in CGHS Sanchar Vihar Apartments',
#   '3 BHK Apartment in CGHS Batukji Apartment',
#   '3 BHK Apartment in CGHS ShivLok Apartment',
#   '3 BHK Apartment in CGHS Kesarwani Apartments'],
#  'Area': ['540',
#   '540',
#   '810',
#   '800',
#   '950',
#   '1100',
#   '1800',
#   '1000',
#   '1500',
#   '2400',
#   '1700',
#   '1700',
# ...

# %%
makaan66=pd.DataFrame(results66)
m66=m65.append(makaan66)
m66.duplicated().sum()
# Out:
# 79

# %%
m66.to_csv("Makaan.com_New_RawData.csv")

# %%
df1.head(60)
# Out:
#     Unnamed: 0                                              Title  \
# 0            0                            4 BHK Independent Floor
# 1            1                                    1 BHK Apartment
# 2            2                            3 BHK Independent Floor
# 3            3                            3 BHK Independent Floor
# 4            4                            4 BHK Independent Floor
# 5            5                            4 BHK Independent Floor
# 6            6                            3 BHK Independent Floor
# 7            7                            4 BHK Independent Floor
# 8            8                                    3 BHK Apartment
# 9            9                                    3 BHK Apartment
# 10          10                                    2 BHK Apartment
# 11          11                                    2 BHK Apartment
# 12          12                                    2 BHK Apartment
# ...
